# %%
import pandas as pd
from pandas import MultiIndex, Int16Dtype
Ref=pd.read_csv('Ref.csv')
Ref["CO"] = 1000 * Ref["CO"]
Ref['Date'] = pd.to_datetime(Ref['Date_Time'])
Ref=Ref.set_index('Date')
Ref.drop('Date_Time',axis = 1, inplace = True)
Ref=Ref.resample('5min').mean()
Ref=Ref[76463:137376]
Ref_CO=Ref['CO'].to_list()
Ref_NO2=Ref['NO2'].to_list()
Ref_SO2=Ref['SO2'].to_list()
Ref_O3=Ref['O3'].to_list()

# %%
import random
import pandas as pd
import scipy.io
import numpy as np
data = pd.read_csv('CO.txt', header = None,low_memory=False)
data.columns=['WE','AE','Temp','RH','Time']
Time=data['Time'].to_list()
time=[]
for i in range(len(Time)):
    time.append(float(abs(Time[i])))
Time=np.array(time)
Date=pd.to_datetime(Time-719529,unit='d').round('s')
data['Date'] = Date.tolist()
data=data.set_index('Date')
data.drop('Time',axis = 1, inplace = True)
data=data.resample('5min').mean()
Data_CO=data
Data_CO['Ref']=Ref_CO
index_names = Data_CO[ (Data_CO['WE'] >1000)].index
Data_CO.drop(index_names, inplace = True)
WE=Data_CO['WE'].to_list()
AE=Data_CO['AE'].to_list()
signal=np.array(WE)-np.array(AE)
Data_CO['Net Signal']=signal
Data_CO['Month']=Data_CO.index.month
Data_CO['Day_of_week']=Data_CO.index.dayofweek
Data_CO['Day']=Data_CO.index.day
Data_CO['Hour']=Data_CO.index.hour
CO_Data=Data_CO
CO_Data=CO_Data[(CO_Data[CO_Data.columns] >= 0).all(axis=1)]
CO_Data=CO_Data.dropna()
data = pd.read_csv('Conc_CO.txt', header = None,low_memory=False)
data.columns=['Lab1','Temp','RH','Time','Ref']
Time=data['Time'].to_list()
time=[]
for i in range(len(Time)):
    time.append(float(abs(Time[i])))
Time=np.array(time)
Date=pd.to_datetime(Time-719529,unit='d').round('s')
data['Date'] = Date.tolist()
data=data.set_index('Date')
data.drop('Time',axis = 1, inplace = True)
data=data.resample('5min').mean()
Data_CO=data
Data_CO.drop(index_names, inplace = True)
signal=np.array(WE)-np.array(AE)
Data_CO['Net Signal']=signal
Data_CO['Month']=Data_CO.index.month
Data_CO['Day_of_week']=Data_CO.index.dayofweek
Data_CO['Day']=Data_CO.index.day
Data_CO['Hour']=Data_CO.index.hour
CO_Data=Data_CO
CO_Data=CO_Data[(CO_Data[CO_Data.columns] >= 0).all(axis=1)]
CO_Data=CO_Data.dropna()
CO_Data=CO_Data.resample('h').mean()
CO_Data=CO_Data.dropna()
CO_Data.tail()
# Out:
#                            Lab1       Temp         RH         Ref  Net Signal  \
# Date
# 2020-04-30 19:00:00  242.060716  18.870796  71.072939  188.915151   91.471325
# 2020-04-30 20:00:00  218.655079  18.056864  75.132153  178.704750   84.176485
# 2020-04-30 21:00:00  194.147868  17.090891  81.315038  161.421792   73.858294
# 2020-04-30 22:00:00  206.432889  16.714085  82.568155  197.744043   83.279611
# 2020-04-30 23:00:00  173.577429  16.365121  83.662401  162.157636   68.669099
#
#                      Month  Day_of_week   Day  Hour
# Date
# 2020-04-30 19:00:00    4.0          3.0  30.0  19.0
# 2020-04-30 20:00:00    4.0          3.0  30.0  20.0
# 2020-04-30 21:00:00    4.0          3.0  30.0  21.0
# 2020-04-30 22:00:00    4.0          3.0  30.0  22.0
# 2020-04-30 23:00:00    4.0          3.0  30.0  23.0

# %%
import pandas as pd
import scipy.io
import numpy as np
data = pd.read_csv('O3.txt', header = None,low_memory=False)
data.columns=['AE','WE','Temp','RH','Time']
Time=data['Time'].to_list()
time=[]
for i in range(len(Time)):
    time.append(float(abs(Time[i])))
Time=np.array(time)
Date=pd.to_datetime(Time-719529,unit='d').round('s')
data['Date'] = Date.tolist()
data=data.set_index('Date')
data.drop('Time',axis = 1, inplace = True)
data=data.resample('5min').mean()
Data_O3=data
Data_O3['Ref']=Ref_O3
WE=Data_O3['WE'].to_list()
AE=Data_O3['AE'].to_list()
signal=np.array(WE)-np.array(AE)
Data_O3['Net Signal']=signal
Data_O3['Month']=Data_O3.index.month
Data_O3['Day_of_week']=Data_O3.index.dayofweek
Data_O3['Day']=Data_O3.index.day
Data_O3['Hour']=Data_O3.index.hour
O3_Data=Data_O3
O3_Data=O3_Data[(O3_Data[O3_Data.columns] >= 0).all(axis=1)]
O3_Data=O3_Data.dropna()
data = pd.read_csv('Conc_O3.txt', header = None,low_memory=False)
data.columns=['Lab1','Temp','RH','Time','Ref']
Time=data['Time'].to_list()
time=[]
for i in range(len(Time)):
    time.append(float(abs(Time[i])))
Time=np.array(time)
Date=pd.to_datetime(Time-719529,unit='d').round('s')
data['Date'] = Date.tolist()
data=data.set_index('Date')
data.drop('Time',axis = 1, inplace = True)
data=data.resample('5min').mean()
Data_O3=data
signal=np.array(WE)-np.array(AE)
Data_O3['Net Signal']=signal
Data_O3['Month']=Data_O3.index.month
Data_O3['Day_of_week']=Data_O3.index.dayofweek
Data_O3['Day']=Data_O3.index.day
Data_O3['Hour']=Data_O3.index.hour
O3_Data=Data_O3
O3_Data=O3_Data[(O3_Data[O3_Data.columns] >= 0).all(axis=1)]
O3_Data=O3_Data.dropna() 
O3_Data=O3_Data.resample('h').mean()
O3_Data=O3_Data.dropna()
O3_Data.head()

ref_O3=Data_O3['Ref'].to_list()
len(ref_O3)
# Out:
# 60913

# %%
import pandas as pd
import scipy.io
import numpy as np
data = pd.read_csv('NO2.txt', header = None,low_memory=False)
data.columns=['WE','AE','Temp','RH','Time']
Time=data['Time'].to_list()
time=[]
for i in range(len(Time)):
    time.append(float(abs(Time[i])))
Time=np.array(time)
Date=pd.to_datetime(Time-719529,unit='d').round('s')
data['Date'] = Date.tolist()
data=data.set_index('Date')
data.drop('Time',axis = 1, inplace = True)
data=data.resample('5min').mean()
Data_NO2=data
Data_NO2['Ref']=Ref_NO2
WE=Data_NO2['WE'].to_list()
AE=Data_NO2['AE'].to_list()
signal=np.array(WE)-np.array(AE)
Data_NO2['Net Signal']=signal
Data_NO2['Month']=Data_NO2.index.month
Data_NO2['Day_of_week']=Data_NO2.index.dayofweek
Data_NO2['Day']=Data_NO2.index.day
Data_NO2['Hour']=Data_NO2.index.hour
NO2_Data=Data_NO2
NO2_Data=NO2_Data[(NO2_Data[NO2_Data.columns] >= 0).all(axis=1)]
NO2_Data=NO2_Data.dropna()
data = pd.read_csv('Conc_NO2.txt', header = None,low_memory=False)
data.columns=['Lab1','Temp','RH','Time','Ref']
Time=data['Time'].to_list()
time=[]
subscript = str.maketrans("0123456789", "₀₁₂₃₄₅₆₇₈₉") 
for i in range(len(Time)):
    time.append(float(abs(Time[i])))
Time=np.array(time)
Date=pd.to_datetime(Time-719529,unit='d').round('s')
data['Date'] = Date.tolist()
data=data.set_index('Date')
data.drop('Time',axis = 1, inplace = True)
data=data.resample('5min').mean()
Data_NO2=data
signal=np.array(WE)-np.array(AE)
Data_NO2['Net Signal']=signal
Data_NO2['Month']=Data_NO2.index.month
Data_NO2['Day_of_week']=Data_NO2.index.dayofweek
Data_NO2['Day']=Data_NO2.index.day
Data_NO2['Hour']=Data_NO2.index.hour
Data_NO2['Ref_O3']=ref_O3
NO2_Data=Data_NO2
NO2_Data=NO2_Data[(NO2_Data[NO2_Data.columns] >= 0).all(axis=1)]
NO2_Data=NO2_Data.dropna()
NO2_Data=NO2_Data.resample('h').mean()
NO2_Data=NO2_Data.dropna()

# %%
import pandas as pd
import scipy.io
import numpy as np
data = pd.read_csv('O3.txt', header = None,low_memory=False)
data.columns=['AE','WE','Temp','RH','Time']
Time=data['Time'].to_list()
time=[]
for i in range(len(Time)):
    time.append(float(abs(Time[i])))
Time=np.array(time)
Date=pd.to_datetime(Time-719529,unit='d').round('s')
data['Date'] = Date.tolist()
data=data.set_index('Date')
data.drop('Time',axis = 1, inplace = True)
data=data.resample('5min').mean()
Data_O3=data
Data_O3['Ref']=Ref_O3
WE=Data_O3['WE'].to_list()
AE=Data_O3['AE'].to_list()
signal=np.array(WE)-np.array(AE)
Data_O3['Net Signal']=signal
Data_O3['Month']=Data_O3.index.month
Data_O3['Day_of_week']=Data_O3.index.dayofweek
Data_O3['Day']=Data_O3.index.day
Data_O3['Hour']=Data_O3.index.hour
O3_Data=Data_O3
O3_Data=O3_Data[(O3_Data[O3_Data.columns] >= 0).all(axis=1)]
O3_Data=O3_Data.dropna()
data = pd.read_csv('Conc_O3.txt', header = None,low_memory=False)
data.columns=['Lab1','Temp','RH','Time','Ref']
Time=data['Time'].to_list()
time=[]
for i in range(len(Time)):
    time.append(float(abs(Time[i])))
Time=np.array(time)
Date=pd.to_datetime(Time-719529,unit='d').round('s')
data['Date'] = Date.tolist()
data=data.set_index('Date')
data.drop('Time',axis = 1, inplace = True)
data=data.resample('5min').mean()
Data_O3=data
signal=np.array(WE)-np.array(AE)
Data_O3['Net Signal']=signal
Data_O3['Month']=Data_O3.index.month
Data_O3['Day_of_week']=Data_O3.index.dayofweek
Data_O3['Day']=Data_O3.index.day
Data_O3['Hour']=Data_O3.index.hour
ref_NO2=Data_NO2['Ref'].to_list()
Data_O3['Ref_NO2']=ref_NO2
O3_Data=Data_O3
O3_Data=O3_Data[(O3_Data[O3_Data.columns] >= 0).all(axis=1)]
O3_Data=O3_Data.dropna()
O3_Data=O3_Data.resample('h').mean()
O3_Data=O3_Data.dropna()
O3_Data.head()
# Out:
#                            Lab1       Temp         RH        Ref  Net Signal  \
# Date
# 2019-10-02 11:00:00  621.625704  26.378438  58.063437  46.094860    3.605625
# 2019-10-02 12:00:00  725.154408  25.795055  48.256857  57.532808   13.865109
# 2019-10-07 10:00:00  108.196313  32.344264  37.260757  47.259008   11.447809
# 2019-10-07 11:00:00  135.822676  34.926112  35.013036  42.114260   10.075221
# 2019-10-07 12:00:00  203.757758  36.201221  31.829282  45.701366    7.624153
#
#                      Month  Day_of_week  Day  Hour    Ref_NO2
# Date
# 2019-10-02 11:00:00   10.0          2.0  2.0  11.0  15.230400
# 2019-10-02 12:00:00   10.0          2.0  2.0  12.0   5.384051
# 2019-10-07 10:00:00   10.0          0.0  7.0  10.0   4.255772
# 2019-10-07 11:00:00   10.0          0.0  7.0  11.0  16.268034
# 2019-10-07 12:00:00   10.0          0.0  7.0  12.0  12.770444

# %% [markdown]
# # CO DATA

# %%
from sktime.performance_metrics.forecasting import sMAPE, smape_loss
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error as mae
import sklearn.metrics as sm
import matplotlib.pyplot as plt
#'Ref_NO2','Ref_SO2','Ref_O3',
#,'Month','Day_of_week','Day','Hour'
X=CO_Data[['Net Signal','Lab1','Temp','RH','Month','Day_of_week','Hour']]
y=CO_Data['Ref']
X_train, X_test, y_train, y_test =train_test_split(X,y,test_size = 0.2,shuffle=True)
#train_test_split(X, y, test_size = 0.2)

# %%
from flaml.model import SKLearnEstimator
# SKLearnEstimator is derived from BaseEstimator
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/xgboost/compat.py:93: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %% [markdown]
# from sklearn.svm import SVR
# from sklearn.model_selection import GridSearchCV
#
# # defining parameter range
# param_grid = {'C': [0.1, 1, 10, 100, 1000],
#               'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#               'kernel':  ['rbf']}
#
# grid = GridSearchCV(SVR(), param_grid, refit = True, verbose = 3)
#
# # fitting the model for grid search
# grid.fit(X_train.drop(['Lab1'], axis=1), y_train)
#
# # print best parameter after tuning
# print(grid.best_params_)
#
# # print how our model looks after hyper-parameter tuning
# print(grid.best_estimator_)

# %% [markdown]
# from flaml.model import SKLearnEstimator

# %% [markdown]
# from flaml.model import SKLearnEstimator
# # SKLearnEstimator is derived from BaseEstimator
# import numpy as np
#
# class RandomForestRegressor(SKLearnEstimator):
#     def __init__(self, task="binary", **config):
#         super().__init__(task, **config)
#
#         if task in CLASSIFICATION:
#             from sklearn.ensemble import RandomForestClassifier
#
#             self.estimator_class =RandomForestClassifier
#         else:
#             from sklearn.ensemble import RandomForestRegressor
#
#             self.estimator_class =RandomForestRegressor
#
#     @classmethod
#     def search_space(cls, data_size, task):
#         space = {
#             "n_estimators": {
#                 "domain": {"domain": tune.loguniform(lower=100, upper=20000)},
#                 "low_cost_init_value": 100,
#             },
#             "max_features": {
#                 "domain": tune.loguniform(lower=0.1, upper=1),
#                 "low_cost_init_value": 0.1,
#             },
#             "max_leaf_nodes": {
#                 "domain": tune.lograndint(lower=100, upper=2500),
#                 "low_cost_init_value": 100,},
#             "min_samples_split": {"domain": tune.lograndint(lower=1, upper=20),
#             "init_value": 20,},
#
#             "min_samples_leaf": {
#                 "domain": tune.lograndint(lower=1, upper=20),
#                 "init_value": 20,
#             },
#         }
#         return space

# %% [markdown]
# from flaml import AutoML
# from flaml import tune
# automl = AutoML()
# automl.add_learner("rfr",RandomForestRegressor )

# %% [markdown]
# automl_settings = {
#     "time_budget": 1000,  # in seconds
#     "metric": 'rmse',
#     "task": 'regression',
#     "log_file_name": "california.log",
# }
# # Train with labeled input data
# automl.fit(X_train=X_train.drop(['Lab1'], axis=1), y_train=y_train,**automl_settings,estimator_list=["rfr"])
# pred=automl.predict(X_test.drop(['Lab1'], axis=1))
# R2=round(sm.r2_score(y_test, pred), 2)
# r=round(np.corrcoef(y_test, pred)[0, 1],2)
# RMSE=round(np.sqrt(sm.mean_squared_error(y_test, pred))/np.mean(y),2)
# print(r,R2,RMSE)

# %% [markdown]
# #  NO2 DATA

# %%
X=NO2_Data[['Net Signal','Lab1','Temp','RH','Month','Day_of_week','Hour','Ref_O3']]#'Ref_O3'
y=NO2_Data['Ref']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)
#len(X_test)
X.shape
# Out:
# (3778, 8)

# %%
from flaml import AutoML
from sklearn.datasets import fetch_california_housing

# Initialize an AutoML instance
automl = AutoML()
# Specify automl goal and constraint
automl_settings = {
    "time_budget": 200,  # in seconds
    "metric": 'mae',
    "task": 'regression',
    "log_file_name": "california.log",
}
# Train with labeled input data
automl.fit(X_train=X_train.drop(['Lab1'], axis=1), y_train=y_train,**automl_settings)
pred=automl.predict(X_test.drop(['Lab1'], axis=1))
R2=round(sm.r2_score(y_test, pred), 2)
r=round(np.corrcoef(y_test, pred)[0, 1],2)
RMSE=round(np.sqrt(sm.mean_squared_error(y_test, pred))/np.mean(y),2)
print(r,R2,RMSE)
# Predict
#print(automl.predict(X_test))
# Print the best model
print(automl.model.estimator)
# Out:
# [flaml.automl: 12-06 08:54:41] {2599} INFO - task = regression
# [flaml.automl: 12-06 08:54:41] {2601} INFO - Data split method: uniform
# [flaml.automl: 12-06 08:54:41] {2604} INFO - Evaluation method: cv
# [flaml.automl: 12-06 08:54:41] {2726} INFO - Minimizing error metric: rmse
# [flaml.automl: 12-06 08:54:41] {2870} INFO - List of ML learners in AutoML Run: ['lgbm', 'rf', 'xgboost', 'extra_tree', 'xgb_limitdepth']
# [flaml.automl: 12-06 08:54:41] {3166} INFO - iteration 0, current learner lgbm
# [flaml.automl: 12-06 08:54:41] {3296} INFO - Estimated sufficient time budget=5651s. Estimated necessary time budget=40s.
# [flaml.automl: 12-06 08:54:41] {3343} INFO -  at 0.7s,	estimator lgbm's best error=9.3646,	best estimator lgbm's best error=9.3646
# [flaml.automl: 12-06 08:54:41] {3166} INFO - iteration 1, current learner lgbm
# [flaml.automl: 12-06 08:54:42] {3343} INFO -  at 1.4s,	estimator lgbm's best error=9.3646,	best estimator lgbm's best error=9.3646
# [flaml.automl: 12-06 08:54:42] {3166} INFO - iteration 2, current learner lgbm
# [flaml.automl: 12-06 08:54:43] {3343} INFO -  at 2.0s,	estimator lgbm's best error=7.0410,	best estimator lgbm's best error=7.0410
# [flaml.automl: 12-06 08:56:02] {3343} INFO -  at 81.7s,	estimator extra_tree's best error=3.3262,	best estimator extra_tree's best error=3.3262
# [flaml.automl: 12-06 08:56:02] {3166} INFO - iteration 59, current learner xgboost
# [flaml.automl: 12-06 08:56:04] {3343} INFO -  at 83.2s,	estimator xgboost's best error=3.2199,	best estimator xgboost's best error=3.2199
# [flaml.automl: 12-06 08:56:04] {3166} INFO - iteration 60, current learner extra_tree
# [flaml.automl: 12-06 08:56:04] {3343} INFO -  at 83.8s,	estimator extra_tree's best error=3.3262,	best estimator xgboost's best error=3.2199
# [flaml.automl: 12-06 08:56:04] {3166} INFO - iteration 61, current learner xgboost
# [flaml.automl: 12-06 08:56:05] {3343} INFO -  at 84.4s,	estimator xgboost's best error=3.2199,	best estimator xgboost's best error=3.2199
# [flaml.automl: 12-06 08:56:05] {3166} INFO - iteration 62, current learner extra_tree
# [flaml.automl: 12-06 08:56:07] {3343} INFO -  at 86.4s,	estimator extra_tree's best error=3.2126,	best estimator extra_tree's best error=3.2126
# [flaml.automl: 12-06 08:56:07] {3166} INFO - iteration 63, current learner extra_tree
# [flaml.automl: 12-06 08:56:08] {3343} INFO -  at 87.3s,	estimator extra_tree's best error=3.2126,	best estimator extra_tree's best error=3.2126
# [flaml.automl: 12-06 08:56:08] {3166} INFO - iteration 64, current learner xgboost
# [flaml.automl: 12-06 08:56:14] {3343} INFO -  at 93.4s,	estimator xgboost's best error=3.2199,	best estimator extra_tree's best error=3.2126
# [flaml.automl: 12-06 08:56:14] {3166} INFO - iteration 65, current learner extra_tree
# [flaml.automl: 12-06 08:56:16] {3343} INFO -  at 95.8s,	estimator extra_tree's best error=3.1783,	best estimator extra_tree's best error=3.1783
# [flaml.automl: 12-06 08:56:16] {3166} INFO - iteration 66, current learner extra_tree
# [flaml.automl: 12-06 08:56:21] {3343} INFO -  at 100.1s,	estimator extra_tree's best error=3.1551,	best estimator extra_tree's best error=3.1551
# [flaml.automl: 12-06 08:56:21] {3166} INFO - iteration 67, current learner xgboost
# [flaml.automl: 12-06 08:56:21] {3343} INFO -  at 100.8s,	estimator xgboost's best error=3.2199,	best estimator extra_tree's best error=3.1551
# [flaml.automl: 12-06 08:56:21] {3166} INFO - iteration 68, current learner lgbm
# [flaml.automl: 12-06 08:56:24] {3343} INFO -  at 103.5s,	estimator lgbm's best error=3.3562,	best estimator extra_tree's best error=3.1551
# [flaml.automl: 12-06 08:56:24] {3166} INFO - iteration 69, current learner extra_tree
# [flaml.automl: 12-06 08:56:26] {3343} INFO -  at 105.7s,	estimator extra_tree's best error=3.1551,	best estimator extra_tree's best error=3.1551
# [flaml.automl: 12-06 08:56:26] {3166} INFO - iteration 70, current learner extra_tree
# [flaml.automl: 12-06 08:56:37] {3343} INFO -  at 116.3s,	estimator extra_tree's best error=3.1551,	best estimator extra_tree's best error=3.1551
# [flaml.automl: 12-06 08:56:37] {3166} INFO - iteration 71, current learner xgboost
# [flaml.automl: 12-06 08:56:39] {3343} INFO -  at 118.5s,	estimator xgboost's best error=3.2199,	best estimator extra_tree's best error=3.1551
# [flaml.automl: 12-06 08:56:39] {3166} INFO - iteration 72, current learner extra_tree
# [flaml.automl: 12-06 08:56:42] {3343} INFO -  at 121.4s,	estimator extra_tree's best error=3.1549,	best estimator extra_tree's best error=3.1549
# [flaml.automl: 12-06 08:56:42] {3166} INFO - iteration 73, current learner xgboost
# [flaml.automl: 12-06 08:56:44] {3343} INFO -  at 123.1s,	estimator xgboost's best error=3.2199,	best estimator extra_tree's best error=3.1549
# [flaml.automl: 12-06 08:56:44] {3166} INFO - iteration 74, current learner extra_tree
# [flaml.automl: 12-06 08:56:45] {3343} INFO -  at 124.7s,	estimator extra_tree's best error=3.1549,	best estimator extra_tree's best error=3.1549
# [flaml.automl: 12-06 08:56:45] {3166} INFO - iteration 75, current learner rf
# [flaml.automl: 12-06 08:56:47] {3343} INFO -  at 126.1s,	estimator rf's best error=3.5911,	best estimator extra_tree's best error=3.1549
# [flaml.automl: 12-06 08:56:47] {3166} INFO - iteration 76, current learner rf
# [flaml.automl: 12-06 08:56:52] {3343} INFO -  at 131.0s,	estimator rf's best error=3.4127,	best estimator extra_tree's best error=3.1549
# [flaml.automl: 12-06 08:56:52] {3166} INFO - iteration 77, current learner extra_tree
# [flaml.automl: 12-06 08:56:57] {3343} INFO -  at 136.5s,	estimator extra_tree's best error=3.1549,	best estimator extra_tree's best error=3.1549
# [flaml.automl: 12-06 08:56:57] {3166} INFO - iteration 78, current learner xgboost
# [flaml.automl: 12-06 08:57:00] {3343} INFO -  at 139.4s,	estimator xgboost's best error=3.2199,	best estimator extra_tree's best error=3.1549
# [flaml.automl: 12-06 08:57:00] {3166} INFO - iteration 79, current learner rf
# [flaml.automl: 12-06 08:57:03] {3343} INFO -  at 142.8s,	estimator rf's best error=3.4127,	best estimator extra_tree's best error=3.1549
# [flaml.automl: 12-06 08:57:03] {3166} INFO - iteration 80, current learner extra_tree
# [flaml.automl: 12-06 08:57:07] {3343} INFO -  at 146.4s,	estimator extra_tree's best error=3.1431,	best estimator extra_tree's best error=3.1431
# [flaml.automl: 12-06 08:57:07] {3166} INFO - iteration 81, current learner xgboost
# [flaml.automl: 12-06 08:57:08] {3343} INFO -  at 147.1s,	estimator xgboost's best error=3.2199,	best estimator extra_tree's best error=3.1431
# [flaml.automl: 12-06 08:57:08] {3166} INFO - iteration 82, current learner extra_tree
# [flaml.automl: 12-06 08:57:12] {3343} INFO -  at 150.9s,	estimator extra_tree's best error=3.1431,	best estimator extra_tree's best error=3.1431
# [flaml.automl: 12-06 08:57:12] {3166} INFO - iteration 83, current learner extra_tree
# [flaml.automl: 12-06 08:57:19] {3343} INFO -  at 158.1s,	estimator extra_tree's best error=3.1431,	best estimator extra_tree's best error=3.1431
# [flaml.automl: 12-06 08:57:19] {3166} INFO - iteration 84, current learner extra_tree
# [flaml.automl: 12-06 08:57:20] {3343} INFO -  at 159.8s,	estimator extra_tree's best error=3.1431,	best estimator extra_tree's best error=3.1431
# [flaml.automl: 12-06 08:57:20] {3166} INFO - iteration 85, current learner extra_tree
# [flaml.automl: 12-06 08:57:24] {3343} INFO -  at 162.9s,	estimator extra_tree's best error=3.1431,	best estimator extra_tree's best error=3.1431
# [flaml.automl: 12-06 08:57:24] {3166} INFO - iteration 86, current learner extra_tree
# [flaml.automl: 12-06 08:57:27] {3343} INFO -  at 166.8s,	estimator extra_tree's best error=3.1431,	best estimator extra_tree's best error=3.1431
# [flaml.automl: 12-06 08:57:27] {3166} INFO - iteration 87, current learner xgboost
# [flaml.automl: 12-06 08:57:37] {3343} INFO -  at 176.7s,	estimator xgboost's best error=3.1583,	best estimator extra_tree's best error=3.1431
# [flaml.automl: 12-06 08:57:37] {3166} INFO - iteration 88, current learner rf
# [flaml.automl: 12-06 08:57:48] {3343} INFO -  at 187.3s,	estimator rf's best error=3.3433,	best estimator extra_tree's best error=3.1431
# [flaml.automl: 12-06 08:57:48] {3166} INFO - iteration 89, current learner extra_tree
# [flaml.automl: 12-06 08:57:50] {3343} INFO -  at 189.3s,	estimator extra_tree's best error=3.1431,	best estimator extra_tree's best error=3.1431
# [flaml.automl: 12-06 08:57:50] {3166} INFO - iteration 90, current learner xgboost
# [flaml.automl: 12-06 08:57:53] {3343} INFO -  at 192.6s,	estimator xgboost's best error=3.1583,	best estimator extra_tree's best error=3.1431
# [flaml.automl: 12-06 08:57:53] {3166} INFO - iteration 91, current learner extra_tree
# [flaml.automl: 12-06 08:57:57] {3343} INFO -  at 196.8s,	estimator extra_tree's best error=3.1329,	best estimator extra_tree's best error=3.1329
# [flaml.automl: 12-06 08:57:57] {3166} INFO - iteration 92, current learner extra_tree
# [flaml.automl: 12-06 08:58:02] {3343} INFO -  at 201.8s,	estimator extra_tree's best error=3.1329,	best estimator extra_tree's best error=3.1329
# [flaml.automl: 12-06 08:58:02] {3166} INFO - iteration 93, current learner xgboost
# [flaml.automl: 12-06 08:58:07] {3343} INFO -  at 206.3s,	estimator xgboost's best error=3.1583,	best estimator extra_tree's best error=3.1329
# [flaml.automl: 12-06 08:58:07] {3166} INFO - iteration 94, current learner lgbm
# [flaml.automl: 12-06 08:58:30] {3343} INFO -  at 229.1s,	estimator lgbm's best error=3.3185,	best estimator extra_tree's best error=3.1329
# [flaml.automl: 12-06 08:58:30] {3166} INFO - iteration 95, current learner extra_tree
# [flaml.automl: 12-06 08:58:35] {3343} INFO -  at 234.8s,	estimator extra_tree's best error=3.1329,	best estimator extra_tree's best error=3.1329
# [flaml.automl: 12-06 08:58:35] {3166} INFO - iteration 96, current learner xgboost
# [flaml.automl: 12-06 08:58:38] {3343} INFO -  at 237.3s,	estimator xgboost's best error=3.1583,	best estimator extra_tree's best error=3.1329
# [flaml.automl: 12-06 08:58:38] {3166} INFO - iteration 97, current learner extra_tree
# [flaml.automl: 12-06 08:58:49] {3343} INFO -  at 248.6s,	estimator extra_tree's best error=3.1329,	best estimator extra_tree's best error=3.1329
# [flaml.automl: 12-06 08:58:49] {3166} INFO - iteration 98, current learner xgboost
# [flaml.automl: 12-06 08:59:04] {3343} INFO -  at 263.6s,	estimator xgboost's best error=3.1583,	best estimator extra_tree's best error=3.1329
# [flaml.automl: 12-06 08:59:04] {3166} INFO - iteration 99, current learner xgboost
# [flaml.automl: 12-06 09:00:02] {3343} INFO -  at 321.6s,	estimator xgb_limitdepth's best error=3.6244,	best estimator extra_tree's best error=3.1116
# [flaml.automl: 12-06 09:00:02] {3166} INFO - iteration 113, current learner xgb_limitdepth
# [flaml.automl: 12-06 09:00:03] {3343} INFO -  at 322.8s,	estimator xgb_limitdepth's best error=3.6244,	best estimator extra_tree's best error=3.1116
# [flaml.automl: 12-06 09:00:03] {3166} INFO - iteration 114, current learner xgb_limitdepth
# [flaml.automl: 12-06 09:00:05] {3343} INFO -  at 324.0s,	estimator xgb_limitdepth's best error=3.6244,	best estimator extra_tree's best error=3.1116
# [flaml.automl: 12-06 09:00:05] {3166} INFO - iteration 115, current learner extra_tree
# [flaml.automl: 12-06 09:00:30] {3343} INFO -  at 348.9s,	estimator extra_tree's best error=3.1116,	best estimator extra_tree's best error=3.1116
# [flaml.automl: 12-06 09:00:30] {3166} INFO - iteration 116, current learner xgboost
# [flaml.automl: 12-06 09:00:34] {3343} INFO -  at 353.4s,	estimator xgboost's best error=3.1506,	best estimator extra_tree's best error=3.1116
# [flaml.automl: 12-06 09:00:34] {3166} INFO - iteration 117, current learner xgb_limitdepth
# [flaml.automl: 12-06 09:00:35] {3343} INFO -  at 354.3s,	estimator xgb_limitdepth's best error=3.6244,	best estimator extra_tree's best error=3.1116
# [flaml.automl: 12-06 09:00:35] {3166} INFO - iteration 118, current learner xgb_limitdepth
# [flaml.automl: 12-06 09:00:36] {3343} INFO -  at 355.1s,	estimator xgb_limitdepth's best error=3.6244,	best estimator extra_tree's best error=3.1116
# [flaml.automl: 12-06 09:00:36] {3166} INFO - iteration 119, current learner rf
# [flaml.automl: 12-06 09:00:58] {3343} INFO -  at 377.9s,	estimator rf's best error=3.3433,	best estimator extra_tree's best error=3.1116
# [flaml.automl: 12-06 09:00:58] {3166} INFO - iteration 120, current learner xgb_limitdepth
# [flaml.automl: 12-06 09:01:00] {3343} INFO -  at 379.6s,	estimator xgb_limitdepth's best error=3.6244,	best estimator extra_tree's best error=3.1116
# [flaml.automl: 12-06 09:01:00] {3166} INFO - iteration 121, current learner xgb_limitdepth
# [flaml.automl: 12-06 09:01:01] {3343} INFO -  at 380.7s,	estimator xgb_limitdepth's best error=3.6244,	best estimator extra_tree's best error=3.1116
# [flaml.automl: 12-06 09:01:01] {3166} INFO - iteration 122, current learner xgb_limitdepth
# [flaml.automl: 12-06 09:01:03] {3343} INFO -  at 382.5s,	estimator xgb_limitdepth's best error=3.6244,	best estimator extra_tree's best error=3.1116
# [flaml.automl: 12-06 09:01:03] {3166} INFO - iteration 123, current learner xgb_limitdepth
# [flaml.automl: 12-06 09:01:05] {3343} INFO -  at 384.3s,	estimator xgb_limitdepth's best error=3.6244,	best estimator extra_tree's best error=3.1116
# [flaml.automl: 12-06 09:01:05] {3166} INFO - iteration 124, current learner extra_tree
# [flaml.automl: 12-06 09:01:10] {3343} INFO -  at 389.8s,	estimator extra_tree's best error=3.1116,	best estimator extra_tree's best error=3.1116
# [flaml.automl: 12-06 09:01:10] {3166} INFO - iteration 125, current learner rf
# [flaml.automl: 12-06 09:01:31] {3343} INFO -  at 410.3s,	estimator rf's best error=3.3348,	best estimator extra_tree's best error=3.1116
# [flaml.automl: 12-06 09:01:31] {3166} INFO - iteration 126, current learner xgboost
# [flaml.automl: 12-06 09:01:40] {3343} INFO -  at 419.6s,	estimator xgboost's best error=3.1506,	best estimator extra_tree's best error=3.1116
# [flaml.automl: 12-06 09:01:40] {3166} INFO - iteration 127, current learner xgboost
# [flaml.automl: 12-06 09:01:45] {3343} INFO -  at 424.3s,	estimator xgboost's best error=3.1506,	best estimator extra_tree's best error=3.1116
# [flaml.automl: 12-06 09:01:45] {3166} INFO - iteration 128, current learner extra_tree
# [flaml.automl: 12-06 09:02:10] {3343} INFO -  at 449.8s,	estimator extra_tree's best error=3.1116,	best estimator extra_tree's best error=3.1116
# [flaml.automl: 12-06 09:02:10] {3166} INFO - iteration 129, current learner xgb_limitdepth
# [flaml.automl: 12-06 09:02:13] {3343} INFO -  at 452.4s,	estimator xgb_limitdepth's best error=3.5832,	best estimator extra_tree's best error=3.1116
# [flaml.automl: 12-06 09:02:13] {3166} INFO - iteration 130, current learner extra_tree
# [flaml.automl: 12-06 09:02:20] {3343} INFO -  at 459.6s,	estimator extra_tree's best error=3.1116,	best estimator extra_tree's best error=3.1116
# [flaml.automl: 12-06 09:02:20] {3166} INFO - iteration 131, current learner extra_tree
# [flaml.automl: 12-06 09:02:28] {3343} INFO -  at 467.6s,	estimator extra_tree's best error=3.1116,	best estimator extra_tree's best error=3.1116
# [flaml.automl: 12-06 09:02:28] {3166} INFO - iteration 132, current learner extra_tree
# [flaml.automl: 12-06 09:02:42] {3343} INFO -  at 481.6s,	estimator extra_tree's best error=3.1116,	best estimator extra_tree's best error=3.1116
# [flaml.automl: 12-06 09:02:42] {3166} INFO - iteration 133, current learner xgboost
# [flaml.automl: 12-06 09:02:58] {3343} INFO -  at 497.3s,	estimator xgboost's best error=3.1506,	best estimator extra_tree's best error=3.1116
# [flaml.automl: 12-06 09:02:58] {3166} INFO - iteration 134, current learner extra_tree
# [flaml.automl: 12-06 09:03:07] {3343} INFO -  at 506.7s,	estimator extra_tree's best error=3.1116,	best estimator extra_tree's best error=3.1116
# [flaml.automl: 12-06 09:03:07] {3166} INFO - iteration 135, current learner extra_tree
# [flaml.automl: 12-06 09:03:18] {3343} INFO -  at 517.9s,	estimator extra_tree's best error=3.1116,	best estimator extra_tree's best error=3.1116
# [flaml.automl: 12-06 09:03:18] {3166} INFO - iteration 136, current learner xgb_limitdepth
# [flaml.automl: 12-06 09:03:19] {3343} INFO -  at 518.4s,	estimator xgb_limitdepth's best error=3.5832,	best estimator extra_tree's best error=3.1116
# [flaml.automl: 12-06 09:03:19] {3166} INFO - iteration 137, current learner extra_tree
# [flaml.automl: 12-06 09:03:50] {3343} INFO -  at 548.9s,	estimator extra_tree's best error=3.1116,	best estimator extra_tree's best error=3.1116
# [flaml.automl: 12-06 09:03:50] {3166} INFO - iteration 138, current learner lgbm
# [flaml.automl: 12-06 09:04:06] {3343} INFO -  at 565.2s,	estimator lgbm's best error=3.3185,	best estimator extra_tree's best error=3.1116
# [flaml.automl: 12-06 09:04:06] {3166} INFO - iteration 139, current learner extra_tree
# [flaml.automl: 12-06 09:04:12] {3343} INFO -  at 571.3s,	estimator extra_tree's best error=3.1116,	best estimator extra_tree's best error=3.1116
# [flaml.automl: 12-06 09:04:12] {3166} INFO - iteration 140, current learner xgboost
# [flaml.automl: 12-06 09:04:14] {3343} INFO -  at 573.7s,	estimator xgboost's best error=3.1506,	best estimator extra_tree's best error=3.1116
# [flaml.automl: 12-06 09:04:14] {3166} INFO - iteration 141, current learner extra_tree
# [flaml.automl: 12-06 09:04:23] {3343} INFO -  at 581.9s,	estimator extra_tree's best error=3.1116,	best estimator extra_tree's best error=3.1116
# [flaml.automl: 12-06 09:04:23] {3166} INFO - iteration 142, current learner extra_tree
# [flaml.automl: 12-06 09:04:52] {3343} INFO -  at 611.7s,	estimator extra_tree's best error=3.1116,	best estimator extra_tree's best error=3.1116
# [flaml.automl: 12-06 09:04:52] {3166} INFO - iteration 143, current learner xgb_limitdepth
# [flaml.automl: 12-06 09:04:56] {3343} INFO -  at 615.5s,	estimator xgb_limitdepth's best error=3.3379,	best estimator extra_tree's best error=3.1116
# [flaml.automl: 12-06 09:04:56] {3166} INFO - iteration 144, current learner xgb_limitdepth
# [flaml.automl: 12-06 09:04:58] {3343} INFO -  at 617.6s,	estimator xgb_limitdepth's best error=3.3379,	best estimator extra_tree's best error=3.1116
# [flaml.automl: 12-06 09:04:58] {3166} INFO - iteration 145, current learner xgb_limitdepth
# [flaml.automl: 12-06 09:05:02] {3343} INFO -  at 621.7s,	estimator xgb_limitdepth's best error=3.3379,	best estimator extra_tree's best error=3.1116
# [flaml.automl: 12-06 09:05:02] {3166} INFO - iteration 146, current learner extra_tree
# [flaml.automl: 12-06 09:05:29] {3343} INFO -  at 648.5s,	estimator extra_tree's best error=3.1098,	best estimator extra_tree's best error=3.1098
# [flaml.automl: 12-06 09:05:29] {3166} INFO - iteration 147, current learner extra_tree
# [flaml.automl: 12-06 09:05:40] {3343} INFO -  at 659.9s,	estimator extra_tree's best error=3.1098,	best estimator extra_tree's best error=3.1098
# [flaml.automl: 12-06 09:05:40] {3166} INFO - iteration 148, current learner extra_tree
# [flaml.automl: 12-06 09:06:08] {3343} INFO -  at 686.9s,	estimator extra_tree's best error=3.1098,	best estimator extra_tree's best error=3.1098
# [flaml.automl: 12-06 09:06:08] {3166} INFO - iteration 149, current learner xgboost
# [flaml.automl: 12-06 09:06:14] {3343} INFO -  at 693.3s,	estimator xgboost's best error=3.1506,	best estimator extra_tree's best error=3.1098
# [flaml.automl: 12-06 09:06:14] {3166} INFO - iteration 150, current learner extra_tree
# [flaml.automl: 12-06 09:06:30] {3343} INFO -  at 709.7s,	estimator extra_tree's best error=3.1098,	best estimator extra_tree's best error=3.1098
# [flaml.automl: 12-06 09:06:30] {3166} INFO - iteration 151, current learner xgb_limitdepth
# [flaml.automl: 12-06 09:06:34] {3343} INFO -  at 713.1s,	estimator xgb_limitdepth's best error=3.3379,	best estimator extra_tree's best error=3.1098
# [flaml.automl: 12-06 09:06:34] {3166} INFO - iteration 152, current learner xgb_limitdepth
# [flaml.automl: 12-06 09:06:36] {3343} INFO -  at 715.6s,	estimator xgb_limitdepth's best error=3.3379,	best estimator extra_tree's best error=3.1098
# [flaml.automl: 12-06 09:06:36] {3166} INFO - iteration 153, current learner xgb_limitdepth
# [flaml.automl: 12-06 09:06:37] {3343} INFO -  at 716.8s,	estimator xgb_limitdepth's best error=3.3379,	best estimator extra_tree's best error=3.1098
# [flaml.automl: 12-06 09:06:37] {3166} INFO - iteration 154, current learner lgbm
# [flaml.automl: 12-06 09:07:29] {3343} INFO -  at 768.6s,	estimator lgbm's best error=3.3185,	best estimator extra_tree's best error=3.1098
# [flaml.automl: 12-06 09:07:29] {3166} INFO - iteration 155, current learner extra_tree
# [flaml.automl: 12-06 09:07:45] {3343} INFO -  at 784.9s,	estimator extra_tree's best error=3.1098,	best estimator extra_tree's best error=3.1098
# [flaml.automl: 12-06 09:07:45] {3166} INFO - iteration 156, current learner xgb_limitdepth
# [flaml.automl: 12-06 09:07:49] {3343} INFO -  at 788.7s,	estimator xgb_limitdepth's best error=3.3379,	best estimator extra_tree's best error=3.1098
# [flaml.automl: 12-06 09:07:49] {3166} INFO - iteration 157, current learner xgb_limitdepth
# [flaml.automl: 12-06 09:07:51] {3343} INFO -  at 790.2s,	estimator xgb_limitdepth's best error=3.3379,	best estimator extra_tree's best error=3.1098
# [flaml.automl: 12-06 09:07:51] {3166} INFO - iteration 158, current learner extra_tree
# [flaml.automl: 12-06 09:08:38] {3343} INFO -  at 837.0s,	estimator extra_tree's best error=3.1098,	best estimator extra_tree's best error=3.1098
# [flaml.automl: 12-06 09:08:38] {3166} INFO - iteration 159, current learner xgb_limitdepth
# [flaml.automl: 12-06 09:08:46] {3343} INFO -  at 845.0s,	estimator xgb_limitdepth's best error=3.2536,	best estimator extra_tree's best error=3.1098
# [flaml.automl: 12-06 09:08:46] {3166} INFO - iteration 160, current learner xgb_limitdepth
# [flaml.automl: 12-06 09:08:49] {3343} INFO -  at 848.7s,	estimator xgb_limitdepth's best error=3.2536,	best estimator extra_tree's best error=3.1098
# [flaml.automl: 12-06 09:08:49] {3166} INFO - iteration 161, current learner extra_tree
# [flaml.automl: 12-06 09:09:21] {3343} INFO -  at 880.0s,	estimator extra_tree's best error=3.1098,	best estimator extra_tree's best error=3.1098
# [flaml.automl: 12-06 09:09:21] {3166} INFO - iteration 162, current learner xgb_limitdepth
# [flaml.automl: 12-06 09:09:26] {3343} INFO -  at 885.5s,	estimator xgb_limitdepth's best error=3.2536,	best estimator extra_tree's best error=3.1098
# [flaml.automl: 12-06 09:09:26] {3166} INFO - iteration 163, current learner xgb_limitdepth
# [flaml.automl: 12-06 09:09:28] {3343} INFO -  at 886.9s,	estimator xgb_limitdepth's best error=3.2536,	best estimator extra_tree's best error=3.1098
# [flaml.automl: 12-06 09:09:28] {3166} INFO - iteration 164, current learner xgb_limitdepth
# [flaml.automl: 12-06 10:01:16] {3343} INFO -  at 3995.1s,	estimator xgb_limitdepth's best error=3.2353,	best estimator extra_tree's best error=3.1098
# [flaml.automl: 12-06 10:01:16] {3166} INFO - iteration 165, current learner xgboost
# [flaml.automl: 12-06 10:01:21] {3343} INFO -  at 4000.2s,	estimator xgboost's best error=3.1506,	best estimator extra_tree's best error=3.1098
# [flaml.automl: 12-06 10:01:21] {3166} INFO - iteration 166, current learner extra_tree
# [flaml.automl: 12-06 10:01:35] {3343} INFO -  at 4014.8s,	estimator extra_tree's best error=3.1098,	best estimator extra_tree's best error=3.1098
# [flaml.automl: 12-06 10:01:35] {3166} INFO - iteration 167, current learner extra_tree
# [flaml.automl: 12-06 10:02:32] {3343} INFO -  at 4071.9s,	estimator extra_tree's best error=3.1098,	best estimator extra_tree's best error=3.1098
# [flaml.automl: 12-06 10:02:32] {3166} INFO - iteration 168, current learner extra_tree
# [flaml.automl: 12-06 10:02:50] {3343} INFO -  at 4089.3s,	estimator extra_tree's best error=3.1098,	best estimator extra_tree's best error=3.1098
# [flaml.automl: 12-06 10:02:50] {3166} INFO - iteration 169, current learner xgboost
# [flaml.automl: 12-06 10:02:54] {3343} INFO -  at 4093.2s,	estimator xgboost's best error=3.1506,	best estimator extra_tree's best error=3.1098
# [flaml.automl: 12-06 10:02:54] {3166} INFO - iteration 170, current learner lgbm
# [flaml.automl: 12-06 10:03:03] {3343} INFO -  at 4102.8s,	estimator lgbm's best error=3.3185,	best estimator extra_tree's best error=3.1098
# [flaml.automl: 12-06 10:03:03] {3166} INFO - iteration 171, current learner lgbm
# [flaml.automl: 12-06 10:03:29] {3343} INFO -  at 4128.3s,	estimator lgbm's best error=3.3185,	best estimator extra_tree's best error=3.1098
# [flaml.automl: 12-06 10:03:29] {3166} INFO - iteration 172, current learner extra_tree
# [flaml.automl: 12-06 10:03:50] {3343} INFO -  at 4149.2s,	estimator extra_tree's best error=3.1098,	best estimator extra_tree's best error=3.1098
# [flaml.automl: 12-06 10:03:50] {3166} INFO - iteration 173, current learner extra_tree
# [flaml.automl: 12-06 10:04:26] {3343} INFO -  at 4185.0s,	estimator extra_tree's best error=3.1098,	best estimator extra_tree's best error=3.1098
# [flaml.automl: 12-06 10:04:26] {3166} INFO - iteration 174, current learner extra_tree
# [flaml.automl: 12-06 10:04:45] {3343} INFO -  at 4204.1s,	estimator extra_tree's best error=3.1098,	best estimator extra_tree's best error=3.1098
# [flaml.automl: 12-06 10:04:45] {3166} INFO - iteration 175, current learner xgboost
# [flaml.automl: 12-06 10:04:48] {3343} INFO -  at 4207.2s,	estimator xgboost's best error=3.1506,	best estimator extra_tree's best error=3.1098
# [flaml.automl: 12-06 10:04:48] {3166} INFO - iteration 176, current learner extra_tree
# [flaml.automl: 12-06 10:04:58] {3343} INFO -  at 4217.0s,	estimator extra_tree's best error=3.1098,	best estimator extra_tree's best error=3.1098
# [flaml.automl: 12-06 10:04:58] {3166} INFO - iteration 177, current learner extra_tree
# [flaml.automl: 12-06 10:05:20] {3343} INFO -  at 4239.8s,	estimator extra_tree's best error=3.1098,	best estimator extra_tree's best error=3.1098
# [flaml.automl: 12-06 10:05:20] {3166} INFO - iteration 178, current learner xgboost
# [flaml.automl: 12-06 10:05:23] {3343} INFO -  at 4242.7s,	estimator xgboost's best error=3.1506,	best estimator extra_tree's best error=3.1098
# [flaml.automl: 12-06 10:05:23] {3166} INFO - iteration 179, current learner extra_tree
# [flaml.automl: 12-06 10:05:52] {3343} INFO -  at 4271.7s,	estimator extra_tree's best error=3.1098,	best estimator extra_tree's best error=3.1098
# [flaml.automl: 12-06 10:05:52] {3166} INFO - iteration 180, current learner extra_tree
# [flaml.automl: 12-06 10:06:06] {3343} INFO -  at 4285.5s,	estimator extra_tree's best error=3.1098,	best estimator extra_tree's best error=3.1098
# [flaml.automl: 12-06 10:06:06] {3166} INFO - iteration 181, current learner extra_tree
# [flaml.automl: 12-06 10:06:48] {3343} INFO -  at 4327.7s,	estimator extra_tree's best error=3.1098,	best estimator extra_tree's best error=3.1098
# [flaml.automl: 12-06 10:06:48] {3166} INFO - iteration 182, current learner xgboost
# [flaml.automl: 12-06 10:06:54] {3343} INFO -  at 4333.2s,	estimator xgboost's best error=3.1139,	best estimator extra_tree's best error=3.1098
# [flaml.automl: 12-06 10:06:54] {3166} INFO - iteration 183, current learner xgboost
# [flaml.automl: 12-06 10:06:59] {3343} INFO -  at 4338.1s,	estimator xgboost's best error=3.1139,	best estimator extra_tree's best error=3.1098
# [flaml.automl: 12-06 10:06:59] {3166} INFO - iteration 184, current learner xgboost
# [flaml.automl: 12-06 10:07:02] {3343} INFO -  at 4341.6s,	estimator xgboost's best error=3.1139,	best estimator extra_tree's best error=3.1098
# [flaml.automl: 12-06 10:07:02] {3166} INFO - iteration 185, current learner xgboost
# [flaml.automl: 12-06 10:07:09] {3343} INFO -  at 4348.1s,	estimator xgboost's best error=3.1139,	best estimator extra_tree's best error=3.1098
# [flaml.automl: 12-06 10:07:09] {3166} INFO - iteration 186, current learner xgboost
# [flaml.automl: 12-06 10:07:12] {3343} INFO -  at 4351.4s,	estimator xgboost's best error=3.1139,	best estimator extra_tree's best error=3.1098
# [flaml.automl: 12-06 10:07:12] {3166} INFO - iteration 187, current learner xgboost
# [flaml.automl: 12-06 10:07:17] {3343} INFO -  at 4356.2s,	estimator xgboost's best error=3.1139,	best estimator extra_tree's best error=3.1098
# [flaml.automl: 12-06 10:07:17] {3166} INFO - iteration 188, current learner xgboost
# [flaml.automl: 12-06 10:07:23] {3343} INFO -  at 4362.7s,	estimator xgboost's best error=3.1139,	best estimator extra_tree's best error=3.1098
# [flaml.automl: 12-06 10:07:23] {3166} INFO - iteration 189, current learner xgboost
# [flaml.automl: 12-06 10:07:33] {3343} INFO -  at 4372.7s,	estimator xgboost's best error=3.1107,	best estimator extra_tree's best error=3.1098
# [flaml.automl: 12-06 10:07:33] {3166} INFO - iteration 190, current learner xgboost
# [flaml.automl: 12-06 10:07:39] {3343} INFO -  at 4377.9s,	estimator xgboost's best error=3.1107,	best estimator extra_tree's best error=3.1098
# [flaml.automl: 12-06 10:07:39] {3166} INFO - iteration 191, current learner xgboost
# [flaml.automl: 12-06 10:07:57] {3343} INFO -  at 4396.8s,	estimator xgboost's best error=3.0633,	best estimator xgboost's best error=3.0633
	best estimator xgboost's best error=2.9785
# [flaml.automl: 12-06 14:46:35] {3166} INFO - iteration 408, current learner xgb_limitdepth
# [flaml.automl: 12-06 14:47:59] {3343} INFO -  at 21198.5s,	estimator xgb_limitdepth's best error=3.0848,	best estimator xgboost's best error=2.9785
# [flaml.automl: 12-06 14:47:59] {3166} INFO - iteration 409, current learner xgb_limitdepth
# [flaml.automl: 12-06 14:48:25] {3343} INFO -  at 21224.2s,	estimator xgb_limitdepth's best error=3.0848,	best estimator xgboost's best error=2.9785
# [flaml.automl: 12-06 14:48:25] {3166} INFO - iteration 410, current learner xgb_limitdepth
# [flaml.automl: 12-06 14:48:53] {3343} INFO -  at 21252.6s,	estimator xgb_limitdepth's best error=3.0848,	best estimator xgboost's best error=2.9785
# [flaml.automl: 12-06 14:48:53] {3166} INFO - iteration 411, current learner xgboost
# [flaml.automl: 12-06 14:49:34] {3343} INFO -  at 21293.9s,	estimator xgboost's best error=2.9785,	best estimator xgboost's best error=2.9785
# [flaml.automl: 12-06 14:49:34] {3166} INFO - iteration 412, current learner xgboost
# [flaml.automl: 12-06 14:51:04] {3343} INFO -  at 21382.9s,	estimator xgboost's best error=2.9785,	best estimator xgboost's best error=2.9785
# [flaml.automl: 12-06 14:51:04] {3166} INFO - iteration 413, current learner xgboost
# [flaml.automl: 12-06 14:52:40] {3343} INFO -  at 21479.5s,	estimator xgboost's best error=2.9785,	best estimator xgboost's best error=2.9785
# [flaml.automl: 12-06 14:52:40] {3166} INFO - iteration 414, current learner xgb_limitdepth
# [flaml.automl: 12-06 14:53:27] {3343} INFO -  at 21526.1s,	estimator xgb_limitdepth's best error=3.0848,	best estimator xgboost's best error=2.9785
# [flaml.automl: 12-06 14:53:27] {3166} INFO - iteration 415, current learner xgb_limitdepth
# [flaml.automl: 12-06 14:54:20] {3343} INFO -  at 21579.6s,	estimator xgb_limitdepth's best error=3.0848,	best estimator xgboost's best error=2.9785
# [flaml.automl: 12-06 14:54:25] {3602} INFO - retrain xgboost for 4.6s
# [flaml.automl: 12-06 14:54:25] {3609} INFO - retrained model: XGBRegressor(base_score=0.5, booster='gbtree',
#              colsample_bylevel=0.6232756141778749, colsample_bynode=1,
#              colsample_bytree=0.8927954782301247, gamma=0, gpu_id=-1,
#              grow_policy='lossguide', importance_type='gain',
#              interaction_constraints='', learning_rate=0.010589437077728296,
#              max_delta_step=0, max_depth=0, max_leaves=181,
#              min_child_weight=2.879913543825662, missing=nan,
#              monotone_constraints='()', n_estimators=160, n_jobs=-1,
#              num_parallel_tree=1, random_state=0, reg_alpha=11.754449125830133,
#              reg_lambda=0.0034561656266561495, scale_pos_weight=1,
#              subsample=0.6657442649927047, tree_method='hist',
#              use_label_encoder=False, validate_parameters=1, verbosity=0)
# [flaml.automl: 12-06 14:54:25] {2901} INFO - fit succeeded
# [flaml.automl: 12-06 14:54:25] {2902} INFO - Time taken to find the best model: 14137.032247066498
# 0.96 0.8 0.29
# XGBRegressor(base_score=0.5, booster='gbtree',
#              colsample_bylevel=0.6232756141778749, colsample_bynode=1,
#              colsample_bytree=0.8927954782301247, gamma=0, gpu_id=-1,
#              grow_policy='lossguide', importance_type='gain',
#              interaction_constraints='', learning_rate=0.010589437077728296,
#              max_delta_step=0, max_depth=0, max_leaves=181,
#              min_child_weight=2.879913543825662, missing=nan,
#              monotone_constraints='()', n_estimators=160, n_jobs=-1,
#              num_parallel_tree=1, random_state=0, reg_alpha=11.754449125830133,
#              reg_lambda=0.0034561656266561495, scale_pos_weight=1,
#              subsample=0.6657442649927047, tree_method='hist',
#              use_label_encoder=False, validate_parameters=1, verbosity=0)

# %% [markdown]
# from flaml import AutoML
# from sklearn.datasets import fetch_california_housing
#
# # Initialize an AutoML instance
# automl = AutoML()
# # Specify automl goal and constraint
# automl_settings = {
#     "time_budget": 200,  # in seconds
#     "metric": 'rmse',
#     "task": 'regression',
#     "log_file_name": "california.log",
# }
# # Train with labeled input data
# automl.fit(X_train=X_train.drop(['Lab1'], axis=1), y_train=y_train,**automl_settings,estimator_list=["xgboost"])
# pred=automl.predict(X_test.drop(['Lab1'], axis=1))
# R2=round(sm.r2_score(y_test, pred), 2)
# r=round(np.corrcoef(y_test, pred)[0, 1],2)
# RMSE=round(np.sqrt(sm.mean_squared_error(y_test, pred))/np.mean(y),2)
# print(r,R2,RMSE)
# # Predict
# #print(automl.predict(X_test))
# # Print the best model
# print(automl.model.estimator)

# %% [markdown]
# from sklearn.svm import SVR
# from sklearn.model_selection import GridSearchCV
#
# # defining parameter range
# param_grid = {'C': [0.1, 1, 10, 100, 1000],
#               'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#               'kernel':  ['rbf', 'poly', 'sigmoid']}
#
# grid = GridSearchCV(SVR(), param_grid, refit = True, verbose = 3)
#
# # fitting the model for grid search
# grid.fit(X_train.drop(['Lab1'], axis=1), y_train)
#
# # print best parameter after tuning
# print(grid.best_params_)
#
# # print how our model looks after hyper-parameter tuning
# print(grid.best_estimator_)

# %% [markdown]
# # O3 DATA

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error as mae
import sklearn.metrics as sm
import matplotlib.pyplot as plt
#,'Ref_CO','Ref_NO2','Ref_SO2'
X=O3_Data[['Net Signal','Lab1','Temp','RH','Month','Day_of_week','Hour','Ref_NO2']]#,'Ref_NO2'
y=O3_Data['Ref']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)
len(X)
# Out:
# 3534

# %% [markdown]
# from flaml import AutoML
# from sklearn.datasets import fetch_california_housing
#
# # Initialize an AutoML instance
# automl = AutoML()
# # Specify automl goal and constraint
# automl_settings = {
#     "time_budget": 200,  # in seconds
#     "metric": 'rmse',
#     "task": 'regression',
#     "log_file_name": "california.log",
# }
# # Train with labeled input data
# automl.fit(X_train=X_train.drop(['Lab1'], axis=1), y_train=y_train,**automl_settings,estimator_list=["xgboost"])
# pred=automl.predict(X_test.drop(['Lab1'], axis=1))
# R2=round(sm.r2_score(y_test, pred), 2)
# r=round(np.corrcoef(y_test, pred)[0, 1],2)
# RMSE=round(np.sqrt(sm.mean_squared_error(y_test, pred))/np.mean(y),2)
# print(r,R2,RMSE)
# # Predict
# #print(automl.predict(X_test))
# # Print the best model
# print(automl.model.estimator)

# %%
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV
  
# defining parameter range
param_grid = {'C': [0.1, 1, 10, 100, 1000], 
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
              'kernel':  ['rbf', 'poly', 'sigmoid']} 
  
grid = GridSearchCV(SVR(), param_grid, refit = True, verbose = 3)
  
# fitting the model for grid search
grid.fit(X_train.drop(['Lab1'], axis=1), y_train)

# print best parameter after tuning
print(grid.best_params_)
  
# print how our model looks after hyper-parameter tuning
print(grid.best_estimator_)
# Out:
# Fitting 5 folds for each of 75 candidates, totalling 375 fits
# [CV 1/5] END .......C=0.1, gamma=1, kernel=rbf;, score=-0.017 total time=   5.0s
# [CV 2/5] END .......C=0.1, gamma=1, kernel=rbf;, score=-0.007 total time=   5.7s
# [CV 3/5] END .......C=0.1, gamma=1, kernel=rbf;, score=-0.004 total time=   5.2s
# [CV 4/5] END .......C=0.1, gamma=1, kernel=rbf;, score=-0.006 total time=   4.4s
# [CV 5/5] END .......C=0.1, gamma=1, kernel=rbf;, score=-0.008 total time=   4.0s

# %% [markdown]
# # SO2 DATA

# %%
import pandas as pd
Ref=pd.read_csv('Ref.csv')
Ref["CO"] = 1000 * Ref["CO"]
Ref['Date'] = pd.to_datetime(Ref['Date_Time'])
Ref=Ref.set_index('Date')
Ref.drop('Date_Time',axis = 1, inplace = True)
Ref=Ref.resample('5min').mean()
Ref=Ref[76463:137376]
Ref_CO=Ref['CO'].to_list()
Ref_NO2=Ref['NO2'].to_list()
Ref_SO2=Ref['SO2'].to_list()
Ref_O3=Ref['O3'].to_list()

# %%
import pandas as pd
import scipy.io
import numpy as np
data = pd.read_csv('Conc_SO2.txt', header = None,low_memory=False)
data.columns=['Lab2','Temp','RH','Time','Ref']
Time=data['Time'].to_list()
time=[]
for i in range(len(Time)):
    time.append(float(abs(Time[i])))
Time=np.array(time)
Date=pd.to_datetime(Time-719529,unit='d').round('s')
data['Date'] = Date.tolist()
data=data.set_index('Date')
data.drop('Time',axis = 1, inplace = True)
data=data.resample('5min').mean()
Data_SO2=data
Data_so2=data
#signal=np.array(WE)-np.array(AE)
#Data_SO2['Net Signal']=signal
Data_SO2['Month']=Data_SO2.index.month
Data_SO2['Day_of_week']=Data_SO2.index.dayofweek
Data_SO2['Day']=Data_SO2.index.day
Data_SO2['Hour']=Data_SO2.index.hour
SO2_Data=Data_SO2
SO2_Data=SO2_Data.resample('5min').mean()
SO2_Data=SO2_Data[(SO2_Data[SO2_Data.columns] >= 0).all(axis=1)]
SO2_Data=SO2_Data.dropna() 
data = pd.read_csv('SO2.txt', header = None,low_memory=False)
data.columns=['WE','AE','Temp','RH','Time']
Time=data['Time'].to_list()
time=[]
for i in range(len(Time)):
    time.append(float(abs(Time[i])))
Time=np.array(time)
Date=pd.to_datetime(Time-719529,unit='d').round('s')
data['Date'] = Date.tolist()
data=data.set_index('Date')
data.drop('Time',axis = 1, inplace = True)
data=data.resample('5min').mean()
Data_SO2=data
Data_SO2['Ref']=Ref_SO2
WE=Data_SO2['WE'].to_list()
AE=Data_SO2['AE'].to_list()
signal=np.array(WE)-np.array(AE)
Data_SO2['Lab2']=Data_so2['Lab2'].to_list()
Data_SO2['Net Signal']=signal
Data_SO2['Month']=Data_SO2.index.month
Data_SO2['Day_of_week']=Data_SO2.index.dayofweek
Data_SO2['Day']=Data_SO2.index.day
Data_SO2['Hour']=Data_SO2.index.hour
SO2_Data=Data_SO2
SO2_Data.shape

# %%
SO2_Data=SO2_Data[(SO2_Data[SO2_Data.columns] >= 0).all(axis=1)]
SO2_Data=SO2_Data.dropna()
SO2_Data=SO2_Data.resample('h').mean()
SO2_Data=SO2_Data.dropna()
SO2_Data.head()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error as mae
import sklearn.metrics as sm
import matplotlib.pyplot as plt
#'Ref_CO','Ref_NO2','Ref_O3',
X=SO2_Data[['Net Signal','Lab2','Temp','RH','Month','Day_of_week','Hour']]
y=SO2_Data['Ref']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)
len(X)

# %% [markdown]
# from flaml import AutoML
# from sklearn.datasets import fetch_california_housing
#
# # Initialize an AutoML instance
# automl = AutoML()
# # Specify automl goal and constraint
# automl_settings = {
#     "time_budget": 200,  # in seconds
#     "metric": 'rmse',
#     "task": 'regression',
#     "log_file_name": "california.log",
# }
# # Train with labeled input data
# automl.fit(X_train=X_train.drop(['Lab2'], axis=1), y_train=y_train,**automl_settings,estimator_list=["xgboost"])
# pred=automl.predict(X_test.drop(['Lab2'], axis=1))
# R2=round(sm.r2_score(y_test, pred), 2)
# r=round(np.corrcoef(y_test, pred)[0, 1],2)
# RMSE=round(np.sqrt(sm.mean_squared_error(y_test, pred))/np.mean(y),2)
# print(r,R2,RMSE)
# # Predict
# #print(automl.predict(X_test))
# # Print the best model
# print(automl.model.estimator)

# %% [markdown]
# from sklearn.svm import SVR
# from sklearn.model_selection import GridSearchCV
#
# # defining parameter range
# param_grid = {'C': [0.1, 1, 10, 100, 1000],
#               'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#               'kernel':  ['rbf', 'poly', 'sigmoid']}
#
# grid = GridSearchCV(SVR(), param_grid, refit = True, verbose = 3)
#
# # fitting the model for grid search
# grid.fit(X_train.drop(['Lab2'], axis=1), y_train)
#
# # print best parameter after tuning
# print(grid.best_params_)
#
# # print how our model looks after hyper-parameter tuning
# print(grid.best_estimator_)
