# %%
import pandas as pd
from pandas import MultiIndex, Int16Dtype
Ref=pd.read_csv('Ref.csv')
Ref["CO"] = 1000 * Ref["CO"]
Ref['Date'] = pd.to_datetime(Ref['Date_Time'])
Ref=Ref.set_index('Date')
Ref.drop('Date_Time',axis = 1, inplace = True)
Ref=Ref.resample('5min').mean()
Ref=Ref[76463:137376]
Ref_CO=Ref['CO'].to_list()
Ref_NO2=Ref['NO2'].to_list()
Ref_SO2=Ref['SO2'].to_list()
Ref_O3=Ref['O3'].to_list()

# %%
import random
import pandas as pd
import scipy.io
import numpy as np
data = pd.read_csv('CO.txt', header = None,low_memory=False)
data.columns=['WE','AE','Temp','RH','Time']
Time=data['Time'].to_list()
time=[]
for i in range(len(Time)):
    time.append(float(abs(Time[i])))
Time=np.array(time)
Date=pd.to_datetime(Time-719529,unit='d').round('s')
data['Date'] = Date.tolist()
data=data.set_index('Date')
data.drop('Time',axis = 1, inplace = True)
data=data.resample('5min').mean()
Data_CO=data
Data_CO['Ref']=Ref_CO
index_names = Data_CO[ (Data_CO['WE'] >1000)].index
Data_CO.drop(index_names, inplace = True)
WE=Data_CO['WE'].to_list()
AE=Data_CO['AE'].to_list()
signal=np.array(WE)-np.array(AE)
Data_CO['Net Signal']=signal
Data_CO['Month']=Data_CO.index.month
Data_CO['Day_of_week']=Data_CO.index.dayofweek
Data_CO['Day']=Data_CO.index.day
Data_CO['Hour']=Data_CO.index.hour
CO_Data=Data_CO
CO_Data=CO_Data[(CO_Data[CO_Data.columns] >= 0).all(axis=1)]
CO_Data=CO_Data.dropna()
data = pd.read_csv('Conc_CO.txt', header = None,low_memory=False)
data.columns=['Lab1','Temp','RH','Time','Ref']
Time=data['Time'].to_list()
time=[]
for i in range(len(Time)):
    time.append(float(abs(Time[i])))
Time=np.array(time)
Date=pd.to_datetime(Time-719529,unit='d').round('s')
data['Date'] = Date.tolist()
data=data.set_index('Date')
data.drop('Time',axis = 1, inplace = True)
data=data.resample('5min').mean()
Data_CO=data
Data_CO.drop(index_names, inplace = True)
signal=np.array(WE)-np.array(AE)
Data_CO['Net Signal']=signal
Data_CO['Month']=Data_CO.index.month
Data_CO['Day_of_week']=Data_CO.index.dayofweek
Data_CO['Day']=Data_CO.index.day
Data_CO['Hour']=Data_CO.index.hour
CO_Data=Data_CO
CO_Data=CO_Data[(CO_Data[CO_Data.columns] >= 0).all(axis=1)]
CO_Data=CO_Data.dropna()
CO_Data=CO_Data.resample('h').mean()
CO_Data=CO_Data.dropna()
CO_Data.tail()
# Out:
#                            Lab1       Temp         RH         Ref  Net Signal  \
# Date
# 2020-04-30 19:00:00  242.060716  18.870796  71.072939  188.915151   91.471325
# 2020-04-30 20:00:00  218.655079  18.056864  75.132153  178.704750   84.176485
# 2020-04-30 21:00:00  194.147868  17.090891  81.315038  161.421792   73.858294
# 2020-04-30 22:00:00  206.432889  16.714085  82.568155  197.744043   83.279611
# 2020-04-30 23:00:00  173.577429  16.365121  83.662401  162.157636   68.669099
#
#                      Month  Day_of_week   Day  Hour
# Date
# 2020-04-30 19:00:00    4.0          3.0  30.0  19.0
# 2020-04-30 20:00:00    4.0          3.0  30.0  20.0
# 2020-04-30 21:00:00    4.0          3.0  30.0  21.0
# 2020-04-30 22:00:00    4.0          3.0  30.0  22.0
# 2020-04-30 23:00:00    4.0          3.0  30.0  23.0

# %%
import pandas as pd
import scipy.io
import numpy as np
data = pd.read_csv('O3.txt', header = None,low_memory=False)
data.columns=['AE','WE','Temp','RH','Time']
Time=data['Time'].to_list()
time=[]
for i in range(len(Time)):
    time.append(float(abs(Time[i])))
Time=np.array(time)
Date=pd.to_datetime(Time-719529,unit='d').round('s')
data['Date'] = Date.tolist()
data=data.set_index('Date')
data.drop('Time',axis = 1, inplace = True)
data=data.resample('5min').mean()
Data_O3=data
Data_O3['Ref']=Ref_O3
WE=Data_O3['WE'].to_list()
AE=Data_O3['AE'].to_list()
signal=np.array(WE)-np.array(AE)
Data_O3['Net Signal']=signal
Data_O3['Month']=Data_O3.index.month
Data_O3['Day_of_week']=Data_O3.index.dayofweek
Data_O3['Day']=Data_O3.index.day
Data_O3['Hour']=Data_O3.index.hour
O3_Data=Data_O3
O3_Data=O3_Data[(O3_Data[O3_Data.columns] >= 0).all(axis=1)]
O3_Data=O3_Data.dropna()
data = pd.read_csv('Conc_O3.txt', header = None,low_memory=False)
data.columns=['Lab1','Temp','RH','Time','Ref']
Time=data['Time'].to_list()
time=[]
for i in range(len(Time)):
    time.append(float(abs(Time[i])))
Time=np.array(time)
Date=pd.to_datetime(Time-719529,unit='d').round('s')
data['Date'] = Date.tolist()
data=data.set_index('Date')
data.drop('Time',axis = 1, inplace = True)
data=data.resample('5min').mean()
Data_O3=data
signal=np.array(WE)-np.array(AE)
Data_O3['Net Signal']=signal
Data_O3['Month']=Data_O3.index.month
Data_O3['Day_of_week']=Data_O3.index.dayofweek
Data_O3['Day']=Data_O3.index.day
Data_O3['Hour']=Data_O3.index.hour
O3_Data=Data_O3
O3_Data=O3_Data[(O3_Data[O3_Data.columns] >= 0).all(axis=1)]
O3_Data=O3_Data.dropna() 
O3_Data=O3_Data.resample('h').mean()
O3_Data=O3_Data.dropna()
O3_Data.head()

ref_O3=Data_O3['Ref'].to_list()
len(ref_O3)
# Out:
# 60913

# %%
import pandas as pd
import scipy.io
import numpy as np
data = pd.read_csv('NO2.txt', header = None,low_memory=False)
data.columns=['WE','AE','Temp','RH','Time']
Time=data['Time'].to_list()
time=[]
for i in range(len(Time)):
    time.append(float(abs(Time[i])))
Time=np.array(time)
Date=pd.to_datetime(Time-719529,unit='d').round('s')
data['Date'] = Date.tolist()
data=data.set_index('Date')
data.drop('Time',axis = 1, inplace = True)
data=data.resample('5min').mean()
Data_NO2=data
Data_NO2['Ref']=Ref_NO2
WE=Data_NO2['WE'].to_list()
AE=Data_NO2['AE'].to_list()
signal=np.array(WE)-np.array(AE)
Data_NO2['Net Signal']=signal
Data_NO2['Month']=Data_NO2.index.month
Data_NO2['Day_of_week']=Data_NO2.index.dayofweek
Data_NO2['Day']=Data_NO2.index.day
Data_NO2['Hour']=Data_NO2.index.hour
NO2_Data=Data_NO2
NO2_Data=NO2_Data[(NO2_Data[NO2_Data.columns] >= 0).all(axis=1)]
NO2_Data=NO2_Data.dropna()
data = pd.read_csv('Conc_NO2.txt', header = None,low_memory=False)
data.columns=['Lab1','Temp','RH','Time','Ref']
Time=data['Time'].to_list()
time=[]
subscript = str.maketrans("0123456789", "₀₁₂₃₄₅₆₇₈₉") 
for i in range(len(Time)):
    time.append(float(abs(Time[i])))
Time=np.array(time)
Date=pd.to_datetime(Time-719529,unit='d').round('s')
data['Date'] = Date.tolist()
data=data.set_index('Date')
data.drop('Time',axis = 1, inplace = True)
data=data.resample('5min').mean()
Data_NO2=data
signal=np.array(WE)-np.array(AE)
Data_NO2['Net Signal']=signal
Data_NO2['Month']=Data_NO2.index.month
Data_NO2['Day_of_week']=Data_NO2.index.dayofweek
Data_NO2['Day']=Data_NO2.index.day
Data_NO2['Hour']=Data_NO2.index.hour
Data_NO2['Ref_O3']=ref_O3
NO2_Data=Data_NO2
NO2_Data=NO2_Data[(NO2_Data[NO2_Data.columns] >= 0).all(axis=1)]
NO2_Data=NO2_Data.dropna()
NO2_Data=NO2_Data.resample('h').mean()
NO2_Data=NO2_Data.dropna()

# %%
import pandas as pd
import scipy.io
import numpy as np
data = pd.read_csv('O3.txt', header = None,low_memory=False)
data.columns=['AE','WE','Temp','RH','Time']
Time=data['Time'].to_list()
time=[]
for i in range(len(Time)):
    time.append(float(abs(Time[i])))
Time=np.array(time)
Date=pd.to_datetime(Time-719529,unit='d').round('s')
data['Date'] = Date.tolist()
data=data.set_index('Date')
data.drop('Time',axis = 1, inplace = True)
data=data.resample('5min').mean()
Data_O3=data
Data_O3['Ref']=Ref_O3
WE=Data_O3['WE'].to_list()
AE=Data_O3['AE'].to_list()
signal=np.array(WE)-np.array(AE)
Data_O3['Net Signal']=signal
Data_O3['Month']=Data_O3.index.month
Data_O3['Day_of_week']=Data_O3.index.dayofweek
Data_O3['Day']=Data_O3.index.day
Data_O3['Hour']=Data_O3.index.hour
O3_Data=Data_O3
O3_Data=O3_Data[(O3_Data[O3_Data.columns] >= 0).all(axis=1)]
O3_Data=O3_Data.dropna()
data = pd.read_csv('Conc_O3.txt', header = None,low_memory=False)
data.columns=['Lab1','Temp','RH','Time','Ref']
Time=data['Time'].to_list()
time=[]
for i in range(len(Time)):
    time.append(float(abs(Time[i])))
Time=np.array(time)
Date=pd.to_datetime(Time-719529,unit='d').round('s')
data['Date'] = Date.tolist()
data=data.set_index('Date')
data.drop('Time',axis = 1, inplace = True)
data=data.resample('5min').mean()
Data_O3=data
signal=np.array(WE)-np.array(AE)
Data_O3['Net Signal']=signal
Data_O3['Month']=Data_O3.index.month
Data_O3['Day_of_week']=Data_O3.index.dayofweek
Data_O3['Day']=Data_O3.index.day
Data_O3['Hour']=Data_O3.index.hour
ref_NO2=Data_NO2['Ref'].to_list()
Data_O3['Ref_NO2']=ref_NO2
O3_Data=Data_O3
O3_Data=O3_Data[(O3_Data[O3_Data.columns] >= 0).all(axis=1)]
O3_Data=O3_Data.dropna()
O3_Data=O3_Data.resample('h').mean()
O3_Data=O3_Data.dropna()
O3_Data.head()
# Out:
#                            Lab1       Temp         RH        Ref  Net Signal  \
# Date
# 2019-10-02 11:00:00  621.625704  26.378438  58.063437  46.094860    3.605625
# 2019-10-02 12:00:00  725.154408  25.795055  48.256857  57.532808   13.865109
# 2019-10-07 10:00:00  108.196313  32.344264  37.260757  47.259008   11.447809
# 2019-10-07 11:00:00  135.822676  34.926112  35.013036  42.114260   10.075221
# 2019-10-07 12:00:00  203.757758  36.201221  31.829282  45.701366    7.624153
#
#                      Month  Day_of_week  Day  Hour    Ref_NO2
# Date
# 2019-10-02 11:00:00   10.0          2.0  2.0  11.0  15.230400
# 2019-10-02 12:00:00   10.0          2.0  2.0  12.0   5.384051
# 2019-10-07 10:00:00   10.0          0.0  7.0  10.0   4.255772
# 2019-10-07 11:00:00   10.0          0.0  7.0  11.0  16.268034
# 2019-10-07 12:00:00   10.0          0.0  7.0  12.0  12.770444

# %% [markdown]
# # CO DATA

# %%
from sktime.performance_metrics.forecasting import sMAPE, smape_loss
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error as mae
import sklearn.metrics as sm
import matplotlib.pyplot as plt
from flaml import AutoML
from sklearn.datasets import fetch_california_housing
#'Ref_NO2','Ref_SO2','Ref_O3',
#,'Month','Day_of_week','Day','Hour'
X=CO_Data[['Net Signal','Lab1','Temp','RH','Month','Day_of_week','Hour']]
y=CO_Data['Ref']
X_train, X_test, y_train, y_test =train_test_split(X,y,test_size = 0.2,shuffle=True)
#train_test_split(X, y, test_size = 0.2)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/xgboost/compat.py:93: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %%
# Initialize an AutoML instance
automl = AutoML()
# Specify automl goal and constraint
automl_settings = {
    "time_budget":1440,  # in seconds
    "metric": 'rmse',
    "task": 'regression',
    "log_file_name": "california.log",
}

Pred=[]
rmse=[]
model=[]
RS=[]
R=[]
for i in range(10):
    X_Train, X_Test, y_Train, y_Test =train_test_split(X_train,y_train,test_size = 0.2,shuffle=True)
    # Train with labeled input data
    automl.fit(X_train=X_Train.drop(['Lab1'], axis=1), y_train=y_Train,**automl_settings,estimator_list=["rf"])
    pred=automl.predict(X_test.drop(['Lab1'], axis=1))
    R2=round(sm.r2_score(y_test, pred), 2)
    r=round(np.corrcoef(y_test, pred)[0, 1],2)
    RMSE=round(np.sqrt(sm.mean_squared_error(y_test, pred))/np.mean(y),5)
    #print(r,R2,RMSE)
    # Predict
    #print(automl.predict(X_test))
    # Print the best model
    #print(automl.model.estimator)
    Pred.append(pred)
    rmse.append(RMSE)
    model.append(automl.model.estimator)
    RS.append(R2)
    R.append(r)

print(np.round(np.mean(R),2),np.round(np.mean(RS),2),np.round(np.mean(rmse),2))
# Out:
# [flaml.automl: 12-15 00:35:05] {2599} INFO - task = regression
# [flaml.automl: 12-15 00:35:05] {2601} INFO - Data split method: uniform
# [flaml.automl: 12-15 00:35:05] {2604} INFO - Evaluation method: cv
# [flaml.automl: 12-15 00:35:05] {2726} INFO - Minimizing error metric: rmse
# [flaml.automl: 12-15 00:35:06] {2870} INFO - List of ML learners in AutoML Run: ['rf']
# [flaml.automl: 12-15 00:35:06] {3166} INFO - iteration 0, current learner rf
# [flaml.automl: 12-15 00:35:06] {3296} INFO - Estimated sufficient time budget=8126s. Estimated necessary time budget=8s.
# [flaml.automl: 12-15 00:35:06] {3343} INFO -  at 1.0s,	estimator rf's best error=163.0386,	best estimator rf's best error=163.0386
# [flaml.automl: 12-15 00:35:06] {3166} INFO - iteration 1, current learner rf
# [flaml.automl: 12-15 00:35:07] {3343} INFO -  at 1.5s,	estimator rf's best error=147.8430,	best estimator rf's best error=147.8430
# [flaml.automl: 12-15 00:35:07] {3166} INFO - iteration 2, current learner rf
# [flaml.automl: 12-15 00:35:08] {3343} INFO -  at 2.2s,	estimator rf's best error=147.8430,	best estimator rf's best error=147.8430
# [flaml.automl: 12-15 00:35:08] {3166} INFO - iteration 3, current learner rf
# [flaml.automl: 12-15 00:35:09] {3343} INFO -  at 3.3s,	estimator rf's best error=138.2535,	best estimator rf's best error=138.2535
# [flaml.automl: 12-15 00:35:09] {3166} INFO - iteration 4, current learner rf
# [flaml.automl: 12-15 00:35:09] {3343} INFO -  at 4.1s,	estimator rf's best error=133.8124,	best estimator rf's best error=133.8124
# [flaml.automl: 12-15 00:35:09] {3166} INFO - iteration 5, current learner rf
# [flaml.automl: 12-15 00:35:10] {3343} INFO -  at 5.0s,	estimator rf's best error=133.8124,	best estimator rf's best error=133.8124
# [flaml.automl: 12-15 00:35:10] {3166} INFO - iteration 6, current learner rf
# [flaml.automl: 12-15 00:35:11] {3343} INFO -  at 5.8s,	estimator rf's best error=130.5778,	best estimator rf's best error=130.5778
# [flaml.automl: 12-15 00:35:11] {3166} INFO - iteration 7, current learner rf
# [flaml.automl: 12-15 00:35:12] {3343} INFO -  at 6.5s,	estimator rf's best error=130.5778,	best estimator rf's best error=130.5778
# [flaml.automl: 12-15 00:35:12] {3166} INFO - iteration 8, current learner rf
# [flaml.automl: 12-15 00:35:13] {3343} INFO -  at 7.5s,	estimator rf's best error=128.1149,	best estimator rf's best error=128.1149
# [flaml.automl: 12-15 00:35:13] {3166} INFO - iteration 9, current learner rf
# [flaml.automl: 12-15 00:35:14] {3343} INFO -  at 8.4s,	estimator rf's best error=128.1149,	best estimator rf's best error=128.1149
# [flaml.automl: 12-15 00:35:14] {3166} INFO - iteration 10, current learner rf
# [flaml.automl: 12-15 00:35:14] {3343} INFO -  at 9.2s,	estimator rf's best error=128.1149,	best estimator rf's best error=128.1149
# [flaml.automl: 12-15 00:35:14] {3166} INFO - iteration 11, current learner rf
# [flaml.automl: 12-15 00:35:16] {3343} INFO -  at 10.7s,	estimator rf's best error=123.6045,	best estimator rf's best error=123.6045
# [flaml.automl: 12-15 00:35:16] {3166} INFO - iteration 12, current learner rf
# [flaml.automl: 12-15 00:35:17] {3343} INFO -  at 11.7s,	estimator rf's best error=123.6045,	best estimator rf's best error=123.6045
# [flaml.automl: 12-15 00:35:17] {3166} INFO - iteration 13, current learner rf
# [flaml.automl: 12-15 00:35:20] {3343} INFO -  at 14.7s,	estimator rf's best error=123.6045,	best estimator rf's best error=123.6045
# [flaml.automl: 12-15 00:35:20] {3166} INFO - iteration 14, current learner rf
# [flaml.automl: 12-15 00:35:22] {3343} INFO -  at 16.3s,	estimator rf's best error=123.6045,	best estimator rf's best error=123.6045
# [flaml.automl: 12-15 00:35:22] {3166} INFO - iteration 15, current learner rf
# [flaml.automl: 12-15 00:35:24] {3343} INFO -  at 18.8s,	estimator rf's best error=120.4261,	best estimator rf's best error=120.4261
# [flaml.automl: 12-15 00:35:24] {3166} INFO - iteration 16, current learner rf
# [flaml.automl: 12-15 00:35:25] {3343} INFO -  at 19.9s,	estimator rf's best error=120.4261,	best estimator rf's best error=120.4261
# [flaml.automl: 12-15 00:35:25] {3166} INFO - iteration 17, current learner rf
# [flaml.automl: 12-15 00:35:32] {3343} INFO -  at 26.8s,	estimator rf's best error=120.4261,	best estimator rf's best error=120.4261
# [flaml.automl: 12-15 00:35:32] {3166} INFO - iteration 18, current learner rf
# [flaml.automl: 12-15 00:35:38] {3343} INFO -  at 32.3s,	estimator rf's best error=120.4261,	best estimator rf's best error=120.4261
# [flaml.automl: 12-15 00:35:38] {3166} INFO - iteration 19, current learner rf
# [flaml.automl: 12-15 00:35:40] {3343} INFO -  at 34.5s,	estimator rf's best error=120.4261,	best estimator rf's best error=120.4261
# [flaml.automl: 12-15 00:35:40] {3166} INFO - iteration 20, current learner rf
# [flaml.automl: 12-15 00:35:46] {3343} INFO -  at 40.2s,	estimator rf's best error=120.4261,	best estimator rf's best error=120.4261
# [flaml.automl: 12-15 00:35:46] {3166} INFO - iteration 21, current learner rf
# [flaml.automl: 12-15 00:35:47] {3343} INFO -  at 42.0s,	estimator rf's best error=120.4261,	best estimator rf's best error=120.4261
# [flaml.automl: 12-15 00:35:47] {3166} INFO - iteration 22, current learner rf
# [flaml.automl: 12-15 00:35:49] {3343} INFO -  at 43.6s,	estimator rf's best error=120.4261,	best estimator rf's best error=120.4261
# [flaml.automl: 12-15 00:35:49] {3166} INFO - iteration 23, current learner rf
# [flaml.automl: 12-15 00:35:57] {3343} INFO -  at 51.7s,	estimator rf's best error=120.4261,	best estimator rf's best error=120.4261
# [flaml.automl: 12-15 00:35:57] {3166} INFO - iteration 24, current learner rf
# [flaml.automl: 12-15 00:36:01] {3343} INFO -  at 55.8s,	estimator rf's best error=120.4261,	best estimator rf's best error=120.4261
# [flaml.automl: 12-15 00:36:01] {3166} INFO - iteration 25, current learner rf
# [flaml.automl: 12-15 00:36:04] {3343} INFO -  at 59.1s,	estimator rf's best error=120.4261,	best estimator rf's best error=120.4261
# [flaml.automl: 12-15 00:36:04] {3166} INFO - iteration 26, current learner rf
# [flaml.automl: 12-15 00:36:12] {3343} INFO -  at 66.7s,	estimator rf's best error=120.4261,	best estimator rf's best error=120.4261
# [flaml.automl: 12-15 00:36:12] {3166} INFO - iteration 27, current learner rf
# [flaml.automl: 12-15 00:36:14] {3343} INFO -  at 69.0s,	estimator rf's best error=120.4261,	best estimator rf's best error=120.4261
# [flaml.automl: 12-15 00:36:14] {3166} INFO - iteration 28, current learner rf
# [flaml.automl: 12-15 00:36:19] {3343} INFO -  at 73.9s,	estimator rf's best error=120.4261,	best estimator rf's best error=120.4261
# [flaml.automl: 12-15 00:36:19] {3166} INFO - iteration 29, current learner rf
# [flaml.automl: 12-15 00:36:23] {3343} INFO -  at 77.6s,	estimator rf's best error=120.4261,	best estimator rf's best error=120.4261
# [flaml.automl: 12-15 00:36:23] {3166} INFO - iteration 30, current learner rf
# [flaml.automl: 12-15 00:36:26] {3343} INFO -  at 80.7s,	estimator rf's best error=120.4261,	best estimator rf's best error=120.4261
# [flaml.automl: 12-15 00:36:26] {3166} INFO - iteration 31, current learner rf
# [flaml.automl: 12-15 00:36:32] {3343} INFO -  at 87.0s,	estimator rf's best error=119.7368,	best estimator rf's best error=119.7368
# [flaml.automl: 12-15 00:36:32] {3166} INFO - iteration 32, current learner rf
# [flaml.automl: 12-15 00:36:39] {3343} INFO -  at 94.1s,	estimator rf's best error=119.7368,	best estimator rf's best error=119.7368
# [flaml.automl: 12-15 00:36:39] {3166} INFO - iteration 33, current learner rf
# [flaml.automl: 12-15 00:36:44] {3343} INFO -  at 99.1s,	estimator rf's best error=119.7368,	best estimator rf's best error=119.7368
# [flaml.automl: 12-15 00:36:44] {3166} INFO - iteration 34, current learner rf
# [flaml.automl: 12-15 00:36:58] {3343} INFO -  at 112.3s,	estimator rf's best error=119.7368,	best estimator rf's best error=119.7368
# [flaml.automl: 12-15 00:36:58] {3166} INFO - iteration 35, current learner rf
# [flaml.automl: 12-15 00:37:01] {3343} INFO -  at 115.4s,	estimator rf's best error=119.7368,	best estimator rf's best error=119.7368
# [flaml.automl: 12-15 00:37:01] {3166} INFO - iteration 36, current learner rf
# [flaml.automl: 12-15 00:37:05] {3343} INFO -  at 119.8s,	estimator rf's best error=119.7368,	best estimator rf's best error=119.7368
# [flaml.automl: 12-15 00:37:05] {3166} INFO - iteration 37, current learner rf
# [flaml.automl: 12-15 00:37:17] {3343} INFO -  at 132.0s,	estimator rf's best error=119.7368,	best estimator rf's best error=119.7368
# [flaml.automl: 12-15 00:37:17] {3166} INFO - iteration 38, current learner rf
# [flaml.automl: 12-15 00:37:28] {3343} INFO -  at 142.9s,	estimator rf's best error=119.7368,	best estimator rf's best error=119.7368
# [flaml.automl: 12-15 00:37:28] {3166} INFO - iteration 39, current learner rf
# [flaml.automl: 12-15 00:37:32] {3343} INFO -  at 146.4s,	estimator rf's best error=119.7368,	best estimator rf's best error=119.7368
# [flaml.automl: 12-15 00:37:32] {3166} INFO - iteration 40, current learner rf
# [flaml.automl: 12-15 00:37:41] {3343} INFO -  at 156.1s,	estimator rf's best error=119.7368,	best estimator rf's best error=119.7368
# [flaml.automl: 12-15 00:37:41] {3166} INFO - iteration 41, current learner rf
# [flaml.automl: 12-15 00:37:45] {3343} INFO -  at 160.0s,	estimator rf's best error=119.7368,	best estimator rf's best error=119.7368
# [flaml.automl: 12-15 00:37:45] {3166} INFO - iteration 42, current learner rf
# [flaml.automl: 12-15 00:37:50] {3343} INFO -  at 164.7s,	estimator rf's best error=119.7368,	best estimator rf's best error=119.7368
# [flaml.automl: 12-15 00:37:50] {3166} INFO - iteration 43, current learner rf
# [flaml.automl: 12-15 00:37:57] {3343} INFO -  at 171.7s,	estimator rf's best error=119.7368,	best estimator rf's best error=119.7368
# [flaml.automl: 12-15 00:37:57] {3166} INFO - iteration 44, current learner rf
# [flaml.automl: 12-15 00:38:02] {3343} INFO -  at 176.9s,	estimator rf's best error=119.7368,	best estimator rf's best error=119.7368
# [flaml.automl: 12-15 00:38:02] {3166} INFO - iteration 45, current learner rf
# [flaml.automl: 12-15 00:38:09] {3343} INFO -  at 183.8s,	estimator rf's best error=119.7368,	best estimator rf's best error=119.7368
# [flaml.automl: 12-15 00:38:09] {3166} INFO - iteration 46, current learner rf
# [flaml.automl: 12-15 00:38:19] {3343} INFO -  at 193.9s,	estimator rf's best error=119.7368,	best estimator rf's best error=119.7368
# [flaml.automl: 12-15 00:38:19] {3166} INFO - iteration 47, current learner rf
# [flaml.automl: 12-15 00:38:22] {3343} INFO -  at 197.1s,	estimator rf's best error=119.7368,	best estimator rf's best error=119.7368
# [flaml.automl: 12-15 00:38:22] {3166} INFO - iteration 48, current learner rf
# [flaml.automl: 12-15 00:38:25] {3343} INFO -  at 199.8s,	estimator rf's best error=119.7368,	best estimator rf's best error=119.7368
# [flaml.automl: 12-15 00:38:25] {3166} INFO - iteration 49, current learner rf
# [flaml.automl: 12-15 00:38:36] {3343} INFO -  at 210.4s,	estimator rf's best error=119.7368,	best estimator rf's best error=119.7368
# [flaml.automl: 12-15 00:38:36] {3166} INFO - iteration 50, current learner rf
# [flaml.automl: 12-15 00:38:46] {3343} INFO -  at 220.3s,	estimator rf's best error=119.7368,	best estimator rf's best error=119.7368
# [flaml.automl: 12-15 00:38:46] {3166} INFO - iteration 51, current learner rf
# [flaml.automl: 12-15 00:38:49] {3343} INFO -  at 223.4s,	estimator rf's best error=119.7368,	best estimator rf's best error=119.7368
# [flaml.automl: 12-15 00:38:49] {3166} INFO - iteration 52, current learner rf
# [flaml.automl: 12-15 00:38:57] {3343} INFO -  at 231.7s,	estimator rf's best error=119.7368,	best estimator rf's best error=119.7368
# [flaml.automl: 12-15 00:38:57] {3166} INFO - iteration 53, current learner rf
# [flaml.automl: 12-15 00:39:01] {3343} INFO -  at 235.9s,	estimator rf's best error=119.7368,	best estimator rf's best error=119.7368
# [flaml.automl: 12-15 00:39:01] {3166} INFO - iteration 54, current learner rf
# [flaml.automl: 12-15 00:39:06] {3343} INFO -  at 240.3s,	estimator rf's best error=119.7368,	best estimator rf's best error=119.7368
# [flaml.automl: 12-15 00:39:06] {3166} INFO - iteration 55, current learner rf
# [flaml.automl: 12-15 00:39:14] {3343} INFO -  at 248.7s,	estimator rf's best error=119.7368,	best estimator rf's best error=119.7368
# [flaml.automl: 12-15 00:39:14] {3166} INFO - iteration 56, current learner rf
# [flaml.automl: 12-15 00:39:23] {3343} INFO -  at 257.7s,	estimator rf's best error=119.7368,	best estimator rf's best error=119.7368
# [flaml.automl: 12-15 00:39:23] {3166} INFO - iteration 57, current learner rf
# [flaml.automl: 12-15 00:39:27] {3343} INFO -  at 261.4s,	estimator rf's best error=119.7368,	best estimator rf's best error=119.7368
# [flaml.automl: 12-15 00:39:27] {3166} INFO - iteration 58, current learner rf
# [flaml.automl: 12-15 00:39:35] {3343} INFO -  at 269.3s,	estimator rf's best error=119.6135,	best estimator rf's best error=119.6135
# [flaml.automl: 12-15 00:39:35] {3166} INFO - iteration 59, current learner rf
# [flaml.automl: 12-15 00:39:41] {3343} INFO -  at 275.2s,	estimator rf's best error=119.6135,	best estimator rf's best error=119.6135
# [flaml.automl: 12-15 00:39:41] {3166} INFO - iteration 60, current learner rf
# [flaml.automl: 12-15 00:39:47] {3343} INFO -  at 281.5s,	estimator rf's best error=119.6135,	best estimator rf's best error=119.6135
# [flaml.automl: 12-15 00:39:47] {3166} INFO - iteration 61, current learner rf
# [flaml.automl: 12-15 00:39:56] {3343} INFO -  at 290.8s,	estimator rf's best error=119.6135,	best estimator rf's best error=119.6135
# [flaml.automl: 12-15 00:39:56] {3166} INFO - iteration 62, current learner rf
# [flaml.automl: 12-15 00:40:11] {3343} INFO -  at 305.5s,	estimator rf's best error=119.6135,	best estimator rf's best error=119.6135
# [flaml.automl: 12-15 00:40:11] {3166} INFO - iteration 63, current learner rf
# [flaml.automl: 12-15 00:40:15] {3343} INFO -  at 309.5s,	estimator rf's best error=119.6135,	best estimator rf's best error=119.6135
# [flaml.automl: 12-15 00:40:15] {3166} INFO - iteration 64, current learner rf
# [flaml.automl: 12-15 00:40:22] {3343} INFO -  at 316.3s,	estimator rf's best error=119.6135,	best estimator rf's best error=119.6135
# [flaml.automl: 12-15 00:40:22] {3166} INFO - iteration 65, current learner rf
# [flaml.automl: 12-15 00:40:31] {3343} INFO -  at 325.4s,	estimator rf's best error=119.3808,	best estimator rf's best error=119.3808
# [flaml.automl: 12-15 00:40:31] {3166} INFO - iteration 66, current learner rf
# [flaml.automl: 12-15 00:40:38] {3343} INFO -  at 332.6s,	estimator rf's best error=119.3808,	best estimator rf's best error=119.3808
# [flaml.automl: 12-15 00:40:38] {3166} INFO - iteration 67, current learner rf
# [flaml.automl: 12-15 00:40:50] {3343} INFO -  at 345.0s,	estimator rf's best error=119.3808,	best estimator rf's best error=119.3808
# [flaml.automl: 12-15 00:40:50] {3166} INFO - iteration 68, current learner rf
# [flaml.automl: 12-15 00:40:57] {3343} INFO -  at 351.9s,	estimator rf's best error=119.3808,	best estimator rf's best error=119.3808
# [flaml.automl: 12-15 00:40:57] {3166} INFO - iteration 69, current learner rf
# [flaml.automl: 12-15 00:41:09] {3343} INFO -  at 363.9s,	estimator rf's best error=119.3808,	best estimator rf's best error=119.3808
# [flaml.automl: 12-15 00:41:09] {3166} INFO - iteration 70, current learner rf
# [flaml.automl: 12-15 00:41:22] {3343} INFO -  at 376.6s,	estimator rf's best error=119.3808,	best estimator rf's best error=119.3808
# [flaml.automl: 12-15 00:41:22] {3166} INFO - iteration 71, current learner rf
# [flaml.automl: 12-15 00:41:28] {3343} INFO -  at 382.5s,	estimator rf's best error=119.3808,	best estimator rf's best error=119.3808
# [flaml.automl: 12-15 00:41:28] {3166} INFO - iteration 72, current learner rf
# [flaml.automl: 12-15 00:41:33] {3343} INFO -  at 387.6s,	estimator rf's best error=119.3808,	best estimator rf's best error=119.3808
# [flaml.automl: 12-15 00:41:33] {3166} INFO - iteration 73, current learner rf
# [flaml.automl: 12-15 00:41:49] {3343} INFO -  at 403.4s,	estimator rf's best error=119.3808,	best estimator rf's best error=119.3808
# [flaml.automl: 12-15 00:41:49] {3166} INFO - iteration 74, current learner rf
# [flaml.automl: 12-15 00:41:58] {3343} INFO -  at 413.0s,	estimator rf's best error=119.3808,	best estimator rf's best error=119.3808
# [flaml.automl: 12-15 00:41:58] {3166} INFO - iteration 75, current learner rf
# [flaml.automl: 12-15 00:42:07] {3343} INFO -  at 421.6s,	estimator rf's best error=119.3808,	best estimator rf's best error=119.3808
# [flaml.automl: 12-15 00:42:07] {3166} INFO - iteration 76, current learner rf
# [flaml.automl: 12-15 00:42:14] {3343} INFO -  at 428.2s,	estimator rf's best error=119.3808,	best estimator rf's best error=119.3808
# [flaml.automl: 12-15 00:42:14] {3166} INFO - iteration 77, current learner rf
# [flaml.automl: 12-15 00:42:23] {3343} INFO -  at 438.1s,	estimator rf's best error=119.3808,	best estimator rf's best error=119.3808
# [flaml.automl: 12-15 00:42:23] {3166} INFO - iteration 78, current learner rf
# [flaml.automl: 12-15 00:42:30] {3343} INFO -  at 444.9s,	estimator rf's best error=119.3808,	best estimator rf's best error=119.3808
# [flaml.automl: 12-15 00:42:30] {3166} INFO - iteration 79, current learner rf
# [flaml.automl: 12-15 00:42:41] {3343} INFO -  at 456.1s,	estimator rf's best error=119.1689,	best estimator rf's best error=119.1689
# [flaml.automl: 12-15 00:42:41] {3166} INFO - iteration 80, current learner rf
# [flaml.automl: 12-15 00:42:50] {3343} INFO -  at 464.2s,	estimator rf's best error=119.1689,	best estimator rf's best error=119.1689
# [flaml.automl: 12-15 00:42:50] {3166} INFO - iteration 81, current learner rf
# [flaml.automl: 12-15 00:43:06] {3343} INFO -  at 480.2s,	estimator rf's best error=119.1689,	best estimator rf's best error=119.1689
# [flaml.automl: 12-15 00:43:06] {3166} INFO - iteration 82, current learner rf
# [flaml.automl: 12-15 00:43:16] {3343} INFO -  at 490.7s,	estimator rf's best error=119.1689,	best estimator rf's best error=119.1689
# [flaml.automl: 12-15 00:43:16] {3166} INFO - iteration 83, current learner rf
# [flaml.automl: 12-15 00:43:27] {3343} INFO -  at 501.8s,	estimator rf's best error=119.1689,	best estimator rf's best error=119.1689
# [flaml.automl: 12-15 00:43:27] {3166} INFO - iteration 84, current learner rf
# [flaml.automl: 12-15 00:43:33] {3343} INFO -  at 507.4s,	estimator rf's best error=119.1689,	best estimator rf's best error=119.1689
# [flaml.automl: 12-15 00:43:33] {3166} INFO - iteration 85, current learner rf
# [flaml.automl: 12-15 00:43:53] {3343} INFO -  at 527.3s,	estimator rf's best error=119.1689,	best estimator rf's best error=119.1689
# [flaml.automl: 12-15 00:43:53] {3166} INFO - iteration 86, current learner rf
# [flaml.automl: 12-15 00:44:09] {3343} INFO -  at 543.3s,	estimator rf's best error=119.1689,	best estimator rf's best error=119.1689
# [flaml.automl: 12-15 00:44:09] {3166} INFO - iteration 87, current learner rf
# [flaml.automl: 12-15 00:44:16] {3343} INFO -  at 551.0s,	estimator rf's best error=119.1689,	best estimator rf's best error=119.1689
# [flaml.automl: 12-15 00:44:16] {3166} INFO - iteration 88, current learner rf
# [flaml.automl: 12-15 00:44:24] {3343} INFO -  at 558.7s,	estimator rf's best error=119.1689,	best estimator rf's best error=119.1689
# [flaml.automl: 12-15 00:44:24] {3166} INFO - iteration 89, current learner rf
# [flaml.automl: 12-15 00:44:40] {3343} INFO -  at 575.0s,	estimator rf's best error=119.1689,	best estimator rf's best error=119.1689
# [flaml.automl: 12-15 00:44:40] {3166} INFO - iteration 90, current learner rf
# [flaml.automl: 12-15 00:44:52] {3343} INFO -  at 586.8s,	estimator rf's best error=119.1689,	best estimator rf's best error=119.1689
# [flaml.automl: 12-15 00:44:52] {3166} INFO - iteration 91, current learner rf
# [flaml.automl: 12-15 00:45:03] {3343} INFO -  at 597.2s,	estimator rf's best error=119.1689,	best estimator rf's best error=119.1689
# [flaml.automl: 12-15 00:45:03] {3166} INFO - iteration 92, current learner rf
# [flaml.automl: 12-15 00:45:14] {3343} INFO -  at 608.5s,	estimator rf's best error=119.1689,	best estimator rf's best error=119.1689
# [flaml.automl: 12-15 00:45:14] {3166} INFO - iteration 93, current learner rf
# [flaml.automl: 12-15 00:45:41] {3343} INFO -  at 636.0s,	estimator rf's best error=119.1689,	best estimator rf's best error=119.1689
# [flaml.automl: 12-15 00:45:41] {3166} INFO - iteration 94, current learner rf
# [flaml.automl: 12-15 00:46:01] {3343} INFO -  at 655.7s,	estimator rf's best error=119.1689,	best estimator rf's best error=119.1689
# [flaml.automl: 12-15 00:46:01] {3166} INFO - iteration 95, current learner rf
# [flaml.automl: 12-15 00:46:24] {3343} INFO -  at 678.8s,	estimator rf's best error=119.1689,	best estimator rf's best error=119.1689
# [flaml.automl: 12-15 00:46:24] {3166} INFO - iteration 96, current learner rf
# [flaml.automl: 12-15 00:46:54] {3343} INFO -  at 709.1s,	estimator rf's best error=118.8760,	best estimator rf's best error=118.8760
# [flaml.automl: 12-15 00:46:54] {3166} INFO - iteration 97, current learner rf
# [flaml.automl: 12-15 00:47:15] {3343} INFO -  at 729.8s,	estimator rf's best error=118.8760,	best estimator rf's best error=118.8760
# [flaml.automl: 12-15 00:47:15] {3166} INFO - iteration 98, current learner rf
# [flaml.automl: 12-15 00:47:35] {3343} INFO -  at 749.4s,	estimator rf's best error=118.8760,	best estimator rf's best error=118.8760
# [flaml.automl: 12-15 00:47:35] {3166} INFO - iteration 99, current learner rf
# [flaml.automl: 12-15 00:48:19] {3343} INFO -  at 793.8s,	estimator rf's best error=118.8760,	best estimator rf's best error=118.8760
# [flaml.automl: 12-15 00:48:19] {3166} INFO - iteration 100, current learner rf
# [flaml.automl: 12-15 00:48:42] {3343} INFO -  at 816.8s,	estimator rf's best error=118.8760,	best estimator rf's best error=118.8760
# [flaml.automl: 12-15 00:48:42] {3166} INFO - iteration 101, current learner rf
# [flaml.automl: 12-15 00:49:18] {3343} INFO -  at 852.5s,	estimator rf's best error=118.8760,	best estimator rf's best error=118.8760
# [flaml.automl: 12-15 00:49:18] {3166} INFO - iteration 102, current learner rf
# [flaml.automl: 12-15 00:50:07] {3343} INFO -  at 902.1s,	estimator rf's best error=118.8760,	best estimator rf's best error=118.8760
# [flaml.automl: 12-15 00:50:07] {3166} INFO - iteration 103, current learner rf
# [flaml.automl: 12-15 00:50:24] {3343} INFO -  at 918.8s,	estimator rf's best error=118.8760,	best estimator rf's best error=118.8760
# [flaml.automl: 12-15 00:50:24] {3166} INFO - iteration 104, current learner rf
# [flaml.automl: 12-15 00:51:06] {3343} INFO -  at 960.7s,	estimator rf's best error=118.8760,	best estimator rf's best error=118.8760
# [flaml.automl: 12-15 00:51:06] {3166} INFO - iteration 105, current learner rf
# [flaml.automl: 12-15 00:51:27] {3343} INFO -  at 981.6s,	estimator rf's best error=118.8760,	best estimator rf's best error=118.8760
# [flaml.automl: 12-15 00:51:27] {3166} INFO - iteration 106, current learner rf
# [flaml.automl: 12-15 00:51:45] {3343} INFO -  at 999.5s,	estimator rf's best error=118.8760,	best estimator rf's best error=118.8760
# [flaml.automl: 12-15 00:51:45] {3166} INFO - iteration 107, current learner rf
# [flaml.automl: 12-15 00:52:29] {3343} INFO -  at 1043.4s,	estimator rf's best error=118.8760,	best estimator rf's best error=118.8760
# [flaml.automl: 12-15 00:52:29] {3166} INFO - iteration 108, current learner rf
# [flaml.automl: 12-15 00:52:55] {3343} INFO -  at 1069.4s,	estimator rf's best error=118.8760,	best estimator rf's best error=118.8760
# [flaml.automl: 12-15 00:52:55] {3166} INFO - iteration 109, current learner rf
# [flaml.automl: 12-15 00:53:27] {3343} INFO -  at 1101.6s,	estimator rf's best error=118.8760,	best estimator rf's best error=118.8760
# [flaml.automl: 12-15 00:53:27] {3166} INFO - iteration 110, current learner rf
# [flaml.automl: 12-15 00:53:49] {3343} INFO -  at 1123.7s,	estimator rf's best error=118.8760,	best estimator rf's best error=118.8760
# [flaml.automl: 12-15 00:53:49] {3166} INFO - iteration 111, current learner rf
# [flaml.automl: 12-15 00:54:22] {3343} INFO -  at 1156.9s,	estimator rf's best error=118.8760,	best estimator rf's best error=118.8760
# [flaml.automl: 12-15 00:54:22] {3166} INFO - iteration 112, current learner rf
# [flaml.automl: 12-15 00:54:59] {3343} INFO -  at 1193.8s,	estimator rf's best error=118.8760,	best estimator rf's best error=118.8760
# [flaml.automl: 12-15 00:54:59] {3166} INFO - iteration 113, current learner rf
# [flaml.automl: 12-15 00:55:19] {3343} INFO -  at 1213.4s,	estimator rf's best error=118.8760,	best estimator rf's best error=118.8760
# [flaml.automl: 12-15 00:55:19] {3166} INFO - iteration 114, current learner rf
# [flaml.automl: 12-15 00:55:50] {3343} INFO -  at 1245.0s,	estimator rf's best error=118.8760,	best estimator rf's best error=118.8760
# [flaml.automl: 12-15 00:55:50] {3166} INFO - iteration 115, current learner rf
# [flaml.automl: 12-15 00:56:16] {3343} INFO -  at 1271.0s,	estimator rf's best error=118.8760,	best estimator rf's best error=118.8760
# [flaml.automl: 12-15 00:56:16] {3166} INFO - iteration 116, current learner rf
# [flaml.automl: 12-15 00:56:35] {3343} INFO -  at 1289.5s,	estimator rf's best error=118.8760,	best estimator rf's best error=118.8760
# [flaml.automl: 12-15 00:56:35] {3166} INFO - iteration 117, current learner rf
# [flaml.automl: 12-15 00:57:18] {3343} INFO -  at 1332.5s,	estimator rf's best error=118.8760,	best estimator rf's best error=118.8760
# [flaml.automl: 12-15 00:57:18] {3166} INFO - iteration 118, current learner rf
# [flaml.automl: 12-15 00:57:36] {3343} INFO -  at 1350.7s,	estimator rf's best error=118.8760,	best estimator rf's best error=118.8760
# [flaml.automl: 12-15 00:57:36] {3166} INFO - iteration 119, current learner rf
# [flaml.automl: 12-15 00:58:25] {3343} INFO -  at 1399.6s,	estimator rf's best error=118.8760,	best estimator rf's best error=118.8760
# [flaml.automl: 12-15 00:58:25] {3166} INFO - iteration 120, current learner rf
# [flaml.automl: 12-15 00:58:31] {3343} INFO -  at 1405.5s,	estimator rf's best error=118.8760,	best estimator rf's best error=118.8760
# [flaml.automl: 12-15 00:58:31] {3166} INFO - iteration 121, current learner rf
# [flaml.automl: 12-15 00:59:14] {3343} INFO -  at 1448.6s,	estimator rf's best error=118.8760,	best estimator rf's best error=118.8760
# [flaml.automl: 12-15 00:59:22] {3602} INFO - retrain rf for 7.9s
# [flaml.automl: 12-15 00:59:22] {3609} INFO - retrained model: RandomForestRegressor(max_features=0.5630167408040062, max_leaf_nodes=1235,
#                       n_estimators=204, n_jobs=-1)
# [flaml.automl: 12-15 00:59:22] {2901} INFO - fit succeeded
# [flaml.automl: 12-15 00:59:22] {2902} INFO - Time taken to find the best model: 709.0817050933838
# [flaml.automl: 12-15 00:59:22] {2599} INFO - task = regression
# [flaml.automl: 12-15 00:59:22] {2601} INFO - Data split method: uniform
# [flaml.automl: 12-15 00:59:22] {2604} INFO - Evaluation method: cv
# [flaml.automl: 12-15 00:59:23] {2726} INFO - Minimizing error metric: rmse
# [flaml.automl: 12-15 00:59:23] {2870} INFO - List of ML learners in AutoML Run: ['rf']
# [flaml.automl: 12-15 00:59:23] {3166} INFO - iteration 0, current learner rf
# [flaml.automl: 12-15 00:59:24] {3296} INFO - Estimated sufficient time budget=14135s. Estimated necessary time budget=14s.
# [flaml.automl: 12-15 00:59:24] {3343} INFO -  at 1.7s,	estimator rf's best error=164.2726,	best estimator rf's best error=164.2726
# [flaml.automl: 12-15 00:59:24] {3166} INFO - iteration 1, current learner rf
# [flaml.automl: 12-15 00:59:26] {3343} INFO -  at 3.3s,	estimator rf's best error=148.4002,	best estimator rf's best error=148.4002
# [flaml.automl: 12-15 00:59:26] {3166} INFO - iteration 2, current learner rf
# [flaml.automl: 12-15 00:59:27] {3343} INFO -  at 4.6s,	estimator rf's best error=148.4002,	best estimator rf's best error=148.4002
# [flaml.automl: 12-15 00:59:27] {3166} INFO - iteration 3, current learner rf
# [flaml.automl: 12-15 00:59:28] {3343} INFO -  at 6.2s,	estimator rf's best error=141.0155,	best estimator rf's best error=141.0155
# [flaml.automl: 12-15 00:59:28] {3166} INFO - iteration 4, current learner rf
# [flaml.automl: 12-15 00:59:31] {3343} INFO -  at 8.3s,	estimator rf's best error=137.6368,	best estimator rf's best error=137.6368
# [flaml.automl: 12-15 00:59:31] {3166} INFO - iteration 5, current learner rf
# [flaml.automl: 12-15 00:59:33] {3343} INFO -  at 10.4s,	estimator rf's best error=137.6368,	best estimator rf's best error=137.6368
# [flaml.automl: 12-15 00:59:33] {3166} INFO - iteration 6, current learner rf
# [flaml.automl: 12-15 00:59:34] {3343} INFO -  at 12.0s,	estimator rf's best error=137.6368,	best estimator rf's best error=137.6368
# [flaml.automl: 12-15 00:59:34] {3166} INFO - iteration 7, current learner rf
# [flaml.automl: 12-15 00:59:36] {3343} INFO -  at 13.9s,	estimator rf's best error=137.6368,	best estimator rf's best error=137.6368
# [flaml.automl: 12-15 00:59:36] {3166} INFO - iteration 8, current learner rf
# [flaml.automl: 12-15 00:59:39] {3343} INFO -  at 16.7s,	estimator rf's best error=131.7728,	best estimator rf's best error=131.7728
# [flaml.automl: 12-15 00:59:39] {3166} INFO - iteration 9, current learner rf
# [flaml.automl: 12-15 00:59:41] {3343} INFO -  at 18.4s,	estimator rf's best error=131.7728,	best estimator rf's best error=131.7728
# [flaml.automl: 12-15 00:59:41] {3166} INFO - iteration 10, current learner rf
# [flaml.automl: 12-15 00:59:42] {3343} INFO -  at 19.9s,	estimator rf's best error=131.7728,	best estimator rf's best error=131.7728
# [flaml.automl: 12-15 00:59:42] {3166} INFO - iteration 11, current learner rf
# [flaml.automl: 12-15 00:59:46] {3343} INFO -  at 24.2s,	estimator rf's best error=131.7728,	best estimator rf's best error=131.7728
# [flaml.automl: 12-15 00:59:46] {3166} INFO - iteration 12, current learner rf
# [flaml.automl: 12-15 00:59:48] {3343} INFO -  at 26.2s,	estimator rf's best error=131.7728,	best estimator rf's best error=131.7728
# [flaml.automl: 12-15 00:59:48] {3166} INFO - iteration 13, current learner rf
# [flaml.automl: 12-15 00:59:53] {3343} INFO -  at 30.3s,	estimator rf's best error=128.5433,	best estimator rf's best error=128.5433
# [flaml.automl: 12-15 00:59:53] {3166} INFO - iteration 14, current learner rf
# [flaml.automl: 12-15 00:59:56] {3343} INFO -  at 33.5s,	estimator rf's best error=128.5433,	best estimator rf's best error=128.5433
# [flaml.automl: 12-15 00:59:56] {3166} INFO - iteration 15, current learner rf
# [flaml.automl: 12-15 01:00:04] {3343} INFO -  at 41.8s,	estimator rf's best error=127.1395,	best estimator rf's best error=127.1395
# [flaml.automl: 12-15 01:00:04] {3166} INFO - iteration 16, current learner rf
# [flaml.automl: 12-15 01:00:08] {3343} INFO -  at 45.4s,	estimator rf's best error=127.1395,	best estimator rf's best error=127.1395
# [flaml.automl: 12-15 01:00:08] {3166} INFO - iteration 17, current learner rf
# [flaml.automl: 12-15 01:00:28] {3343} INFO -  at 65.3s,	estimator rf's best error=126.2884,	best estimator rf's best error=126.2884
# [flaml.automl: 12-15 01:00:28] {3166} INFO - iteration 18, current learner rf
# [flaml.automl: 12-15 01:01:15] {3343} INFO -  at 112.4s,	estimator rf's best error=123.8258,	best estimator rf's best error=123.8258
# [flaml.automl: 12-15 01:01:15] {3166} INFO - iteration 19, current learner rf
# [flaml.automl: 12-15 01:01:36] {3343} INFO -  at 133.4s,	estimator rf's best error=123.8258,	best estimator rf's best error=123.8258
# [flaml.automl: 12-15 01:01:36] {3166} INFO - iteration 20, current learner rf
# [flaml.automl: 12-15 01:03:06] {3343} INFO -  at 223.8s,	estimator rf's best error=123.8258,	best estimator rf's best error=123.8258
# [flaml.automl: 12-15 01:03:06] {3166} INFO - iteration 21, current learner rf
# [flaml.automl: 12-15 01:03:26] {3343} INFO -  at 243.5s,	estimator rf's best error=123.8258,	best estimator rf's best error=123.8258
# [flaml.automl: 12-15 01:03:26] {3166} INFO - iteration 22, current learner rf
# [flaml.automl: 12-15 01:03:46] {3343} INFO -  at 264.3s,	estimator rf's best error=123.8258,	best estimator rf's best error=123.8258
# [flaml.automl: 12-15 01:03:46] {3166} INFO - iteration 23, current learner rf
# [flaml.automl: 12-15 01:05:21] {3343} INFO -  at 358.8s,	estimator rf's best error=123.8258,	best estimator rf's best error=123.8258
# [flaml.automl: 12-15 01:05:21] {3166} INFO - iteration 24, current learner rf
# [flaml.automl: 12-15 01:06:17] {3343} INFO -  at 415.2s,	estimator rf's best error=123.8258,	best estimator rf's best error=123.8258
# [flaml.automl: 12-15 01:06:17] {3166} INFO - iteration 25, current learner rf
# [flaml.automl: 12-15 01:06:55] {3343} INFO -  at 452.7s,	estimator rf's best error=123.8258,	best estimator rf's best error=123.8258
# [flaml.automl: 12-15 01:06:55] {3166} INFO - iteration 26, current learner rf
# [flaml.automl: 12-15 01:08:25] {3343} INFO -  at 543.1s,	estimator rf's best error=123.8258,	best estimator rf's best error=123.8258
# [flaml.automl: 12-15 01:08:25] {3166} INFO - iteration 27, current learner rf
# [flaml.automl: 12-15 01:08:46] {3343} INFO -  at 564.1s,	estimator rf's best error=123.8258,	best estimator rf's best error=123.8258
# [flaml.automl: 12-15 01:08:46] {3166} INFO - iteration 28, current learner rf
# [flaml.automl: 12-15 01:09:30] {3343} INFO -  at 608.0s,	estimator rf's best error=123.8258,	best estimator rf's best error=123.8258
# [flaml.automl: 12-15 01:09:30] {3166} INFO - iteration 29, current learner rf
# [flaml.automl: 12-15 01:10:13] {3343} INFO -  at 650.3s,	estimator rf's best error=123.8258,	best estimator rf's best error=123.8258
# [flaml.automl: 12-15 01:10:13] {3166} INFO - iteration 30, current learner rf
# [flaml.automl: 12-15 01:10:40] {3343} INFO -  at 677.6s,	estimator rf's best error=123.8258,	best estimator rf's best error=123.8258
# [flaml.automl: 12-15 01:10:40] {3166} INFO - iteration 31, current learner rf
# [flaml.automl: 12-15 01:11:50] {3343} INFO -  at 747.6s,	estimator rf's best error=123.8258,	best estimator rf's best error=123.8258
# [flaml.automl: 12-15 01:11:50] {3166} INFO - iteration 32, current learner rf
# [flaml.automl: 12-15 01:12:37] {3343} INFO -  at 794.4s,	estimator rf's best error=123.8258,	best estimator rf's best error=123.8258
# [flaml.automl: 12-15 01:12:37] {3166} INFO - iteration 33, current learner rf
# [flaml.automl: 12-15 01:13:15] {3343} INFO -  at 832.9s,	estimator rf's best error=123.8258,	best estimator rf's best error=123.8258
# [flaml.automl: 12-15 01:13:15] {3166} INFO - iteration 34, current learner rf
# [flaml.automl: 12-15 01:14:47] {3343} INFO -  at 924.8s,	estimator rf's best error=123.8258,	best estimator rf's best error=123.8258
# [flaml.automl: 12-15 01:14:47] {3166} INFO - iteration 35, current learner rf
# [flaml.automl: 12-15 01:15:07] {3343} INFO -  at 944.4s,	estimator rf's best error=123.8258,	best estimator rf's best error=123.8258
# [flaml.automl: 12-15 01:15:07] {3166} INFO - iteration 36, current learner rf
# [flaml.automl: 12-15 01:15:32] {3343} INFO -  at 969.8s,	estimator rf's best error=123.8258,	best estimator rf's best error=123.8258
# [flaml.automl: 12-15 01:15:32] {3166} INFO - iteration 37, current learner rf
# [flaml.automl: 12-15 01:16:48] {3343} INFO -  at 1045.5s,	estimator rf's best error=123.8258,	best estimator rf's best error=123.8258
# [flaml.automl: 12-15 01:16:48] {3166} INFO - iteration 38, current learner rf
# [flaml.automl: 12-15 01:18:03] {3343} INFO -  at 1120.9s,	estimator rf's best error=123.7779,	best estimator rf's best error=123.7779
# [flaml.automl: 12-15 01:18:03] {3166} INFO - iteration 39, current learner rf
# [flaml.automl: 12-15 01:18:45] {3343} INFO -  at 1163.0s,	estimator rf's best error=123.7640,	best estimator rf's best error=123.7640
# [flaml.automl: 12-15 01:18:45] {3166} INFO - iteration 40, current learner rf
# [flaml.automl: 12-15 01:19:55] {3343} INFO -  at 1232.4s,	estimator rf's best error=123.7640,	best estimator rf's best error=123.7640
# [flaml.automl: 12-15 01:19:55] {3166} INFO - iteration 41, current learner rf
# [flaml.automl: 12-15 01:20:22] {3343} INFO -  at 1260.2s,	estimator rf's best error=123.7640,	best estimator rf's best error=123.7640
# [flaml.automl: 12-15 01:20:22] {3166} INFO - iteration 42, current learner rf
# [flaml.automl: 12-15 01:20:58] {3343} INFO -  at 1295.4s,	estimator rf's best error=123.7640,	best estimator rf's best error=123.7640
# [flaml.automl: 12-15 01:20:58] {3166} INFO - iteration 43, current learner rf
# [flaml.automl: 12-15 01:21:32] {3343} INFO -  at 1330.1s,	estimator rf's best error=123.7640,	best estimator rf's best error=123.7640
# [flaml.automl: 12-15 01:21:32] {3166} INFO - iteration 44, current learner rf
# [flaml.automl: 12-15 01:22:06] {3343} INFO -  at 1364.0s,	estimator rf's best error=123.6211,	best estimator rf's best error=123.6211
# [flaml.automl: 12-15 01:22:06] {3166} INFO - iteration 45, current learner rf
# [flaml.automl: 12-15 01:22:26] {3343} INFO -  at 1383.7s,	estimator rf's best error=123.6211,	best estimator rf's best error=123.6211
# [flaml.automl: 12-15 01:22:26] {3166} INFO - iteration 46, current learner rf
# [flaml.automl: 12-15 01:22:41] {3343} INFO -  at 1399.2s,	estimator rf's best error=123.6211,	best estimator rf's best error=123.6211
# [flaml.automl: 12-15 01:22:41] {3166} INFO - iteration 47, current learner rf
# [flaml.automl: 12-15 01:22:53] {3343} INFO -  at 1411.0s,	estimator rf's best error=123.6211,	best estimator rf's best error=123.6211
# [flaml.automl: 12-15 01:23:01] {3602} INFO - retrain rf for 7.4s
# [flaml.automl: 12-15 01:23:01] {3609} INFO - retrained model: RandomForestRegressor(max_features=0.5630521425929172, max_leaf_nodes=939,
#                       n_estimators=238, n_jobs=-1)
# [flaml.automl: 12-15 01:23:01] {2901} INFO - fit succeeded
# [flaml.automl: 12-15 01:23:01] {2902} INFO - Time taken to find the best model: 1363.9757199287415
# [flaml.automl: 12-15 01:23:01] {2913} WARNING - Time taken to find the best model is 95% of the provided time budget and not all estimators' hyperparameter search converged. Consider increasing the time budget.
# [flaml.automl: 12-15 01:23:01] {2599} INFO - task = regression
# [flaml.automl: 12-15 01:23:01] {2601} INFO - Data split method: uniform
# [flaml.automl: 12-15 01:23:01] {2604} INFO - Evaluation method: cv
# [flaml.automl: 12-15 01:23:01] {2726} INFO - Minimizing error metric: rmse
# [flaml.automl: 12-15 01:23:01] {2870} INFO - List of ML learners in AutoML Run: ['rf']
# [flaml.automl: 12-15 01:23:01] {3166} INFO - iteration 0, current learner rf
# [flaml.automl: 12-15 01:23:02] {3296} INFO - Estimated sufficient time budget=12299s. Estimated necessary time budget=12s.
# [flaml.automl: 12-15 01:23:02] {3343} INFO -  at 1.5s,	estimator rf's best error=161.1581,	best estimator rf's best error=161.1581
# [flaml.automl: 12-15 01:23:02] {3166} INFO - iteration 1, current learner rf
# [flaml.automl: 12-15 01:23:04] {3343} INFO -  at 2.9s,	estimator rf's best error=146.9517,	best estimator rf's best error=146.9517
# [flaml.automl: 12-15 01:23:04] {3166} INFO - iteration 2, current learner rf
# [flaml.automl: 12-15 01:23:06] {3343} INFO -  at 4.6s,	estimator rf's best error=146.9517,	best estimator rf's best error=146.9517
# [flaml.automl: 12-15 01:23:06] {3166} INFO - iteration 3, current learner rf
# [flaml.automl: 12-15 01:23:08] {3343} INFO -  at 6.6s,	estimator rf's best error=134.1750,	best estimator rf's best error=134.1750
# [flaml.automl: 12-15 01:23:08] {3166} INFO - iteration 4, current learner rf
# [flaml.automl: 12-15 01:23:10] {3343} INFO -  at 9.1s,	estimator rf's best error=131.5313,	best estimator rf's best error=131.5313
# [flaml.automl: 12-15 01:23:10] {3166} INFO - iteration 5, current learner rf
# [flaml.automl: 12-15 01:23:12] {3343} INFO -  at 11.0s,	estimator rf's best error=131.5313,	best estimator rf's best error=131.5313
# [flaml.automl: 12-15 01:23:12] {3166} INFO - iteration 6, current learner rf
# [flaml.automl: 12-15 01:23:14] {3343} INFO -  at 12.7s,	estimator rf's best error=130.7720,	best estimator rf's best error=130.7720
# [flaml.automl: 12-15 01:23:14] {3166} INFO - iteration 7, current learner rf
# [flaml.automl: 12-15 01:23:16] {3343} INFO -  at 14.7s,	estimator rf's best error=130.0140,	best estimator rf's best error=130.0140
# [flaml.automl: 12-15 01:23:16] {3166} INFO - iteration 8, current learner rf
# [flaml.automl: 12-15 01:23:18] {3343} INFO -  at 17.4s,	estimator rf's best error=123.7082,	best estimator rf's best error=123.7082
# [flaml.automl: 12-15 01:23:18] {3166} INFO - iteration 9, current learner rf
# [flaml.automl: 12-15 01:23:20] {3343} INFO -  at 19.5s,	estimator rf's best error=123.7082,	best estimator rf's best error=123.7082
# [flaml.automl: 12-15 01:23:20] {3166} INFO - iteration 10, current learner rf
# [flaml.automl: 12-15 01:23:25] {3343} INFO -  at 23.8s,	estimator rf's best error=123.7082,	best estimator rf's best error=123.7082
# [flaml.automl: 12-15 01:23:25] {3166} INFO - iteration 11, current learner rf
# [flaml.automl: 12-15 01:23:26] {3343} INFO -  at 25.4s,	estimator rf's best error=123.7082,	best estimator rf's best error=123.7082
# [flaml.automl: 12-15 01:23:26] {3166} INFO - iteration 12, current learner rf
# [flaml.automl: 12-15 01:23:31] {3343} INFO -  at 29.7s,	estimator rf's best error=119.8639,	best estimator rf's best error=119.8639
# [flaml.automl: 12-15 01:23:31] {3166} INFO - iteration 13, current learner rf
# [flaml.automl: 12-15 01:23:33] {3343} INFO -  at 32.1s,	estimator rf's best error=119.8639,	best estimator rf's best error=119.8639
# [flaml.automl: 12-15 01:23:33] {3166} INFO - iteration 14, current learner rf
# [flaml.automl: 12-15 01:23:42] {3343} INFO -  at 40.8s,	estimator rf's best error=119.8639,	best estimator rf's best error=119.8639
# [flaml.automl: 12-15 01:23:42] {3166} INFO - iteration 15, current learner rf
# [flaml.automl: 12-15 01:23:44] {3343} INFO -  at 43.4s,	estimator rf's best error=119.8639,	best estimator rf's best error=119.8639
# [flaml.automl: 12-15 01:23:44] {3166} INFO - iteration 16, current learner rf
# [flaml.automl: 12-15 01:23:55] {3343} INFO -  at 53.7s,	estimator rf's best error=119.8639,	best estimator rf's best error=119.8639
# [flaml.automl: 12-15 01:23:55] {3166} INFO - iteration 17, current learner rf
# [flaml.automl: 12-15 01:24:03] {3343} INFO -  at 62.5s,	estimator rf's best error=118.2957,	best estimator rf's best error=118.2957
# [flaml.automl: 12-15 01:24:03] {3166} INFO - iteration 18, current learner rf
# [flaml.automl: 12-15 01:24:08] {3343} INFO -  at 66.8s,	estimator rf's best error=118.2957,	best estimator rf's best error=118.2957
# [flaml.automl: 12-15 01:24:08] {3166} INFO - iteration 19, current learner rf
# [flaml.automl: 12-15 01:24:27] {3343} INFO -  at 86.4s,	estimator rf's best error=118.2957,	best estimator rf's best error=118.2957
# [flaml.automl: 12-15 01:24:27] {3166} INFO - iteration 20, current learner rf
# [flaml.automl: 12-15 01:24:31] {3343} INFO -  at 89.9s,	estimator rf's best error=118.2957,	best estimator rf's best error=118.2957
# [flaml.automl: 12-15 01:24:31] {3166} INFO - iteration 21, current learner rf
# [flaml.automl: 12-15 01:24:35] {3343} INFO -  at 94.0s,	estimator rf's best error=118.2957,	best estimator rf's best error=118.2957
# [flaml.automl: 12-15 01:24:35] {3166} INFO - iteration 22, current learner rf
# [flaml.automl: 12-15 01:24:56] {3343} INFO -  at 114.8s,	estimator rf's best error=117.7627,	best estimator rf's best error=117.7627
# [flaml.automl: 12-15 01:24:56] {3166} INFO - iteration 23, current learner rf
# [flaml.automl: 12-15 01:25:19] {3343} INFO -  at 138.1s,	estimator rf's best error=117.7627,	best estimator rf's best error=117.7627
# [flaml.automl: 12-15 01:25:19] {3166} INFO - iteration 24, current learner rf
# [flaml.automl: 12-15 01:25:37] {3343} INFO -  at 156.5s,	estimator rf's best error=117.7627,	best estimator rf's best error=117.7627
# [flaml.automl: 12-15 01:25:37] {3166} INFO - iteration 25, current learner rf
# [flaml.automl: 12-15 01:26:21] {3343} INFO -  at 200.1s,	estimator rf's best error=117.7627,	best estimator rf's best error=117.7627
# [flaml.automl: 12-15 01:26:21] {3166} INFO - iteration 26, current learner rf
# [flaml.automl: 12-15 01:26:32] {3343} INFO -  at 211.4s,	estimator rf's best error=117.7627,	best estimator rf's best error=117.7627
# [flaml.automl: 12-15 01:26:32] {3166} INFO - iteration 27, current learner rf
# [flaml.automl: 12-15 01:26:51] {3343} INFO -  at 230.2s,	estimator rf's best error=117.7627,	best estimator rf's best error=117.7627
# [flaml.automl: 12-15 01:26:51] {3166} INFO - iteration 28, current learner rf
# [flaml.automl: 12-15 01:27:13] {3343} INFO -  at 252.1s,	estimator rf's best error=117.7627,	best estimator rf's best error=117.7627
# [flaml.automl: 12-15 01:27:13] {3166} INFO - iteration 29, current learner rf
# [flaml.automl: 12-15 01:27:23] {3343} INFO -  at 262.3s,	estimator rf's best error=117.7627,	best estimator rf's best error=117.7627
# [flaml.automl: 12-15 01:27:23] {3166} INFO - iteration 30, current learner rf
# [flaml.automl: 12-15 01:28:02] {3343} INFO -  at 300.9s,	estimator rf's best error=117.2534,	best estimator rf's best error=117.2534
# [flaml.automl: 12-15 01:28:02] {3166} INFO - iteration 31, current learner rf
# [flaml.automl: 12-15 01:28:51] {3343} INFO -  at 349.9s,	estimator rf's best error=117.2534,	best estimator rf's best error=117.2534
# [flaml.automl: 12-15 01:28:51] {3166} INFO - iteration 32, current learner rf
# [flaml.automl: 12-15 01:29:25] {3343} INFO -  at 384.3s,	estimator rf's best error=117.2534,	best estimator rf's best error=117.2534
# [flaml.automl: 12-15 01:29:25] {3166} INFO - iteration 33, current learner rf
# [flaml.automl: 12-15 01:31:21] {3343} INFO -  at 500.5s,	estimator rf's best error=117.2534,	best estimator rf's best error=117.2534
# [flaml.automl: 12-15 01:31:21] {3166} INFO - iteration 34, current learner rf
# [flaml.automl: 12-15 01:31:35] {3343} INFO -  at 514.2s,	estimator rf's best error=117.2534,	best estimator rf's best error=117.2534
# [flaml.automl: 12-15 01:31:35] {3166} INFO - iteration 35, current learner rf
# [flaml.automl: 12-15 01:31:50] {3343} INFO -  at 528.7s,	estimator rf's best error=117.2534,	best estimator rf's best error=117.2534
# [flaml.automl: 12-15 01:31:50] {3166} INFO - iteration 36, current learner rf
# [flaml.automl: 12-15 01:33:27] {3343} INFO -  at 625.8s,	estimator rf's best error=117.2534,	best estimator rf's best error=117.2534
# [flaml.automl: 12-15 01:33:27] {3166} INFO - iteration 37, current learner rf
# [flaml.automl: 12-15 01:35:00] {3343} INFO -  at 719.4s,	estimator rf's best error=116.1244,	best estimator rf's best error=116.1244
# [flaml.automl: 12-15 01:35:00] {3166} INFO - iteration 38, current learner rf
# [flaml.automl: 12-15 01:35:41] {3343} INFO -  at 759.8s,	estimator rf's best error=116.1244,	best estimator rf's best error=116.1244
# [flaml.automl: 12-15 01:35:41] {3166} INFO - iteration 39, current learner rf
# [flaml.automl: 12-15 01:39:09] {3343} INFO -  at 968.1s,	estimator rf's best error=116.1244,	best estimator rf's best error=116.1244
# [flaml.automl: 12-15 01:39:09] {3166} INFO - iteration 40, current learner rf
# [flaml.automl: 12-15 01:39:56] {3343} INFO -  at 1014.7s,	estimator rf's best error=116.1244,	best estimator rf's best error=116.1244
# [flaml.automl: 12-15 01:39:56] {3166} INFO - iteration 41, current learner rf
# [flaml.automl: 12-15 01:40:46] {3343} INFO -  at 1065.1s,	estimator rf's best error=116.1244,	best estimator rf's best error=116.1244
# [flaml.automl: 12-15 01:40:46] {3166} INFO - iteration 42, current learner rf
# [flaml.automl: 12-15 01:41:36] {3343} INFO -  at 1115.2s,	estimator rf's best error=116.1244,	best estimator rf's best error=116.1244
# [flaml.automl: 12-15 01:41:36] {3166} INFO - iteration 43, current learner rf
# [flaml.automl: 12-15 01:42:33] {3343} INFO -  at 1171.9s,	estimator rf's best error=116.1244,	best estimator rf's best error=116.1244
# [flaml.automl: 12-15 01:42:33] {3166} INFO - iteration 44, current learner rf
# [flaml.automl: 12-15 01:44:47] {3343} INFO -  at 1305.9s,	estimator rf's best error=116.1244,	best estimator rf's best error=116.1244
# [flaml.automl: 12-15 01:44:47] {3166} INFO - iteration 45, current learner rf
# [flaml.automl: 12-15 01:47:05] {3343} INFO -  at 1444.1s,	estimator rf's best error=116.1244,	best estimator rf's best error=116.1244
# ...
# [flaml.automl: 12-15 04:09:23] {3343} INFO -  at 19.4s,	estimator rf's best error=128.4864,	best estimator rf's best error=128.4864
# [flaml.automl: 12-15 04:09:23] {3166} INFO - iteration 10, current learner rf
# [flaml.automl: 12-15 04:09:24] {3343} INFO -  at 21.1s,	estimator rf's best error=128.4864,	best estimator rf's best error=128.4864
# [flaml.automl: 12-15 04:09:24] {3166} INFO - iteration 11, current learner rf
# [flaml.automl: 12-15 04:09:29] {3343} INFO -  at 26.3s,	estimator rf's best error=128.4864,	best estimator rf's best error=128.4864
# [flaml.automl: 12-15 04:09:29] {3166} INFO - iteration 12, current learner rf
# [flaml.automl: 12-15 04:09:31] {3343} INFO -  at 28.1s,	estimator rf's best error=128.4864,	best estimator rf's best error=128.4864
# [flaml.automl: 12-15 04:09:31] {3166} INFO - iteration 13, current learner rf
# [flaml.automl: 12-15 04:09:37] {3343} INFO -  at 33.6s,	estimator rf's best error=125.0131,	best estimator rf's best error=125.0131
# [flaml.automl: 12-15 04:09:37] {3166} INFO - iteration 14, current learner rf
# [flaml.automl: 12-15 04:09:41] {3343} INFO -  at 37.7s,	estimator rf's best error=125.0131,	best estimator rf's best error=125.0131
# [flaml.automl: 12-15 04:09:41] {3166} INFO - iteration 15, current learner rf
# [flaml.automl: 12-15 04:09:50] {3343} INFO -  at 46.4s,	estimator rf's best error=122.4600,	best estimator rf's best error=122.4600
# [flaml.automl: 12-15 04:09:50] {3166} INFO - iteration 16, current learner rf
# [flaml.automl: 12-15 04:09:53] {3343} INFO -  at 49.6s,	estimator rf's best error=122.4600,	best estimator rf's best error=122.4600
# [flaml.automl: 12-15 04:09:53] {3166} INFO - iteration 17, current learner rf
# [flaml.automl: 12-15 04:10:15] {3343} INFO -  at 71.5s,	estimator rf's best error=122.4600,	best estimator rf's best error=122.4600
# [flaml.automl: 12-15 04:10:15] {3166} INFO - iteration 18, current learner rf
# [flaml.automl: 12-15 04:10:35] {3343} INFO -  at 91.9s,	estimator rf's best error=120.6673,	best estimator rf's best error=120.6673
# [flaml.automl: 12-15 04:10:35] {3166} INFO - iteration 19, current learner rf
# [flaml.automl: 12-15 04:10:44] {3343} INFO -  at 101.0s,	estimator rf's best error=120.6673,	best estimator rf's best error=120.6673
# [flaml.automl: 12-15 04:10:44] {3166} INFO - iteration 20, current learner rf
# [flaml.automl: 12-15 04:11:26] {3343} INFO -  at 143.0s,	estimator rf's best error=120.6673,	best estimator rf's best error=120.6673
# [flaml.automl: 12-15 04:11:26] {3166} INFO - iteration 21, current learner rf
# [flaml.automl: 12-15 04:11:37] {3343} INFO -  at 153.3s,	estimator rf's best error=120.6673,	best estimator rf's best error=120.6673
# [flaml.automl: 12-15 04:11:37] {3166} INFO - iteration 22, current learner rf
# [flaml.automl: 12-15 04:11:46] {3343} INFO -  at 162.9s,	estimator rf's best error=120.6673,	best estimator rf's best error=120.6673
# [flaml.automl: 12-15 04:11:46] {3166} INFO - iteration 23, current learner rf
# [flaml.automl: 12-15 04:12:32] {3343} INFO -  at 209.2s,	estimator rf's best error=120.6673,	best estimator rf's best error=120.6673
# [flaml.automl: 12-15 04:12:32] {3166} INFO - iteration 24, current learner rf
# [flaml.automl: 12-15 04:12:57] {3343} INFO -  at 234.1s,	estimator rf's best error=120.6673,	best estimator rf's best error=120.6673
# [flaml.automl: 12-15 04:12:57] {3166} INFO - iteration 25, current learner rf
# [flaml.automl: 12-15 04:13:14] {3343} INFO -  at 250.3s,	estimator rf's best error=120.6673,	best estimator rf's best error=120.6673
# [flaml.automl: 12-15 04:13:14] {3166} INFO - iteration 26, current learner rf
# [flaml.automl: 12-15 04:13:57] {3343} INFO -  at 293.8s,	estimator rf's best error=120.6673,	best estimator rf's best error=120.6673
# [flaml.automl: 12-15 04:13:57] {3166} INFO - iteration 27, current learner rf
# [flaml.automl: 12-15 04:14:09] {3343} INFO -  at 305.3s,	estimator rf's best error=120.6673,	best estimator rf's best error=120.6673
# [flaml.automl: 12-15 04:14:09] {3166} INFO - iteration 28, current learner rf
# [flaml.automl: 12-15 04:14:29] {3343} INFO -  at 325.6s,	estimator rf's best error=120.6673,	best estimator rf's best error=120.6673
# [flaml.automl: 12-15 04:14:29] {3166} INFO - iteration 29, current learner rf
# [flaml.automl: 12-15 04:14:51] {3343} INFO -  at 347.3s,	estimator rf's best error=120.6673,	best estimator rf's best error=120.6673
# [flaml.automl: 12-15 04:14:51] {3166} INFO - iteration 30, current learner rf
# [flaml.automl: 12-15 04:15:02] {3343} INFO -  at 359.0s,	estimator rf's best error=120.6673,	best estimator rf's best error=120.6673
# [flaml.automl: 12-15 04:15:02] {3166} INFO - iteration 31, current learner rf
# [flaml.automl: 12-15 04:15:37] {3343} INFO -  at 393.8s,	estimator rf's best error=120.6673,	best estimator rf's best error=120.6673
# [flaml.automl: 12-15 04:15:37] {3166} INFO - iteration 32, current learner rf
# [flaml.automl: 12-15 04:15:57] {3343} INFO -  at 414.2s,	estimator rf's best error=120.6673,	best estimator rf's best error=120.6673
# [flaml.automl: 12-15 04:15:57] {3166} INFO - iteration 33, current learner rf
# [flaml.automl: 12-15 04:16:18] {3343} INFO -  at 435.1s,	estimator rf's best error=120.6673,	best estimator rf's best error=120.6673
# [flaml.automl: 12-15 04:16:18] {3166} INFO - iteration 34, current learner rf
# [flaml.automl: 12-15 04:16:56] {3343} INFO -  at 472.5s,	estimator rf's best error=120.6673,	best estimator rf's best error=120.6673
# [flaml.automl: 12-15 04:16:56] {3166} INFO - iteration 35, current learner rf
# [flaml.automl: 12-15 04:17:06] {3343} INFO -  at 482.6s,	estimator rf's best error=120.6673,	best estimator rf's best error=120.6673
# [flaml.automl: 12-15 04:17:06] {3166} INFO - iteration 36, current learner rf
# [flaml.automl: 12-15 04:17:14] {3343} INFO -  at 491.0s,	estimator rf's best error=120.6673,	best estimator rf's best error=120.6673
# [flaml.automl: 12-15 04:17:14] {3166} INFO - iteration 37, current learner rf
# [flaml.automl: 12-15 04:17:52] {3343} INFO -  at 529.1s,	estimator rf's best error=120.6673,	best estimator rf's best error=120.6673
# [flaml.automl: 12-15 04:17:52] {3166} INFO - iteration 38, current learner rf
# [flaml.automl: 12-15 04:18:29] {3343} INFO -  at 565.7s,	estimator rf's best error=120.6673,	best estimator rf's best error=120.6673
# [flaml.automl: 12-15 04:18:29] {3166} INFO - iteration 39, current learner rf
# [flaml.automl: 12-15 04:18:40] {3343} INFO -  at 576.8s,	estimator rf's best error=120.6673,	best estimator rf's best error=120.6673
# [flaml.automl: 12-15 04:18:40] {3166} INFO - iteration 40, current learner rf
# [flaml.automl: 12-15 04:19:11] {3343} INFO -  at 607.7s,	estimator rf's best error=120.6673,	best estimator rf's best error=120.6673
# [flaml.automl: 12-15 04:19:11] {3166} INFO - iteration 41, current learner rf
# [flaml.automl: 12-15 04:19:24] {3343} INFO -  at 621.0s,	estimator rf's best error=120.6673,	best estimator rf's best error=120.6673
# [flaml.automl: 12-15 04:19:24] {3166} INFO - iteration 42, current learner rf
# [flaml.automl: 12-15 04:19:42] {3343} INFO -  at 638.7s,	estimator rf's best error=120.6673,	best estimator rf's best error=120.6673
# [flaml.automl: 12-15 04:19:42] {3166} INFO - iteration 43, current learner rf
# [flaml.automl: 12-15 04:20:06] {3343} INFO -  at 663.2s,	estimator rf's best error=120.6673,	best estimator rf's best error=120.6673
# [flaml.automl: 12-15 04:20:06] {3166} INFO - iteration 44, current learner rf
# [flaml.automl: 12-15 04:20:25] {3343} INFO -  at 682.2s,	estimator rf's best error=120.6673,	best estimator rf's best error=120.6673
# [flaml.automl: 12-15 04:20:25] {3166} INFO - iteration 45, current learner rf
# [flaml.automl: 12-15 04:20:50] {3343} INFO -  at 706.5s,	estimator rf's best error=120.6673,	best estimator rf's best error=120.6673
# [flaml.automl: 12-15 04:20:50] {3166} INFO - iteration 46, current learner rf
# [flaml.automl: 12-15 04:21:27] {3343} INFO -  at 743.9s,	estimator rf's best error=120.6673,	best estimator rf's best error=120.6673
# [flaml.automl: 12-15 04:21:27] {3166} INFO - iteration 47, current learner rf
# [flaml.automl: 12-15 04:21:38] {3343} INFO -  at 755.1s,	estimator rf's best error=120.6673,	best estimator rf's best error=120.6673
# [flaml.automl: 12-15 04:21:38] {3166} INFO - iteration 48, current learner rf
# [flaml.automl: 12-15 04:21:50] {3343} INFO -  at 767.1s,	estimator rf's best error=120.6673,	best estimator rf's best error=120.6673
# [flaml.automl: 12-15 04:21:50] {3166} INFO - iteration 49, current learner rf
# [flaml.automl: 12-15 04:22:27] {3343} INFO -  at 803.5s,	estimator rf's best error=120.6673,	best estimator rf's best error=120.6673
# [flaml.automl: 12-15 04:22:27] {3166} INFO - iteration 50, current learner rf
# [flaml.automl: 12-15 04:23:00] {3343} INFO -  at 836.5s,	estimator rf's best error=120.6673,	best estimator rf's best error=120.6673
# [flaml.automl: 12-15 04:23:00] {3166} INFO - iteration 51, current learner rf
# [flaml.automl: 12-15 04:23:12] {3343} INFO -  at 848.9s,	estimator rf's best error=120.6673,	best estimator rf's best error=120.6673
# [flaml.automl: 12-15 04:23:12] {3166} INFO - iteration 52, current learner rf
# [flaml.automl: 12-15 04:23:42] {3343} INFO -  at 878.4s,	estimator rf's best error=120.6673,	best estimator rf's best error=120.6673
# [flaml.automl: 12-15 04:23:42] {3166} INFO - iteration 53, current learner rf
# [flaml.automl: 12-15 04:23:56] {3343} INFO -  at 893.2s,	estimator rf's best error=120.6673,	best estimator rf's best error=120.6673
# [flaml.automl: 12-15 04:23:56] {3166} INFO - iteration 54, current learner rf
# [flaml.automl: 12-15 04:24:10] {3343} INFO -  at 907.0s,	estimator rf's best error=120.6673,	best estimator rf's best error=120.6673
# [flaml.automl: 12-15 04:24:10] {3166} INFO - iteration 55, current learner rf
# [flaml.automl: 12-15 04:24:40] {3343} INFO -  at 936.4s,	estimator rf's best error=120.6673,	best estimator rf's best error=120.6673
# [flaml.automl: 12-15 04:24:40] {3166} INFO - iteration 56, current learner rf
# [flaml.automl: 12-15 04:25:09] {3343} INFO -  at 966.3s,	estimator rf's best error=120.6673,	best estimator rf's best error=120.6673
# [flaml.automl: 12-15 04:25:09] {3166} INFO - iteration 57, current learner rf
# [flaml.automl: 12-15 04:25:22] {3343} INFO -  at 978.8s,	estimator rf's best error=120.6673,	best estimator rf's best error=120.6673
# [flaml.automl: 12-15 04:25:22] {3166} INFO - iteration 58, current learner rf
# [flaml.automl: 12-15 04:25:50] {3343} INFO -  at 1006.8s,	estimator rf's best error=120.6673,	best estimator rf's best error=120.6673
# [flaml.automl: 12-15 04:25:50] {3166} INFO - iteration 59, current learner rf
# [flaml.automl: 12-15 04:26:05] {3343} INFO -  at 1021.3s,	estimator rf's best error=120.6673,	best estimator rf's best error=120.6673
# [flaml.automl: 12-15 04:26:05] {3166} INFO - iteration 60, current learner rf
# [flaml.automl: 12-15 04:26:21] {3343} INFO -  at 1037.9s,	estimator rf's best error=120.6673,	best estimator rf's best error=120.6673
# [flaml.automl: 12-15 04:26:21] {3166} INFO - iteration 61, current learner rf
# [flaml.automl: 12-15 04:26:48] {3343} INFO -  at 1064.7s,	estimator rf's best error=120.6673,	best estimator rf's best error=120.6673
# [flaml.automl: 12-15 04:26:48] {3166} INFO - iteration 62, current learner rf
# [flaml.automl: 12-15 04:27:25] {3343} INFO -  at 1102.2s,	estimator rf's best error=120.6673,	best estimator rf's best error=120.6673
# [flaml.automl: 12-15 04:27:25] {3166} INFO - iteration 63, current learner rf
# [flaml.automl: 12-15 04:27:36] {3343} INFO -  at 1112.3s,	estimator rf's best error=120.6673,	best estimator rf's best error=120.6673
# [flaml.automl: 12-15 04:27:36] {3166} INFO - iteration 64, current learner rf
# [flaml.automl: 12-15 04:27:56] {3343} INFO -  at 1132.4s,	estimator rf's best error=120.6673,	best estimator rf's best error=120.6673
# [flaml.automl: 12-15 04:27:56] {3166} INFO - iteration 65, current learner rf
# [flaml.automl: 12-15 04:28:15] {3343} INFO -  at 1151.8s,	estimator rf's best error=120.6673,	best estimator rf's best error=120.6673
# [flaml.automl: 12-15 04:28:15] {3166} INFO - iteration 66, current learner rf
# [flaml.automl: 12-15 04:28:30] {3343} INFO -  at 1166.7s,	estimator rf's best error=120.6673,	best estimator rf's best error=120.6673
# [flaml.automl: 12-15 04:28:30] {3166} INFO - iteration 67, current learner rf
# [flaml.automl: 12-15 04:28:55] {3343} INFO -  at 1192.3s,	estimator rf's best error=120.6673,	best estimator rf's best error=120.6673
# [flaml.automl: 12-15 04:28:55] {3166} INFO - iteration 68, current learner rf
# [flaml.automl: 12-15 04:29:09] {3343} INFO -  at 1205.4s,	estimator rf's best error=120.6673,	best estimator rf's best error=120.6673
# [flaml.automl: 12-15 04:29:09] {3166} INFO - iteration 69, current learner rf
# [flaml.automl: 12-15 04:29:35] {3343} INFO -  at 1232.2s,	estimator rf's best error=120.6673,	best estimator rf's best error=120.6673
# [flaml.automl: 12-15 04:29:35] {3166} INFO - iteration 70, current learner rf
# [flaml.automl: 12-15 04:29:57] {3343} INFO -  at 1254.2s,	estimator rf's best error=120.6673,	best estimator rf's best error=120.6673
# [flaml.automl: 12-15 04:29:57] {3166} INFO - iteration 71, current learner rf
# [flaml.automl: 12-15 04:30:08] {3343} INFO -  at 1265.2s,	estimator rf's best error=120.6673,	best estimator rf's best error=120.6673
# [flaml.automl: 12-15 04:30:08] {3166} INFO - iteration 72, current learner rf
# [flaml.automl: 12-15 04:30:21] {3343} INFO -  at 1277.8s,	estimator rf's best error=120.6673,	best estimator rf's best error=120.6673
# [flaml.automl: 12-15 04:30:21] {3166} INFO - iteration 73, current learner rf
# [flaml.automl: 12-15 04:30:47] {3343} INFO -  at 1303.7s,	estimator rf's best error=120.6673,	best estimator rf's best error=120.6673
# [flaml.automl: 12-15 04:30:47] {3166} INFO - iteration 74, current learner rf
# [flaml.automl: 12-15 04:31:05] {3343} INFO -  at 1321.7s,	estimator rf's best error=120.6673,	best estimator rf's best error=120.6673
# [flaml.automl: 12-15 04:31:05] {3166} INFO - iteration 75, current learner rf
# [flaml.automl: 12-15 04:31:20] {3343} INFO -  at 1336.9s,	estimator rf's best error=120.6673,	best estimator rf's best error=120.6673
# [flaml.automl: 12-15 04:31:20] {3166} INFO - iteration 76, current learner rf
# [flaml.automl: 12-15 04:31:33] {3343} INFO -  at 1349.9s,	estimator rf's best error=120.6673,	best estimator rf's best error=120.6673
# [flaml.automl: 12-15 04:31:33] {3166} INFO - iteration 77, current learner rf
# [flaml.automl: 12-15 04:31:50] {3343} INFO -  at 1367.0s,	estimator rf's best error=120.6673,	best estimator rf's best error=120.6673
# [flaml.automl: 12-15 04:31:50] {3166} INFO - iteration 78, current learner rf
# [flaml.automl: 12-15 04:32:03] {3343} INFO -  at 1379.3s,	estimator rf's best error=120.6673,	best estimator rf's best error=120.6673
# [flaml.automl: 12-15 04:32:03] {3166} INFO - iteration 79, current learner rf
# [flaml.automl: 12-15 04:32:20] {3343} INFO -  at 1396.5s,	estimator rf's best error=120.6673,	best estimator rf's best error=120.6673
# [flaml.automl: 12-15 04:32:20] {3166} INFO - iteration 80, current learner rf
# [flaml.automl: 12-15 04:32:30] {3343} INFO -  at 1406.3s,	estimator rf's best error=120.6673,	best estimator rf's best error=120.6673
# [flaml.automl: 12-15 04:32:30] {3166} INFO - iteration 81, current learner rf
# [flaml.automl: 12-15 04:32:36] {3343} INFO -  at 1412.7s,	estimator rf's best error=120.6673,	best estimator rf's best error=120.6673
# [flaml.automl: 12-15 04:32:36] {3166} INFO - iteration 82, current learner rf
# [flaml.automl: 12-15 04:32:48] {3343} INFO -  at 1425.0s,	estimator rf's best error=120.6673,	best estimator rf's best error=120.6673
# [flaml.automl: 12-15 04:32:51] {3602} INFO - retrain rf for 2.4s
# [flaml.automl: 12-15 04:32:51] {3609} INFO - retrained model: RandomForestRegressor(max_features=0.5641179850893047, max_leaf_nodes=663,
#                       n_estimators=143, n_jobs=-1)
# [flaml.automl: 12-15 04:32:51] {2901} INFO - fit succeeded
# [flaml.automl: 12-15 04:32:51] {2902} INFO - Time taken to find the best model: 91.85125613212585
# 0.95 0.9 0.27

# %% [markdown]
# from flaml import AutoML
# from sklearn.datasets import fetch_california_housing
# # Initialize an AutoML instance
# automl = AutoML()
# # Specify automl goal and constraint
# automl_settings = {
#     "time_budget": 180,  # in seconds
#     "metric": 'rmse',
#     "task": 'regression',
#     "log_file_name": "california.log",
# }
#
# Pred=[]
# rmse=[]
# model=[]
# for i in range(20):
#     X_Train, X_Test, y_Train, y_Test =train_test_split(X_train,y_train,test_size = 0.2,shuffle=True)
#     # Train with labeled input data
#     automl.fit(X_train=X_Train.drop(['Lab1'], axis=1), y_train=y_Train,**automl_settings,estimator_list=["extra_tree"])
#     pred=automl.predict(X_test.drop(['Lab1'], axis=1))
#     R2=round(sm.r2_score(y_test, pred), 2)
#     r=round(np.corrcoef(y_test, pred)[0, 1],2)
#     RMSE=round(np.sqrt(sm.mean_squared_error(y_test, pred))/np.mean(y),5)
#     print(r,R2,RMSE)
#     # Predict
#     #print(automl.predict(X_test))
#     # Print the best model
#     print(automl.model.estimator)
#     Pred.append(pred)
#     rmse.append(RMSE)
#     model.append(automl.model.estimator)
#
# Sorted_pred=[]
# sort_index = np.argsort(rmse)
# for i in sort_index:
#     Sorted_pred.append(Pred[i])
# ind=[i for i in range(len(y_test))]
# import matplotlib.pyplot as plt
# fig= plt.figure(figsize=(7,5))
# plt.plot(ind[:200],y_test[:200], color='blue',linewidth=1.5)
# plt.plot(ind[:200],Sorted_pred[1][:200],color='salmon',linewidth=1.5)
# plt.plot(ind[:200],Sorted_pred[17][:200],color='teal',linewidth=1.5)
# plt.legend(['Actual','p10','p90'],loc = 2, bbox_to_anchor = (0.75,1), fontsize=12)
# #plt.plot(ind[:200],Sorted_pred[4][:200],color='black',linewidth=0.2)
# #plt.fill_between(np.array(ind[:200]), np.array(Sorted_pred[0][:200]), np.array(Sorted_pred[4][:200]),
#                  #color='blue', alpha=0.15)
# #plt.plot(ind,Pred[2],color='darkgoldenrod')
# #plt.plot(ind,Pred[3],color='magenta')
# #plt.plot(ind,Pred[4],color='purple')
# plt.xlabel('Observation number',fontsize=16)
# plt.ylabel('Concentraton (ppb)',fontsize=16)
# plt.title('CO-Extra Tree',fontsize=16)
# plt.savefig("co_extra_tree.pdf", format="pdf", bbox_inches="tight")

# %% [markdown]
# from flaml import AutoML
# from sklearn.datasets import fetch_california_housing
#
# # Initialize an AutoML instance
# automl = AutoML()
# # Specify automl goal and constraint
# automl_settings = {
#     "time_budget": 21600,  # in seconds
#     "metric": 'rmse',
#     "task": 'regression',
#     "log_file_name": "california.log",
# }
# # Train with labeled input data
# automl.fit(X_train=X_train.drop(['Lab1'], axis=1), y_train=y_train,**automl_settings,estimator_list=["extra_tree"])
# pred=automl.predict(X_test.drop(['Lab1'], axis=1))
# R2=round(sm.r2_score(y_test, pred), 2)
# r=round(np.corrcoef(y_test, pred)[0, 1],2)
# RMSE=round(np.sqrt(sm.mean_squared_error(y_test, pred))/np.mean(y),2)
# print(r,R2,RMSE)
# # Predict
# #print(automl.predict(X_test))
# # Print the best model
# print(automl.model.estimator)

# %% [markdown]
# from sklearn.svm import SVR
# from sklearn.model_selection import GridSearchCV
#
# # defining parameter range
# param_grid = {'C': [0.1, 1, 10, 100, 1000],
#               'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#               'kernel':  ['rbf']}
#
# grid = GridSearchCV(SVR(), param_grid, refit = True, verbose = 3)
#
# # fitting the model for grid search
# grid.fit(X_train.drop(['Lab1'], axis=1), y_train)
#
# # print best parameter after tuning
# print(grid.best_params_)
#
# # print how our model looks after hyper-parameter tuning
# print(grid.best_estimator_)

# %% [markdown]
# from flaml.model import SKLearnEstimator

# %% [markdown]
# from flaml.model import SKLearnEstimator
# # SKLearnEstimator is derived from BaseEstimator
# import numpy as np
#
# class RandomForestRegressor(SKLearnEstimator):
#     def __init__(self, task="binary", **config):
#         super().__init__(task, **config)
#
#         if task in CLASSIFICATION:
#             from sklearn.ensemble import RandomForestClassifier
#
#             self.estimator_class =RandomForestClassifier
#         else:
#             from sklearn.ensemble import RandomForestRegressor
#
#             self.estimator_class =RandomForestRegressor
#
#     @classmethod
#     def search_space(cls, data_size, task):
#         space = {
#             "n_estimators": {
#                 "domain": {"domain": tune.loguniform(lower=100, upper=20000)},
#                 "low_cost_init_value": 100,
#             },
#             "max_features": {
#                 "domain": tune.loguniform(lower=0.1, upper=1),
#                 "low_cost_init_value": 0.1,
#             },
#             "max_leaf_nodes": {
#                 "domain": tune.lograndint(lower=100, upper=2500),
#                 "low_cost_init_value": 100,},
#             "min_samples_split": {"domain": tune.lograndint(lower=1, upper=20),
#             "init_value": 20,},
#
#             "min_samples_leaf": {
#                 "domain": tune.lograndint(lower=1, upper=20),
#                 "init_value": 20,
#             },
#         }
#         return space

# %% [markdown]
# from flaml import AutoML
# from flaml import tune
# automl = AutoML()
# automl.add_learner("rfr",RandomForestRegressor )

# %% [markdown]
# automl_settings = {
#     "time_budget": 1000,  # in seconds
#     "metric": 'rmse',
#     "task": 'regression',
#     "log_file_name": "california.log",
# }
# # Train with labeled input data
# automl.fit(X_train=X_train.drop(['Lab1'], axis=1), y_train=y_train,**automl_settings,estimator_list=["rfr"])
# pred=automl.predict(X_test.drop(['Lab1'], axis=1))
# R2=round(sm.r2_score(y_test, pred), 2)
# r=round(np.corrcoef(y_test, pred)[0, 1],2)
# RMSE=round(np.sqrt(sm.mean_squared_error(y_test, pred))/np.mean(y),2)
# print(r,R2,RMSE)

# %% [markdown]
# #  NO2 DATA

# %%
X=NO2_Data[['Net Signal','Lab1','Temp','RH','Month','Day_of_week','Hour','Ref_O3']]#'Ref_O3'
y=NO2_Data['Ref']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)
#len(X_test)
X.shape
# Out:
# (3778, 8)

# %% [markdown]
# from flaml import AutoML
# from sklearn.datasets import fetch_california_housing
#
# # Initialize an AutoML instance
# automl = AutoML()
# # Specify automl goal and constraint
# automl_settings = {
#     "time_budget": 200,  # in seconds
#     "metric": 'rmse',
#     "task": 'regression',
#     "log_file_name": "california.log",
# }
# # Train with labeled input data
# automl.fit(X_train=X_train.drop(['Lab1'], axis=1), y_train=y_train,**automl_settings,estimator_list=["xgboost"])
# pred=automl.predict(X_test.drop(['Lab1'], axis=1))
# R2=round(sm.r2_score(y_test, pred), 2)
# r=round(np.corrcoef(y_test, pred)[0, 1],2)
# RMSE=round(np.sqrt(sm.mean_squared_error(y_test, pred))/np.mean(y),2)
# print(r,R2,RMSE)
# # Predict
# #print(automl.predict(X_test))
# # Print the best model
# print(automl.model.estimator)

# %% [markdown]
# from sklearn.svm import SVR
# from sklearn.model_selection import GridSearchCV
#
# # defining parameter range
# param_grid = {'C': [0.1, 1, 10, 100, 1000],
#               'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#               'kernel':  ['rbf', 'poly', 'sigmoid']}
#
# grid = GridSearchCV(SVR(), param_grid, refit = True, verbose = 3)
#
# # fitting the model for grid search
# grid.fit(X_train.drop(['Lab1'], axis=1), y_train)
#
# # print best parameter after tuning
# print(grid.best_params_)
#
# # print how our model looks after hyper-parameter tuning
# print(grid.best_estimator_)

# %% [markdown]
# # O3 DATA

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error as mae
import sklearn.metrics as sm
import matplotlib.pyplot as plt
#,'Ref_CO','Ref_NO2','Ref_SO2'
X=O3_Data[['Net Signal','Lab1','Temp','RH','Month','Day_of_week','Hour','Ref_NO2']]#,'Ref_NO2'
y=O3_Data['Ref']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)
len(X)
# Out:
# 3534

# %% [markdown]
# from flaml import AutoML
# from sklearn.datasets import fetch_california_housing
#
# # Initialize an AutoML instance
# automl = AutoML()
# # Specify automl goal and constraint
# automl_settings = {
#     "time_budget": 200,  # in seconds
#     "metric": 'rmse',
#     "task": 'regression',
#     "log_file_name": "california.log",
# }
# # Train with labeled input data
# automl.fit(X_train=X_train.drop(['Lab1'], axis=1), y_train=y_train,**automl_settings,estimator_list=["xgboost"])
# pred=automl.predict(X_test.drop(['Lab1'], axis=1))
# R2=round(sm.r2_score(y_test, pred), 2)
# r=round(np.corrcoef(y_test, pred)[0, 1],2)
# RMSE=round(np.sqrt(sm.mean_squared_error(y_test, pred))/np.mean(y),2)
# print(r,R2,RMSE)
# # Predict
# #print(automl.predict(X_test))
# # Print the best model
# print(automl.model.estimator)

# %% [markdown]
# from sklearn.svm import SVR
# from sklearn.model_selection import GridSearchCV
#
# # defining parameter range
# param_grid = {'C': [0.1, 1, 10, 100, 1000],
#               'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#               'kernel':  ['rbf', 'poly', 'sigmoid']}
#
# grid = GridSearchCV(SVR(), param_grid, refit = True, verbose = 3)
#
# # fitting the model for grid search
# grid.fit(X_train.drop(['Lab1'], axis=1), y_train)
#
# # print best parameter after tuning
# print(grid.best_params_)
#
# # print how our model looks after hyper-parameter tuning
# print(grid.best_estimator_)

# %% [markdown]
# # SO2 DATA

# %%
import pandas as pd
Ref=pd.read_csv('Ref.csv')
Ref["CO"] = 1000 * Ref["CO"]
Ref['Date'] = pd.to_datetime(Ref['Date_Time'])
Ref=Ref.set_index('Date')
Ref.drop('Date_Time',axis = 1, inplace = True)
Ref=Ref.resample('5min').mean()
Ref=Ref[76463:137376]
Ref_CO=Ref['CO'].to_list()
Ref_NO2=Ref['NO2'].to_list()
Ref_SO2=Ref['SO2'].to_list()
Ref_O3=Ref['O3'].to_list()

# %%
import pandas as pd
import scipy.io
import numpy as np
data = pd.read_csv('Conc_SO2.txt', header = None,low_memory=False)
data.columns=['Lab2','Temp','RH','Time','Ref']
Time=data['Time'].to_list()
time=[]
for i in range(len(Time)):
    time.append(float(abs(Time[i])))
Time=np.array(time)
Date=pd.to_datetime(Time-719529,unit='d').round('s')
data['Date'] = Date.tolist()
data=data.set_index('Date')
data.drop('Time',axis = 1, inplace = True)
data=data.resample('5min').mean()
Data_SO2=data
Data_so2=data
#signal=np.array(WE)-np.array(AE)
#Data_SO2['Net Signal']=signal
Data_SO2['Month']=Data_SO2.index.month
Data_SO2['Day_of_week']=Data_SO2.index.dayofweek
Data_SO2['Day']=Data_SO2.index.day
Data_SO2['Hour']=Data_SO2.index.hour
SO2_Data=Data_SO2
SO2_Data=SO2_Data.resample('5min').mean()
SO2_Data=SO2_Data[(SO2_Data[SO2_Data.columns] >= 0).all(axis=1)]
SO2_Data=SO2_Data.dropna() 
data = pd.read_csv('SO2.txt', header = None,low_memory=False)
data.columns=['WE','AE','Temp','RH','Time']
Time=data['Time'].to_list()
time=[]
for i in range(len(Time)):
    time.append(float(abs(Time[i])))
Time=np.array(time)
Date=pd.to_datetime(Time-719529,unit='d').round('s')
data['Date'] = Date.tolist()
data=data.set_index('Date')
data.drop('Time',axis = 1, inplace = True)
data=data.resample('5min').mean()
Data_SO2=data
Data_SO2['Ref']=Ref_SO2
WE=Data_SO2['WE'].to_list()
AE=Data_SO2['AE'].to_list()
signal=np.array(WE)-np.array(AE)
Data_SO2['Lab2']=Data_so2['Lab2'].to_list()
Data_SO2['Net Signal']=signal
Data_SO2['Month']=Data_SO2.index.month
Data_SO2['Day_of_week']=Data_SO2.index.dayofweek
Data_SO2['Day']=Data_SO2.index.day
Data_SO2['Hour']=Data_SO2.index.hour
SO2_Data=Data_SO2
SO2_Data.shape
# Out:
# (60913, 11)

# %%
SO2_Data=SO2_Data[(SO2_Data[SO2_Data.columns] >= 0).all(axis=1)]
SO2_Data=SO2_Data.dropna()
SO2_Data=SO2_Data.resample('h').mean()
SO2_Data=SO2_Data.dropna()
SO2_Data.head()
# Out:
#                              WE          AE       Temp         RH       Ref  \
# Date
# 2019-10-10 04:00:00  344.013811  342.484305  18.332589  82.373211  1.190555
# 2019-10-10 05:00:00  347.947204  342.688948  18.160512  83.041499  1.517400
# 2019-10-10 06:00:00  349.586425  342.643169  18.294731  80.755815  1.596648
# 2019-10-10 07:00:00  348.280332  342.545156  21.874264  74.161148  1.518688
# 2019-10-10 08:00:00  352.303813  345.041354  29.141688  59.611152  1.379748
#
#                           Lab2  Net Signal  Month  Day_of_week   Day  Hour
# Date
# 2019-10-10 04:00:00   9.990807    1.529506   10.0          3.0  10.0   4.0
# 2019-10-10 05:00:00  21.173371    5.258256   10.0          3.0  10.0   5.0
# 2019-10-10 06:00:00  26.255508    6.943256   10.0          3.0  10.0   6.0
# 2019-10-10 07:00:00  22.449829    5.735176   10.0          3.0  10.0   7.0
# 2019-10-10 08:00:00  23.209242    7.262459   10.0          3.0  10.0   8.0

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error as mae
import sklearn.metrics as sm
import matplotlib.pyplot as plt
#'Ref_CO','Ref_NO2','Ref_O3',
X=SO2_Data[['Net Signal','Lab2','Temp','RH','Month','Day_of_week','Hour']]
y=SO2_Data['Ref']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)
len(X)
# Out:
# 1996

# %% [markdown]
# from flaml import AutoML
# from sklearn.datasets import fetch_california_housing
#
# # Initialize an AutoML instance
# automl = AutoML()
# # Specify automl goal and constraint
# automl_settings = {
#     "time_budget": 200,  # in seconds
#     "metric": 'rmse',
#     "task": 'regression',
#     "log_file_name": "california.log",
# }
# # Train with labeled input data
# automl.fit(X_train=X_train.drop(['Lab2'], axis=1), y_train=y_train,**automl_settings,estimator_list=["xgboost"])
# pred=automl.predict(X_test.drop(['Lab2'], axis=1))
# R2=round(sm.r2_score(y_test, pred), 2)
# r=round(np.corrcoef(y_test, pred)[0, 1],2)
# RMSE=round(np.sqrt(sm.mean_squared_error(y_test, pred))/np.mean(y),2)
# print(r,R2,RMSE)
# # Predict
# #print(automl.predict(X_test))
# # Print the best model
# print(automl.model.estimator)

# %% [markdown]
# from sklearn.svm import SVR
# from sklearn.model_selection import GridSearchCV
#
# # defining parameter range
# param_grid = {'C': [0.1, 1, 10, 100, 1000],
#               'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#               'kernel':  ['rbf', 'poly', 'sigmoid']}
#
# grid = GridSearchCV(SVR(), param_grid, refit = True, verbose = 3)
#
# # fitting the model for grid search
# grid.fit(X_train.drop(['Lab2'], axis=1), y_train)
#
# # print best parameter after tuning
# print(grid.best_params_)
#
# # print how our model looks after hyper-parameter tuning
# print(grid.best_estimator_)
