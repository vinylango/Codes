# %%
import pandas as pd
from pandas import MultiIndex, Int16Dtype
Ref=pd.read_csv('Ref.csv')
Ref["CO"] = 1000 * Ref["CO"]
Ref['Date'] = pd.to_datetime(Ref['Date_Time'])
Ref=Ref.set_index('Date')
Ref.drop('Date_Time',axis = 1, inplace = True)
Ref=Ref.resample('5min').mean()
Ref=Ref[76463:137376]
Ref_CO=Ref['CO'].to_list()
Ref_NO2=Ref['NO2'].to_list()
Ref_SO2=Ref['SO2'].to_list()
Ref_O3=Ref['O3'].to_list()

# %%
import random
import pandas as pd
import scipy.io
import numpy as np
data = pd.read_csv('CO.txt', header = None,low_memory=False)
data.columns=['WE','AE','Temp','RH','Time']
Time=data['Time'].to_list()
time=[]
for i in range(len(Time)):
    time.append(float(abs(Time[i])))
Time=np.array(time)
Date=pd.to_datetime(Time-719529,unit='d').round('s')
data['Date'] = Date.tolist()
data=data.set_index('Date')
data.drop('Time',axis = 1, inplace = True)
data=data.resample('5min').mean()
Data_CO=data
Data_CO['Ref']=Ref_CO
index_names = Data_CO[ (Data_CO['WE'] >1000)].index
Data_CO.drop(index_names, inplace = True)
WE=Data_CO['WE'].to_list()
AE=Data_CO['AE'].to_list()
signal=np.array(WE)-np.array(AE)
Data_CO['Net Signal']=signal
Data_CO['Month']=Data_CO.index.month
Data_CO['Day_of_week']=Data_CO.index.dayofweek
Data_CO['Day']=Data_CO.index.day
Data_CO['Hour']=Data_CO.index.hour
CO_Data=Data_CO
CO_Data=CO_Data[(CO_Data[CO_Data.columns] >= 0).all(axis=1)]
CO_Data=CO_Data.dropna()
data = pd.read_csv('Conc_CO.txt', header = None,low_memory=False)
data.columns=['Lab1','Temp','RH','Time','Ref']
Time=data['Time'].to_list()
time=[]
for i in range(len(Time)):
    time.append(float(abs(Time[i])))
Time=np.array(time)
Date=pd.to_datetime(Time-719529,unit='d').round('s')
data['Date'] = Date.tolist()
data=data.set_index('Date')
data.drop('Time',axis = 1, inplace = True)
data=data.resample('5min').mean()
Data_CO=data
Data_CO.drop(index_names, inplace = True)
signal=np.array(WE)-np.array(AE)
Data_CO['Net Signal']=signal
Data_CO['Month']=Data_CO.index.month
Data_CO['Day_of_week']=Data_CO.index.dayofweek
Data_CO['Day']=Data_CO.index.day
Data_CO['Hour']=Data_CO.index.hour
CO_Data=Data_CO
CO_Data=CO_Data[(CO_Data[CO_Data.columns] >= 0).all(axis=1)]
CO_Data=CO_Data.dropna()
CO_Data=CO_Data.resample('h').mean()
CO_Data=CO_Data.dropna()
CO_Data.tail()
# Out:
#                            Lab1       Temp         RH         Ref  Net Signal  \
# Date
# 2020-04-30 19:00:00  242.060716  18.870796  71.072939  188.915151   91.471325
# 2020-04-30 20:00:00  218.655079  18.056864  75.132153  178.704750   84.176485
# 2020-04-30 21:00:00  194.147868  17.090891  81.315038  161.421792   73.858294
# 2020-04-30 22:00:00  206.432889  16.714085  82.568155  197.744043   83.279611
# 2020-04-30 23:00:00  173.577429  16.365121  83.662401  162.157636   68.669099
#
#                      Month  Day_of_week   Day  Hour
# Date
# 2020-04-30 19:00:00    4.0          3.0  30.0  19.0
# 2020-04-30 20:00:00    4.0          3.0  30.0  20.0
# 2020-04-30 21:00:00    4.0          3.0  30.0  21.0
# 2020-04-30 22:00:00    4.0          3.0  30.0  22.0
# 2020-04-30 23:00:00    4.0          3.0  30.0  23.0

# %%
import pandas as pd
import scipy.io
import numpy as np
data = pd.read_csv('O3.txt', header = None,low_memory=False)
data.columns=['AE','WE','Temp','RH','Time']
Time=data['Time'].to_list()
time=[]
for i in range(len(Time)):
    time.append(float(abs(Time[i])))
Time=np.array(time)
Date=pd.to_datetime(Time-719529,unit='d').round('s')
data['Date'] = Date.tolist()
data=data.set_index('Date')
data.drop('Time',axis = 1, inplace = True)
data=data.resample('5min').mean()
Data_O3=data
Data_O3['Ref']=Ref_O3
WE=Data_O3['WE'].to_list()
AE=Data_O3['AE'].to_list()
signal=np.array(WE)-np.array(AE)
Data_O3['Net Signal']=signal
Data_O3['Month']=Data_O3.index.month
Data_O3['Day_of_week']=Data_O3.index.dayofweek
Data_O3['Day']=Data_O3.index.day
Data_O3['Hour']=Data_O3.index.hour
O3_Data=Data_O3
O3_Data=O3_Data[(O3_Data[O3_Data.columns] >= 0).all(axis=1)]
O3_Data=O3_Data.dropna()
data = pd.read_csv('Conc_O3.txt', header = None,low_memory=False)
data.columns=['Lab1','Temp','RH','Time','Ref']
Time=data['Time'].to_list()
time=[]
for i in range(len(Time)):
    time.append(float(abs(Time[i])))
Time=np.array(time)
Date=pd.to_datetime(Time-719529,unit='d').round('s')
data['Date'] = Date.tolist()
data=data.set_index('Date')
data.drop('Time',axis = 1, inplace = True)
data=data.resample('5min').mean()
Data_O3=data
signal=np.array(WE)-np.array(AE)
Data_O3['Net Signal']=signal
Data_O3['Month']=Data_O3.index.month
Data_O3['Day_of_week']=Data_O3.index.dayofweek
Data_O3['Day']=Data_O3.index.day
Data_O3['Hour']=Data_O3.index.hour
O3_Data=Data_O3
O3_Data=O3_Data[(O3_Data[O3_Data.columns] >= 0).all(axis=1)]
O3_Data=O3_Data.dropna() 
O3_Data=O3_Data.resample('h').mean()
O3_Data=O3_Data.dropna()
O3_Data.head()

ref_O3=Data_O3['Ref'].to_list()
len(ref_O3)
# Out:
# 60913

# %%
import pandas as pd
import scipy.io
import numpy as np
data = pd.read_csv('NO2.txt', header = None,low_memory=False)
data.columns=['WE','AE','Temp','RH','Time']
Time=data['Time'].to_list()
time=[]
for i in range(len(Time)):
    time.append(float(abs(Time[i])))
Time=np.array(time)
Date=pd.to_datetime(Time-719529,unit='d').round('s')
data['Date'] = Date.tolist()
data=data.set_index('Date')
data.drop('Time',axis = 1, inplace = True)
data=data.resample('5min').mean()
Data_NO2=data
Data_NO2['Ref']=Ref_NO2
WE=Data_NO2['WE'].to_list()
AE=Data_NO2['AE'].to_list()
signal=np.array(WE)-np.array(AE)
Data_NO2['Net Signal']=signal
Data_NO2['Month']=Data_NO2.index.month
Data_NO2['Day_of_week']=Data_NO2.index.dayofweek
Data_NO2['Day']=Data_NO2.index.day
Data_NO2['Hour']=Data_NO2.index.hour
NO2_Data=Data_NO2
NO2_Data=NO2_Data[(NO2_Data[NO2_Data.columns] >= 0).all(axis=1)]
NO2_Data=NO2_Data.dropna()
data = pd.read_csv('Conc_NO2.txt', header = None,low_memory=False)
data.columns=['Lab1','Temp','RH','Time','Ref']
Time=data['Time'].to_list()
time=[]
subscript = str.maketrans("0123456789", "₀₁₂₃₄₅₆₇₈₉") 
for i in range(len(Time)):
    time.append(float(abs(Time[i])))
Time=np.array(time)
Date=pd.to_datetime(Time-719529,unit='d').round('s')
data['Date'] = Date.tolist()
data=data.set_index('Date')
data.drop('Time',axis = 1, inplace = True)
data=data.resample('5min').mean()
Data_NO2=data
signal=np.array(WE)-np.array(AE)
Data_NO2['Net Signal']=signal
Data_NO2['Month']=Data_NO2.index.month
Data_NO2['Day_of_week']=Data_NO2.index.dayofweek
Data_NO2['Day']=Data_NO2.index.day
Data_NO2['Hour']=Data_NO2.index.hour
Data_NO2['Ref_O3']=ref_O3
NO2_Data=Data_NO2
NO2_Data=NO2_Data[(NO2_Data[NO2_Data.columns] >= 0).all(axis=1)]
NO2_Data=NO2_Data.dropna()
NO2_Data=NO2_Data.resample('h').mean()
NO2_Data=NO2_Data.dropna()

# %%
import pandas as pd
import scipy.io
import numpy as np
data = pd.read_csv('O3.txt', header = None,low_memory=False)
data.columns=['AE','WE','Temp','RH','Time']
Time=data['Time'].to_list()
time=[]
for i in range(len(Time)):
    time.append(float(abs(Time[i])))
Time=np.array(time)
Date=pd.to_datetime(Time-719529,unit='d').round('s')
data['Date'] = Date.tolist()
data=data.set_index('Date')
data.drop('Time',axis = 1, inplace = True)
data=data.resample('5min').mean()
Data_O3=data
Data_O3['Ref']=Ref_O3
WE=Data_O3['WE'].to_list()
AE=Data_O3['AE'].to_list()
signal=np.array(WE)-np.array(AE)
Data_O3['Net Signal']=signal
Data_O3['Month']=Data_O3.index.month
Data_O3['Day_of_week']=Data_O3.index.dayofweek
Data_O3['Day']=Data_O3.index.day
Data_O3['Hour']=Data_O3.index.hour
O3_Data=Data_O3
O3_Data=O3_Data[(O3_Data[O3_Data.columns] >= 0).all(axis=1)]
O3_Data=O3_Data.dropna()
data = pd.read_csv('Conc_O3.txt', header = None,low_memory=False)
data.columns=['Lab1','Temp','RH','Time','Ref']
Time=data['Time'].to_list()
time=[]
for i in range(len(Time)):
    time.append(float(abs(Time[i])))
Time=np.array(time)
Date=pd.to_datetime(Time-719529,unit='d').round('s')
data['Date'] = Date.tolist()
data=data.set_index('Date')
data.drop('Time',axis = 1, inplace = True)
data=data.resample('5min').mean()
Data_O3=data
signal=np.array(WE)-np.array(AE)
Data_O3['Net Signal']=signal
Data_O3['Month']=Data_O3.index.month
Data_O3['Day_of_week']=Data_O3.index.dayofweek
Data_O3['Day']=Data_O3.index.day
Data_O3['Hour']=Data_O3.index.hour
ref_NO2=Data_NO2['Ref'].to_list()
Data_O3['Ref_NO2']=ref_NO2
O3_Data=Data_O3
O3_Data=O3_Data[(O3_Data[O3_Data.columns] >= 0).all(axis=1)]
O3_Data=O3_Data.dropna()
O3_Data=O3_Data.resample('h').mean()
O3_Data=O3_Data.dropna()
O3_Data.head()
# Out:
#                            Lab1       Temp         RH        Ref  Net Signal  \
# Date
# 2019-10-02 11:00:00  621.625704  26.378438  58.063437  46.094860    3.605625
# 2019-10-02 12:00:00  725.154408  25.795055  48.256857  57.532808   13.865109
# 2019-10-07 10:00:00  108.196313  32.344264  37.260757  47.259008   11.447809
# 2019-10-07 11:00:00  135.822676  34.926112  35.013036  42.114260   10.075221
# 2019-10-07 12:00:00  203.757758  36.201221  31.829282  45.701366    7.624153
#
#                      Month  Day_of_week  Day  Hour    Ref_NO2
# Date
# 2019-10-02 11:00:00   10.0          2.0  2.0  11.0  15.230400
# 2019-10-02 12:00:00   10.0          2.0  2.0  12.0   5.384051
# 2019-10-07 10:00:00   10.0          0.0  7.0  10.0   4.255772
# 2019-10-07 11:00:00   10.0          0.0  7.0  11.0  16.268034
# 2019-10-07 12:00:00   10.0          0.0  7.0  12.0  12.770444

# %% [markdown]
# # CO DATA

# %%
from sktime.performance_metrics.forecasting import sMAPE, smape_loss
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error as mae
import sklearn.metrics as sm
import matplotlib.pyplot as plt
#'Ref_NO2','Ref_SO2','Ref_O3',
#,'Month','Day_of_week','Day','Hour'
X=CO_Data[['Net Signal','Lab1','Temp','RH','Month','Day_of_week','Hour']]
y=CO_Data['Ref']
X_train, X_test, y_train, y_test =train_test_split(X,y,test_size = 0.2,shuffle=True)
#train_test_split(X, y, test_size = 0.2)

# %%
from flaml.model import SKLearnEstimator
# SKLearnEstimator is derived from BaseEstimator
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/xgboost/compat.py:93: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %% [markdown]
# from sklearn.svm import SVR
# from sklearn.model_selection import GridSearchCV
#
# # defining parameter range
# param_grid = {'C': [0.1, 1, 10, 100, 1000],
#               'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#               'kernel':  ['rbf']}
#
# grid = GridSearchCV(SVR(), param_grid, refit = True, verbose = 3)
#
# # fitting the model for grid search
# grid.fit(X_train.drop(['Lab1'], axis=1), y_train)
#
# # print best parameter after tuning
# print(grid.best_params_)
#
# # print how our model looks after hyper-parameter tuning
# print(grid.best_estimator_)

# %% [markdown]
# from flaml.model import SKLearnEstimator

# %% [markdown]
# from flaml.model import SKLearnEstimator
# # SKLearnEstimator is derived from BaseEstimator
# import numpy as np
#
# class RandomForestRegressor(SKLearnEstimator):
#     def __init__(self, task="binary", **config):
#         super().__init__(task, **config)
#
#         if task in CLASSIFICATION:
#             from sklearn.ensemble import RandomForestClassifier
#
#             self.estimator_class =RandomForestClassifier
#         else:
#             from sklearn.ensemble import RandomForestRegressor
#
#             self.estimator_class =RandomForestRegressor
#
#     @classmethod
#     def search_space(cls, data_size, task):
#         space = {
#             "n_estimators": {
#                 "domain": {"domain": tune.loguniform(lower=100, upper=20000)},
#                 "low_cost_init_value": 100,
#             },
#             "max_features": {
#                 "domain": tune.loguniform(lower=0.1, upper=1),
#                 "low_cost_init_value": 0.1,
#             },
#             "max_leaf_nodes": {
#                 "domain": tune.lograndint(lower=100, upper=2500),
#                 "low_cost_init_value": 100,},
#             "min_samples_split": {"domain": tune.lograndint(lower=1, upper=20),
#             "init_value": 20,},
#
#             "min_samples_leaf": {
#                 "domain": tune.lograndint(lower=1, upper=20),
#                 "init_value": 20,
#             },
#         }
#         return space

# %% [markdown]
# from flaml import AutoML
# from flaml import tune
# automl = AutoML()
# automl.add_learner("rfr",RandomForestRegressor )

# %% [markdown]
# automl_settings = {
#     "time_budget": 1000,  # in seconds
#     "metric": 'rmse',
#     "task": 'regression',
#     "log_file_name": "california.log",
# }
# # Train with labeled input data
# automl.fit(X_train=X_train.drop(['Lab1'], axis=1), y_train=y_train,**automl_settings,estimator_list=["rfr"])
# pred=automl.predict(X_test.drop(['Lab1'], axis=1))
# R2=round(sm.r2_score(y_test, pred), 2)
# r=round(np.corrcoef(y_test, pred)[0, 1],2)
# RMSE=round(np.sqrt(sm.mean_squared_error(y_test, pred))/np.mean(y),2)
# print(r,R2,RMSE)

# %% [markdown]
# #  NO2 DATA

# %%
from flaml import AutoML
from sklearn.datasets import fetch_california_housing
X=NO2_Data[['Net Signal','Lab1','Temp','RH','Month','Day_of_week','Hour','Ref_O3']]#'Ref_O3'
y=NO2_Data['Ref']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)
#len(X_test)
X.shape
# Out:
# (3778, 8)

# %%
# Initialize an AutoML instance
automl = AutoML()
# Specify automl goal and constraint
automl_settings = {
    "time_budget": 1440,  # in seconds
    "metric": 'rmse',
    "task": 'regression',
    "log_file_name": "california.log",
}

Pred=[]
rmse=[]
model=[]
RS=[]
R=[]
for i in range(10):
    X_Train, X_Test, y_Train, y_Test =train_test_split(X_train,y_train,test_size = 0.2,shuffle=True)
    # Train with labeled input data
    automl.fit(X_train=X_Train.drop(['Lab1'], axis=1), y_train=y_Train,**automl_settings,estimator_list=["rf"])
    pred=automl.predict(X_test.drop(['Lab1'], axis=1))
    R2=round(sm.r2_score(y_test, pred), 2)
    r=round(np.corrcoef(y_test, pred)[0, 1],2)
    RMSE=round(np.sqrt(sm.mean_squared_error(y_test, pred))/np.mean(y),5)
    #print(r,R2,RMSE)
    # Predict
    #print(automl.predict(X_test))
    # Print the best model
    #print(automl.model.estimator)
    Pred.append(pred)
    rmse.append(RMSE)
    model.append(automl.model.estimator)
    RS.append(R2)
    R.append(r)

print(np.round(np.mean(R),2),np.round(np.mean(RS),2),np.round(np.mean(rmse),2))
# Out:
# [flaml.automl: 12-15 00:35:39] {2599} INFO - task = regression
# [flaml.automl: 12-15 00:35:39] {2601} INFO - Data split method: uniform
# [flaml.automl: 12-15 00:35:39] {2604} INFO - Evaluation method: cv
# [flaml.automl: 12-15 00:35:39] {2726} INFO - Minimizing error metric: rmse
# [flaml.automl: 12-15 00:35:39] {2870} INFO - List of ML learners in AutoML Run: ['rf']
# [flaml.automl: 12-15 00:35:39] {3166} INFO - iteration 0, current learner rf
# [flaml.automl: 12-15 00:35:40] {3296} INFO - Estimated sufficient time budget=10075s. Estimated necessary time budget=10s.
# [flaml.automl: 12-15 00:35:40] {3343} INFO -  at 1.3s,	estimator rf's best error=6.9012,	best estimator rf's best error=6.9012
# [flaml.automl: 12-15 00:35:40] {3166} INFO - iteration 1, current learner rf
# [flaml.automl: 12-15 00:35:41] {3343} INFO -  at 2.2s,	estimator rf's best error=5.1597,	best estimator rf's best error=5.1597
# [flaml.automl: 12-15 00:35:41] {3166} INFO - iteration 2, current learner rf
# [flaml.automl: 12-15 00:35:41] {3343} INFO -  at 3.0s,	estimator rf's best error=5.1597,	best estimator rf's best error=5.1597
# [flaml.automl: 12-15 00:35:41] {3166} INFO - iteration 3, current learner rf
# [flaml.automl: 12-15 00:35:42] {3343} INFO -  at 3.9s,	estimator rf's best error=4.4780,	best estimator rf's best error=4.4780
# [flaml.automl: 12-15 00:35:42] {3166} INFO - iteration 4, current learner rf
# [flaml.automl: 12-15 00:35:43] {3343} INFO -  at 5.0s,	estimator rf's best error=4.0101,	best estimator rf's best error=4.0101
# [flaml.automl: 12-15 00:35:43] {3166} INFO - iteration 5, current learner rf
# [flaml.automl: 12-15 00:35:45] {3343} INFO -  at 6.2s,	estimator rf's best error=4.0101,	best estimator rf's best error=4.0101
# [flaml.automl: 12-15 00:35:45] {3166} INFO - iteration 6, current learner rf
# [flaml.automl: 12-15 00:35:46] {3343} INFO -  at 7.2s,	estimator rf's best error=3.8482,	best estimator rf's best error=3.8482
# [flaml.automl: 12-15 00:35:46] {3166} INFO - iteration 7, current learner rf
# [flaml.automl: 12-15 00:35:47] {3343} INFO -  at 8.8s,	estimator rf's best error=3.8482,	best estimator rf's best error=3.8482
# [flaml.automl: 12-15 00:35:47] {3166} INFO - iteration 8, current learner rf
# [flaml.automl: 12-15 00:35:48] {3343} INFO -  at 10.1s,	estimator rf's best error=3.5693,	best estimator rf's best error=3.5693
# [flaml.automl: 12-15 00:35:48] {3166} INFO - iteration 9, current learner rf
# [flaml.automl: 12-15 00:35:50] {3343} INFO -  at 11.5s,	estimator rf's best error=3.5693,	best estimator rf's best error=3.5693
# [flaml.automl: 12-15 00:35:50] {3166} INFO - iteration 10, current learner rf
# [flaml.automl: 12-15 00:35:51] {3343} INFO -  at 12.9s,	estimator rf's best error=3.5693,	best estimator rf's best error=3.5693
# [flaml.automl: 12-15 00:35:51] {3166} INFO - iteration 11, current learner rf
# [flaml.automl: 12-15 00:35:54] {3343} INFO -  at 15.4s,	estimator rf's best error=3.5515,	best estimator rf's best error=3.5515
# [flaml.automl: 12-15 00:35:54] {3166} INFO - iteration 12, current learner rf
# [flaml.automl: 12-15 00:35:55] {3343} INFO -  at 16.8s,	estimator rf's best error=3.5515,	best estimator rf's best error=3.5515
# [flaml.automl: 12-15 00:35:55] {3166} INFO - iteration 13, current learner rf
# [flaml.automl: 12-15 00:36:00] {3343} INFO -  at 21.7s,	estimator rf's best error=3.4306,	best estimator rf's best error=3.4306
# [flaml.automl: 12-15 00:36:00] {3166} INFO - iteration 14, current learner rf
# [flaml.automl: 12-15 00:36:03] {3343} INFO -  at 24.6s,	estimator rf's best error=3.4306,	best estimator rf's best error=3.4306
# [flaml.automl: 12-15 00:36:03] {3166} INFO - iteration 15, current learner rf
# [flaml.automl: 12-15 00:36:13] {3343} INFO -  at 34.7s,	estimator rf's best error=3.3377,	best estimator rf's best error=3.3377
# [flaml.automl: 12-15 00:36:13] {3166} INFO - iteration 16, current learner rf
# [flaml.automl: 12-15 00:36:18] {3343} INFO -  at 39.3s,	estimator rf's best error=3.3377,	best estimator rf's best error=3.3377
# [flaml.automl: 12-15 00:36:18] {3166} INFO - iteration 17, current learner rf
# [flaml.automl: 12-15 00:36:44] {3343} INFO -  at 65.8s,	estimator rf's best error=3.3377,	best estimator rf's best error=3.3377
# [flaml.automl: 12-15 00:36:44] {3166} INFO - iteration 18, current learner rf
# [flaml.automl: 12-15 00:37:08] {3343} INFO -  at 90.1s,	estimator rf's best error=3.3377,	best estimator rf's best error=3.3377
# [flaml.automl: 12-15 00:37:08] {3166} INFO - iteration 19, current learner rf
# [flaml.automl: 12-15 00:37:13] {3343} INFO -  at 95.1s,	estimator rf's best error=3.3377,	best estimator rf's best error=3.3377
# [flaml.automl: 12-15 00:37:13] {3166} INFO - iteration 20, current learner rf
# [flaml.automl: 12-15 00:37:34] {3343} INFO -  at 115.6s,	estimator rf's best error=3.3377,	best estimator rf's best error=3.3377
# [flaml.automl: 12-15 00:37:34] {3166} INFO - iteration 21, current learner rf
# [flaml.automl: 12-15 00:37:39] {3343} INFO -  at 120.8s,	estimator rf's best error=3.3377,	best estimator rf's best error=3.3377
# [flaml.automl: 12-15 00:37:39] {3166} INFO - iteration 22, current learner rf
# [flaml.automl: 12-15 00:37:44] {3343} INFO -  at 125.4s,	estimator rf's best error=3.3377,	best estimator rf's best error=3.3377
# [flaml.automl: 12-15 00:37:44] {3166} INFO - iteration 23, current learner rf
# [flaml.automl: 12-15 00:38:05] {3343} INFO -  at 146.8s,	estimator rf's best error=3.3377,	best estimator rf's best error=3.3377
# [flaml.automl: 12-15 00:38:05] {3166} INFO - iteration 24, current learner rf
# [flaml.automl: 12-15 00:38:17] {3343} INFO -  at 158.2s,	estimator rf's best error=3.3377,	best estimator rf's best error=3.3377
# [flaml.automl: 12-15 00:38:17] {3166} INFO - iteration 25, current learner rf
# [flaml.automl: 12-15 00:38:25] {3343} INFO -  at 167.0s,	estimator rf's best error=3.3377,	best estimator rf's best error=3.3377
# [flaml.automl: 12-15 00:38:25] {3166} INFO - iteration 26, current learner rf
# [flaml.automl: 12-15 00:38:43] {3343} INFO -  at 184.2s,	estimator rf's best error=3.3377,	best estimator rf's best error=3.3377
# [flaml.automl: 12-15 00:38:43] {3166} INFO - iteration 27, current learner rf
# [flaml.automl: 12-15 00:38:48] {3343} INFO -  at 189.6s,	estimator rf's best error=3.3377,	best estimator rf's best error=3.3377
# [flaml.automl: 12-15 00:38:48] {3166} INFO - iteration 28, current learner rf
# [flaml.automl: 12-15 00:38:57] {3343} INFO -  at 198.6s,	estimator rf's best error=3.3377,	best estimator rf's best error=3.3377
# [flaml.automl: 12-15 00:38:57] {3166} INFO - iteration 29, current learner rf
# [flaml.automl: 12-15 00:39:06] {3343} INFO -  at 207.9s,	estimator rf's best error=3.3377,	best estimator rf's best error=3.3377
# [flaml.automl: 12-15 00:39:06] {3166} INFO - iteration 30, current learner rf
# [flaml.automl: 12-15 00:39:12] {3343} INFO -  at 213.7s,	estimator rf's best error=3.3377,	best estimator rf's best error=3.3377
# [flaml.automl: 12-15 00:39:12] {3166} INFO - iteration 31, current learner rf
# [flaml.automl: 12-15 00:39:27] {3343} INFO -  at 229.0s,	estimator rf's best error=3.3377,	best estimator rf's best error=3.3377
# [flaml.automl: 12-15 00:39:27] {3166} INFO - iteration 32, current learner rf
# [flaml.automl: 12-15 00:39:38] {3343} INFO -  at 239.3s,	estimator rf's best error=3.3377,	best estimator rf's best error=3.3377
# [flaml.automl: 12-15 00:39:38] {3166} INFO - iteration 33, current learner rf
# [flaml.automl: 12-15 00:39:46] {3343} INFO -  at 247.7s,	estimator rf's best error=3.3377,	best estimator rf's best error=3.3377
# [flaml.automl: 12-15 00:39:46] {3166} INFO - iteration 34, current learner rf
# [flaml.automl: 12-15 00:40:03] {3343} INFO -  at 264.9s,	estimator rf's best error=3.3377,	best estimator rf's best error=3.3377
# [flaml.automl: 12-15 00:40:03] {3166} INFO - iteration 35, current learner rf
# [flaml.automl: 12-15 00:40:08] {3343} INFO -  at 269.9s,	estimator rf's best error=3.3377,	best estimator rf's best error=3.3377
# [flaml.automl: 12-15 00:40:08] {3166} INFO - iteration 36, current learner rf
# [flaml.automl: 12-15 00:40:13] {3343} INFO -  at 275.1s,	estimator rf's best error=3.3377,	best estimator rf's best error=3.3377
# [flaml.automl: 12-15 00:40:13] {3166} INFO - iteration 37, current learner rf
# [flaml.automl: 12-15 00:40:31] {3343} INFO -  at 292.1s,	estimator rf's best error=3.3377,	best estimator rf's best error=3.3377
# [flaml.automl: 12-15 00:40:31] {3166} INFO - iteration 38, current learner rf
# [flaml.automl: 12-15 00:40:46] {3343} INFO -  at 308.1s,	estimator rf's best error=3.3377,	best estimator rf's best error=3.3377
# [flaml.automl: 12-15 00:40:46] {3166} INFO - iteration 39, current learner rf
# [flaml.automl: 12-15 00:40:52] {3343} INFO -  at 313.6s,	estimator rf's best error=3.3377,	best estimator rf's best error=3.3377
# [flaml.automl: 12-15 00:40:52] {3166} INFO - iteration 40, current learner rf
# [flaml.automl: 12-15 00:41:06] {3343} INFO -  at 327.4s,	estimator rf's best error=3.3377,	best estimator rf's best error=3.3377
# [flaml.automl: 12-15 00:41:06] {3166} INFO - iteration 41, current learner rf
# [flaml.automl: 12-15 00:41:12] {3343} INFO -  at 333.6s,	estimator rf's best error=3.3377,	best estimator rf's best error=3.3377
# [flaml.automl: 12-15 00:41:12] {3166} INFO - iteration 42, current learner rf
# [flaml.automl: 12-15 00:41:20] {3343} INFO -  at 341.8s,	estimator rf's best error=3.3377,	best estimator rf's best error=3.3377
# [flaml.automl: 12-15 00:41:20] {3166} INFO - iteration 43, current learner rf
# [flaml.automl: 12-15 00:41:32] {3343} INFO -  at 353.4s,	estimator rf's best error=3.3377,	best estimator rf's best error=3.3377
# [flaml.automl: 12-15 00:41:32] {3166} INFO - iteration 44, current learner rf
# [flaml.automl: 12-15 00:41:40] {3343} INFO -  at 361.5s,	estimator rf's best error=3.3377,	best estimator rf's best error=3.3377
# [flaml.automl: 12-15 00:41:40] {3166} INFO - iteration 45, current learner rf
# [flaml.automl: 12-15 00:41:51] {3343} INFO -  at 372.1s,	estimator rf's best error=3.3377,	best estimator rf's best error=3.3377
# [flaml.automl: 12-15 00:41:51] {3166} INFO - iteration 46, current learner rf
# [flaml.automl: 12-15 00:42:07] {3343} INFO -  at 388.5s,	estimator rf's best error=3.3251,	best estimator rf's best error=3.3251
# [flaml.automl: 12-15 00:42:07] {3166} INFO - iteration 47, current learner rf
# [flaml.automl: 12-15 00:42:14] {3343} INFO -  at 396.1s,	estimator rf's best error=3.3251,	best estimator rf's best error=3.3251
# [flaml.automl: 12-15 00:42:14] {3166} INFO - iteration 48, current learner rf
# [flaml.automl: 12-15 00:42:24] {3343} INFO -  at 405.8s,	estimator rf's best error=3.3251,	best estimator rf's best error=3.3251
# [flaml.automl: 12-15 00:42:24] {3166} INFO - iteration 49, current learner rf
# [flaml.automl: 12-15 00:42:52] {3343} INFO -  at 433.5s,	estimator rf's best error=3.3251,	best estimator rf's best error=3.3251
# [flaml.automl: 12-15 00:42:52] {3166} INFO - iteration 50, current learner rf
# [flaml.automl: 12-15 00:43:17] {3343} INFO -  at 459.0s,	estimator rf's best error=3.3251,	best estimator rf's best error=3.3251
# [flaml.automl: 12-15 00:43:17] {3166} INFO - iteration 51, current learner rf
# [flaml.automl: 12-15 00:43:27] {3343} INFO -  at 469.1s,	estimator rf's best error=3.3251,	best estimator rf's best error=3.3251
# [flaml.automl: 12-15 00:43:28] {3166} INFO - iteration 52, current learner rf
# [flaml.automl: 12-15 00:43:49] {3343} INFO -  at 490.5s,	estimator rf's best error=3.3251,	best estimator rf's best error=3.3251
# [flaml.automl: 12-15 00:43:49] {3166} INFO - iteration 53, current learner rf
# [flaml.automl: 12-15 00:44:00] {3343} INFO -  at 501.8s,	estimator rf's best error=3.3251,	best estimator rf's best error=3.3251
# [flaml.automl: 12-15 00:44:00] {3166} INFO - iteration 54, current learner rf
# [flaml.automl: 12-15 00:44:11] {3343} INFO -  at 512.9s,	estimator rf's best error=3.3251,	best estimator rf's best error=3.3251
# [flaml.automl: 12-15 00:44:11] {3166} INFO - iteration 55, current learner rf
# [flaml.automl: 12-15 00:44:34] {3343} INFO -  at 535.3s,	estimator rf's best error=3.3251,	best estimator rf's best error=3.3251
# [flaml.automl: 12-15 00:44:34] {3166} INFO - iteration 56, current learner rf
# [flaml.automl: 12-15 00:44:57] {3343} INFO -  at 558.5s,	estimator rf's best error=3.3251,	best estimator rf's best error=3.3251
# [flaml.automl: 12-15 00:44:57] {3166} INFO - iteration 57, current learner rf
# [flaml.automl: 12-15 00:45:07] {3343} INFO -  at 569.1s,	estimator rf's best error=3.3251,	best estimator rf's best error=3.3251
# [flaml.automl: 12-15 00:45:07] {3166} INFO - iteration 58, current learner rf
# [flaml.automl: 12-15 00:45:45] {3343} INFO -  at 606.4s,	estimator rf's best error=3.3251,	best estimator rf's best error=3.3251
# [flaml.automl: 12-15 00:45:45] {3166} INFO - iteration 59, current learner rf
# [flaml.automl: 12-15 00:46:08] {3343} INFO -  at 629.8s,	estimator rf's best error=3.3251,	best estimator rf's best error=3.3251
# [flaml.automl: 12-15 00:46:08] {3166} INFO - iteration 60, current learner rf
# [flaml.automl: 12-15 00:46:32] {3343} INFO -  at 653.6s,	estimator rf's best error=3.3251,	best estimator rf's best error=3.3251
# [flaml.automl: 12-15 00:46:32] {3166} INFO - iteration 61, current learner rf
# [flaml.automl: 12-15 00:47:08] {3343} INFO -  at 689.7s,	estimator rf's best error=3.3251,	best estimator rf's best error=3.3251
# [flaml.automl: 12-15 00:47:08] {3166} INFO - iteration 62, current learner rf
# [flaml.automl: 12-15 00:48:02] {3343} INFO -  at 743.9s,	estimator rf's best error=3.3251,	best estimator rf's best error=3.3251
# [flaml.automl: 12-15 00:48:02] {3166} INFO - iteration 63, current learner rf
# [flaml.automl: 12-15 00:48:17] {3343} INFO -  at 759.0s,	estimator rf's best error=3.3251,	best estimator rf's best error=3.3251
# [flaml.automl: 12-15 00:48:17] {3166} INFO - iteration 64, current learner rf
# [flaml.automl: 12-15 00:48:47] {3343} INFO -  at 789.1s,	estimator rf's best error=3.3251,	best estimator rf's best error=3.3251
# [flaml.automl: 12-15 00:48:47] {3166} INFO - iteration 65, current learner rf
# [flaml.automl: 12-15 00:49:17] {3343} INFO -  at 818.9s,	estimator rf's best error=3.3251,	best estimator rf's best error=3.3251
# [flaml.automl: 12-15 00:49:17] {3166} INFO - iteration 66, current learner rf
# [flaml.automl: 12-15 00:49:37] {3343} INFO -  at 838.7s,	estimator rf's best error=3.3251,	best estimator rf's best error=3.3251
# [flaml.automl: 12-15 00:49:37] {3166} INFO - iteration 67, current learner rf
# [flaml.automl: 12-15 00:50:21] {3343} INFO -  at 882.1s,	estimator rf's best error=3.3251,	best estimator rf's best error=3.3251
# [flaml.automl: 12-15 00:50:21] {3166} INFO - iteration 68, current learner rf
# [flaml.automl: 12-15 00:50:42] {3343} INFO -  at 903.4s,	estimator rf's best error=3.3251,	best estimator rf's best error=3.3251
# [flaml.automl: 12-15 00:50:42] {3166} INFO - iteration 69, current learner rf
# [flaml.automl: 12-15 00:51:23] {3343} INFO -  at 944.7s,	estimator rf's best error=3.3251,	best estimator rf's best error=3.3251
# [flaml.automl: 12-15 00:51:23] {3166} INFO - iteration 70, current learner rf
# [flaml.automl: 12-15 00:52:03] {3343} INFO -  at 985.0s,	estimator rf's best error=3.3251,	best estimator rf's best error=3.3251
# [flaml.automl: 12-15 00:52:03] {3166} INFO - iteration 71, current learner rf
# [flaml.automl: 12-15 00:52:23] {3343} INFO -  at 1004.5s,	estimator rf's best error=3.3251,	best estimator rf's best error=3.3251
# [flaml.automl: 12-15 00:52:23] {3166} INFO - iteration 72, current learner rf
# [flaml.automl: 12-15 00:52:44] {3343} INFO -  at 1025.9s,	estimator rf's best error=3.3251,	best estimator rf's best error=3.3251
# [flaml.automl: 12-15 00:52:44] {3166} INFO - iteration 73, current learner rf
# [flaml.automl: 12-15 00:53:27] {3343} INFO -  at 1069.0s,	estimator rf's best error=3.3251,	best estimator rf's best error=3.3251
# [flaml.automl: 12-15 00:53:27] {3166} INFO - iteration 74, current learner rf
# [flaml.automl: 12-15 00:54:01] {3343} INFO -  at 1102.3s,	estimator rf's best error=3.3251,	best estimator rf's best error=3.3251
# [flaml.automl: 12-15 00:54:01] {3166} INFO - iteration 75, current learner rf
# [flaml.automl: 12-15 00:54:29] {3343} INFO -  at 1130.2s,	estimator rf's best error=3.3251,	best estimator rf's best error=3.3251
# [flaml.automl: 12-15 00:54:29] {3166} INFO - iteration 76, current learner rf
# [flaml.automl: 12-15 00:54:53] {3343} INFO -  at 1154.4s,	estimator rf's best error=3.3251,	best estimator rf's best error=3.3251
# [flaml.automl: 12-15 00:54:53] {3166} INFO - iteration 77, current learner rf
# [flaml.automl: 12-15 00:55:28] {3343} INFO -  at 1189.4s,	estimator rf's best error=3.3251,	best estimator rf's best error=3.3251
# [flaml.automl: 12-15 00:55:28] {3166} INFO - iteration 78, current learner rf
# [flaml.automl: 12-15 00:55:53] {3343} INFO -  at 1215.0s,	estimator rf's best error=3.3251,	best estimator rf's best error=3.3251
# [flaml.automl: 12-15 00:55:53] {3166} INFO - iteration 79, current learner rf
# [flaml.automl: 12-15 00:56:28] {3343} INFO -  at 1249.8s,	estimator rf's best error=3.3251,	best estimator rf's best error=3.3251
# [flaml.automl: 12-15 00:56:28] {3166} INFO - iteration 80, current learner rf
# [flaml.automl: 12-15 00:56:51] {3343} INFO -  at 1272.7s,	estimator rf's best error=3.3251,	best estimator rf's best error=3.3251
# [flaml.automl: 12-15 00:56:51] {3166} INFO - iteration 81, current learner rf
# [flaml.automl: 12-15 00:57:29] {3343} INFO -  at 1311.0s,	estimator rf's best error=3.3251,	best estimator rf's best error=3.3251
# [flaml.automl: 12-15 00:57:29] {3166} INFO - iteration 82, current learner rf
# [flaml.automl: 12-15 00:57:49] {3343} INFO -  at 1330.5s,	estimator rf's best error=3.3251,	best estimator rf's best error=3.3251
# [flaml.automl: 12-15 00:57:49] {3166} INFO - iteration 83, current learner rf
# [flaml.automl: 12-15 00:58:17] {3343} INFO -  at 1358.2s,	estimator rf's best error=3.3251,	best estimator rf's best error=3.3251
# [flaml.automl: 12-15 00:58:17] {3166} INFO - iteration 84, current learner rf
# [flaml.automl: 12-15 00:58:36] {3343} INFO -  at 1377.5s,	estimator rf's best error=3.3251,	best estimator rf's best error=3.3251
# [flaml.automl: 12-15 00:58:36] {3166} INFO - iteration 85, current learner rf
# [flaml.automl: 12-15 00:58:55] {3343} INFO -  at 1396.8s,	estimator rf's best error=3.3251,	best estimator rf's best error=3.3251
# [flaml.automl: 12-15 00:58:55] {3166} INFO - iteration 86, current learner rf
# [flaml.automl: 12-15 00:59:25] {3343} INFO -  at 1427.0s,	estimator rf's best error=3.3251,	best estimator rf's best error=3.3251
# [flaml.automl: 12-15 00:59:33] {3602} INFO - retrain rf for 7.3s
# [flaml.automl: 12-15 00:59:33] {3609} INFO - retrained model: RandomForestRegressor(max_features=0.49054652623349737, max_leaf_nodes=772,
#                       n_estimators=228, n_jobs=-1)
# [flaml.automl: 12-15 00:59:33] {2901} INFO - fit succeeded
# [flaml.automl: 12-15 00:59:33] {2902} INFO - Time taken to find the best model: 388.53800225257874
# [flaml.automl: 12-15 00:59:33] {2599} INFO - task = regression
# [flaml.automl: 12-15 00:59:33] {2601} INFO - Data split method: uniform
# [flaml.automl: 12-15 00:59:33] {2604} INFO - Evaluation method: cv
# [flaml.automl: 12-15 00:59:33] {2726} INFO - Minimizing error metric: rmse
# [flaml.automl: 12-15 00:59:33] {2870} INFO - List of ML learners in AutoML Run: ['rf']
# [flaml.automl: 12-15 00:59:33] {3166} INFO - iteration 0, current learner rf
# [flaml.automl: 12-15 00:59:35] {3296} INFO - Estimated sufficient time budget=14828s. Estimated necessary time budget=15s.
# [flaml.automl: 12-15 00:59:35] {3343} INFO -  at 1.7s,	estimator rf's best error=6.8016,	best estimator rf's best error=6.8016
# [flaml.automl: 12-15 00:59:35] {3166} INFO - iteration 1, current learner rf
# [flaml.automl: 12-15 00:59:36] {3343} INFO -  at 3.1s,	estimator rf's best error=5.1365,	best estimator rf's best error=5.1365
# [flaml.automl: 12-15 00:59:36] {3166} INFO - iteration 2, current learner rf
# [flaml.automl: 12-15 00:59:38] {3343} INFO -  at 5.1s,	estimator rf's best error=5.1365,	best estimator rf's best error=5.1365
# [flaml.automl: 12-15 00:59:38] {3166} INFO - iteration 3, current learner rf
# [flaml.automl: 12-15 00:59:40] {3343} INFO -  at 7.1s,	estimator rf's best error=4.5003,	best estimator rf's best error=4.5003
# [flaml.automl: 12-15 00:59:40] {3166} INFO - iteration 4, current learner rf
# [flaml.automl: 12-15 00:59:42] {3343} INFO -  at 8.6s,	estimator rf's best error=3.9809,	best estimator rf's best error=3.9809
# [flaml.automl: 12-15 00:59:42] {3166} INFO - iteration 5, current learner rf
# [flaml.automl: 12-15 00:59:43] {3343} INFO -  at 10.1s,	estimator rf's best error=3.9809,	best estimator rf's best error=3.9809
# [flaml.automl: 12-15 00:59:43] {3166} INFO - iteration 6, current learner rf
# [flaml.automl: 12-15 00:59:45] {3343} INFO -  at 12.2s,	estimator rf's best error=3.8222,	best estimator rf's best error=3.8222
# [flaml.automl: 12-15 00:59:45] {3166} INFO - iteration 7, current learner rf
# [flaml.automl: 12-15 00:59:47] {3343} INFO -  at 14.3s,	estimator rf's best error=3.8222,	best estimator rf's best error=3.8222
# [flaml.automl: 12-15 00:59:47] {3166} INFO - iteration 8, current learner rf
# [flaml.automl: 12-15 00:59:50] {3343} INFO -  at 16.9s,	estimator rf's best error=3.5617,	best estimator rf's best error=3.5617
# [flaml.automl: 12-15 00:59:50] {3166} INFO - iteration 9, current learner rf
# [flaml.automl: 12-15 00:59:52] {3343} INFO -  at 18.9s,	estimator rf's best error=3.5617,	best estimator rf's best error=3.5617
# [flaml.automl: 12-15 00:59:52] {3166} INFO - iteration 10, current learner rf
# [flaml.automl: 12-15 00:59:54] {3343} INFO -  at 21.0s,	estimator rf's best error=3.5617,	best estimator rf's best error=3.5617
# [flaml.automl: 12-15 00:59:54] {3166} INFO - iteration 11, current learner rf
# [flaml.automl: 12-15 00:59:59] {3343} INFO -  at 25.7s,	estimator rf's best error=3.5598,	best estimator rf's best error=3.5598
# [flaml.automl: 12-15 00:59:59] {3166} INFO - iteration 12, current learner rf
# [flaml.automl: 12-15 01:00:01] {3343} INFO -  at 28.0s,	estimator rf's best error=3.5598,	best estimator rf's best error=3.5598
# [flaml.automl: 12-15 01:00:01] {3166} INFO - iteration 13, current learner rf
# [flaml.automl: 12-15 01:00:12] {3343} INFO -  at 38.6s,	estimator rf's best error=3.4073,	best estimator rf's best error=3.4073
# [flaml.automl: 12-15 01:00:12] {3166} INFO - iteration 14, current learner rf
# [flaml.automl: 12-15 01:00:19] {3343} INFO -  at 45.6s,	estimator rf's best error=3.4073,	best estimator rf's best error=3.4073
# [flaml.automl: 12-15 01:00:19] {3166} INFO - iteration 15, current learner rf
# [flaml.automl: 12-15 01:00:38] {3343} INFO -  at 65.2s,	estimator rf's best error=3.3203,	best estimator rf's best error=3.3203
# [flaml.automl: 12-15 01:00:38] {3166} INFO - iteration 16, current learner rf
# [flaml.automl: 12-15 01:00:47] {3343} INFO -  at 73.7s,	estimator rf's best error=3.3203,	best estimator rf's best error=3.3203
# [flaml.automl: 12-15 01:00:47] {3166} INFO - iteration 17, current learner rf
# [flaml.automl: 12-15 01:01:37] {3343} INFO -  at 123.8s,	estimator rf's best error=3.3203,	best estimator rf's best error=3.3203
# [flaml.automl: 12-15 01:01:37] {3166} INFO - iteration 18, current learner rf
# [flaml.automl: 12-15 01:02:20] {3343} INFO -  at 166.6s,	estimator rf's best error=3.3094,	best estimator rf's best error=3.3094
# [flaml.automl: 12-15 01:02:20] {3166} INFO - iteration 19, current learner rf
# [flaml.automl: 12-15 01:03:40] {3343} INFO -  at 247.5s,	estimator rf's best error=3.3030,	best estimator rf's best error=3.3030
# [flaml.automl: 12-15 01:03:41] {3166} INFO - iteration 20, current learner rf
# [flaml.automl: 12-15 01:04:24] {3343} INFO -  at 290.8s,	estimator rf's best error=3.2986,	best estimator rf's best error=3.2986
# [flaml.automl: 12-15 01:04:24] {3166} INFO - iteration 21, current learner rf
# [flaml.automl: 12-15 01:04:42] {3343} INFO -  at 308.8s,	estimator rf's best error=3.2986,	best estimator rf's best error=3.2986
# [flaml.automl: 12-15 01:04:42] {3166} INFO - iteration 22, current learner rf
# [flaml.automl: 12-15 01:06:20] {3343} INFO -  at 406.5s,	estimator rf's best error=3.2986,	best estimator rf's best error=3.2986
# [flaml.automl: 12-15 01:06:20] {3166} INFO - iteration 23, current learner rf
# [flaml.automl: 12-15 01:07:08] {3343} INFO -  at 454.5s,	estimator rf's best error=3.2986,	best estimator rf's best error=3.2986
# [flaml.automl: 12-15 01:07:08] {3166} INFO - iteration 24, current learner rf
# [flaml.automl: 12-15 01:07:45] {3343} INFO -  at 492.2s,	estimator rf's best error=3.2986,	best estimator rf's best error=3.2986
# [flaml.automl: 12-15 01:07:45] {3166} INFO - iteration 25, current learner rf
# [flaml.automl: 12-15 01:09:13] {3343} INFO -  at 580.0s,	estimator rf's best error=3.2986,	best estimator rf's best error=3.2986
# [flaml.automl: 12-15 01:09:13] {3166} INFO - iteration 26, current learner rf
# [flaml.automl: 12-15 01:09:33] {3343} INFO -  at 600.4s,	estimator rf's best error=3.2986,	best estimator rf's best error=3.2986
# [flaml.automl: 12-15 01:09:33] {3166} INFO - iteration 27, current learner rf
# [flaml.automl: 12-15 01:10:13] {3343} INFO -  at 639.9s,	estimator rf's best error=3.2986,	best estimator rf's best error=3.2986
# [flaml.automl: 12-15 01:10:13] {3166} INFO - iteration 28, current learner rf
# [flaml.automl: 12-15 01:10:58] {3343} INFO -  at 685.1s,	estimator rf's best error=3.2986,	best estimator rf's best error=3.2986
# [flaml.automl: 12-15 01:10:58] {3166} INFO - iteration 29, current learner rf
# [flaml.automl: 12-15 01:11:21] {3343} INFO -  at 708.2s,	estimator rf's best error=3.2986,	best estimator rf's best error=3.2986
# [flaml.automl: 12-15 01:11:21] {3166} INFO - iteration 30, current learner rf
# [flaml.automl: 12-15 01:11:58] {3343} INFO -  at 744.7s,	estimator rf's best error=3.2986,	best estimator rf's best error=3.2986
# [flaml.automl: 12-15 01:11:58] {3166} INFO - iteration 31, current learner rf
# [flaml.automl: 12-15 01:12:47] {3343} INFO -  at 794.3s,	estimator rf's best error=3.2986,	best estimator rf's best error=3.2986
# [flaml.automl: 12-15 01:12:47] {3166} INFO - iteration 32, current learner rf
# [flaml.automl: 12-15 01:13:25] {3343} INFO -  at 832.3s,	estimator rf's best error=3.2986,	best estimator rf's best error=3.2986
# [flaml.automl: 12-15 01:13:25] {3166} INFO - iteration 33, current learner rf
# [flaml.automl: 12-15 01:14:47] {3343} INFO -  at 914.4s,	estimator rf's best error=3.2955,	best estimator rf's best error=3.2955
# [flaml.automl: 12-15 01:14:47] {3166} INFO - iteration 34, current learner rf
# [flaml.automl: 12-15 01:15:29] {3343} INFO -  at 955.6s,	estimator rf's best error=3.2955,	best estimator rf's best error=3.2955
# [flaml.automl: 12-15 01:15:29] {3166} INFO - iteration 35, current learner rf
# [flaml.automl: 12-15 01:16:10] {3343} INFO -  at 997.1s,	estimator rf's best error=3.2955,	best estimator rf's best error=3.2955
# [flaml.automl: 12-15 01:16:10] {3166} INFO - iteration 36, current learner rf
# [flaml.automl: 12-15 01:18:13] {3343} INFO -  at 1120.4s,	estimator rf's best error=3.2926,	best estimator rf's best error=3.2926
# [flaml.automl: 12-15 01:18:13] {3166} INFO - iteration 37, current learner rf
# [flaml.automl: 12-15 01:18:49] {3343} INFO -  at 1156.3s,	estimator rf's best error=3.2926,	best estimator rf's best error=3.2926
# [flaml.automl: 12-15 01:18:49] {3166} INFO - iteration 38, current learner rf
# [flaml.automl: 12-15 01:19:41] {3343} INFO -  at 1208.3s,	estimator rf's best error=3.2926,	best estimator rf's best error=3.2926
# [flaml.automl: 12-15 01:19:41] {3166} INFO - iteration 39, current learner rf
# [flaml.automl: 12-15 01:20:50] {3343} INFO -  at 1276.8s,	estimator rf's best error=3.2926,	best estimator rf's best error=3.2926
# [flaml.automl: 12-15 01:20:50] {3166} INFO - iteration 40, current learner rf
# [flaml.automl: 12-15 01:22:01] {3343} INFO -  at 1348.3s,	estimator rf's best error=3.2926,	best estimator rf's best error=3.2926
# [flaml.automl: 12-15 01:22:19] {3602} INFO - retrain rf for 18.1s
# [flaml.automl: 12-15 01:22:19] {3609} INFO - retrained model: RandomForestRegressor(max_features=0.4554310980664976, max_leaf_nodes=1207,
#                       n_estimators=572, n_jobs=-1)
# [flaml.automl: 12-15 01:22:19] {2901} INFO - fit succeeded
# [flaml.automl: 12-15 01:22:19] {2902} INFO - Time taken to find the best model: 1120.3546528816223
# [flaml.automl: 12-15 01:22:19] {2913} WARNING - Time taken to find the best model is 78% of the provided time budget and not all estimators' hyperparameter search converged. Consider increasing the time budget.
# [flaml.automl: 12-15 01:22:20] {2599} INFO - task = regression
# [flaml.automl: 12-15 01:22:20] {2601} INFO - Data split method: uniform
# [flaml.automl: 12-15 01:22:20] {2604} INFO - Evaluation method: cv
# [flaml.automl: 12-15 01:22:20] {2726} INFO - Minimizing error metric: rmse
# [flaml.automl: 12-15 01:22:20] {2870} INFO - List of ML learners in AutoML Run: ['rf']
# [flaml.automl: 12-15 01:22:20] {3166} INFO - iteration 0, current learner rf
# [flaml.automl: 12-15 01:22:22] {3296} INFO - Estimated sufficient time budget=16678s. Estimated necessary time budget=17s.
# [flaml.automl: 12-15 01:22:22] {3343} INFO -  at 1.9s,	estimator rf's best error=7.0296,	best estimator rf's best error=7.0296
# [flaml.automl: 12-15 01:22:22] {3166} INFO - iteration 1, current learner rf
# [flaml.automl: 12-15 01:22:23] {3343} INFO -  at 3.1s,	estimator rf's best error=4.9366,	best estimator rf's best error=4.9366
# [flaml.automl: 12-15 01:22:23] {3166} INFO - iteration 2, current learner rf
# [flaml.automl: 12-15 01:22:25] {3343} INFO -  at 4.9s,	estimator rf's best error=4.9366,	best estimator rf's best error=4.9366
# [flaml.automl: 12-15 01:22:25] {3166} INFO - iteration 3, current learner rf
# [flaml.automl: 12-15 01:22:27] {3343} INFO -  at 7.1s,	estimator rf's best error=4.4644,	best estimator rf's best error=4.4644
# [flaml.automl: 12-15 01:22:27] {3166} INFO - iteration 4, current learner rf
# [flaml.automl: 12-15 01:22:29] {3343} INFO -  at 9.2s,	estimator rf's best error=3.9335,	best estimator rf's best error=3.9335
# [flaml.automl: 12-15 01:22:29] {3166} INFO - iteration 5, current learner rf
# [flaml.automl: 12-15 01:22:31] {3343} INFO -  at 11.2s,	estimator rf's best error=3.9335,	best estimator rf's best error=3.9335
# [flaml.automl: 12-15 01:22:31] {3166} INFO - iteration 6, current learner rf
# [flaml.automl: 12-15 01:22:33] {3343} INFO -  at 12.9s,	estimator rf's best error=3.7943,	best estimator rf's best error=3.7943
# [flaml.automl: 12-15 01:22:33] {3166} INFO - iteration 7, current learner rf
# [flaml.automl: 12-15 01:22:35] {3343} INFO -  at 14.6s,	estimator rf's best error=3.7943,	best estimator rf's best error=3.7943
# [flaml.automl: 12-15 01:22:35] {3166} INFO - iteration 8, current learner rf
# [flaml.automl: 12-15 01:22:38] {3343} INFO -  at 17.9s,	estimator rf's best error=3.5774,	best estimator rf's best error=3.5774
# [flaml.automl: 12-15 01:22:38] {3166} INFO - iteration 9, current learner rf
# [flaml.automl: 12-15 01:22:40] {3343} INFO -  at 19.5s,	estimator rf's best error=3.5774,	best estimator rf's best error=3.5774
# [flaml.automl: 12-15 01:22:40] {3166} INFO - iteration 10, current learner rf
# [flaml.automl: 12-15 01:22:41] {3343} INFO -  at 21.3s,	estimator rf's best error=3.5774,	best estimator rf's best error=3.5774
# [flaml.automl: 12-15 01:22:41] {3166} INFO - iteration 11, current learner rf
# [flaml.automl: 12-15 01:22:47] {3343} INFO -  at 26.4s,	estimator rf's best error=3.5715,	best estimator rf's best error=3.5715
# [flaml.automl: 12-15 01:22:47] {3166} INFO - iteration 12, current learner rf
# [flaml.automl: 12-15 01:22:50] {3343} INFO -  at 29.9s,	estimator rf's best error=3.5715,	best estimator rf's best error=3.5715
# [flaml.automl: 12-15 01:22:50] {3166} INFO - iteration 13, current learner rf
# [flaml.automl: 12-15 01:23:00] {3343} INFO -  at 40.1s,	estimator rf's best error=3.4205,	best estimator rf's best error=3.4205
# [flaml.automl: 12-15 01:23:00] {3166} INFO - iteration 14, current learner rf
# [flaml.automl: 12-15 01:23:05] {3343} INFO -  at 45.2s,	estimator rf's best error=3.4205,	best estimator rf's best error=3.4205
# [flaml.automl: 12-15 01:23:05] {3166} INFO - iteration 15, current learner rf
# [flaml.automl: 12-15 01:23:24] {3343} INFO -  at 64.1s,	estimator rf's best error=3.3301,	best estimator rf's best error=3.3301
# [flaml.automl: 12-15 01:23:24] {3166} INFO - iteration 16, current learner rf
# [flaml.automl: 12-15 01:23:32] {3343} INFO -  at 71.4s,	estimator rf's best error=3.3301,	best estimator rf's best error=3.3301
# [flaml.automl: 12-15 01:23:32] {3166} INFO - iteration 17, current learner rf
# [flaml.automl: 12-15 01:24:18] {3343} INFO -  at 118.0s,	estimator rf's best error=3.3301,	best estimator rf's best error=3.3301
# [flaml.automl: 12-15 01:24:18] {3166} INFO - iteration 18, current learner rf
# [flaml.automl: 12-15 01:25:01] {3343} INFO -  at 161.0s,	estimator rf's best error=3.3258,	best estimator rf's best error=3.3258
# [flaml.automl: 12-15 01:25:01] {3166} INFO - iteration 19, current learner rf
# [flaml.automl: 12-15 01:26:24] {3343} INFO -  at 243.4s,	estimator rf's best error=3.3162,	best estimator rf's best error=3.3162
# [flaml.automl: 12-15 01:26:24] {3166} INFO - iteration 20, current learner rf
# [flaml.automl: 12-15 01:27:06] {3343} INFO -  at 285.8s,	estimator rf's best error=3.3162,	best estimator rf's best error=3.3162
# [flaml.automl: 12-15 01:27:06] {3166} INFO - iteration 21, current learner rf
# [flaml.automl: 12-15 01:27:48] {3343} INFO -  at 328.3s,	estimator rf's best error=3.3099,	best estimator rf's best error=3.3099
# [flaml.automl: 12-15 01:27:48] {3166} INFO - iteration 22, current learner rf
# [flaml.automl: 12-15 01:28:48] {3343} INFO -  at 388.0s,	estimator rf's best error=3.3099,	best estimator rf's best error=3.3099
# [flaml.automl: 12-15 01:28:48] {3166} INFO - iteration 23, current learner rf
# [flaml.automl: 12-15 01:29:42] {3343} INFO -  at 441.8s,	estimator rf's best error=3.3099,	best estimator rf's best error=3.3099
# [flaml.automl: 12-15 01:29:42] {3166} INFO - iteration 24, current learner rf
# [flaml.automl: 12-15 01:30:18] {3343} INFO -  at 477.5s,	estimator rf's best error=3.3099,	best estimator rf's best error=3.3099
# [flaml.automl: 12-15 01:30:18] {3166} INFO - iteration 25, current learner rf
# [flaml.automl: 12-15 01:31:42] {3343} INFO -  at 561.8s,	estimator rf's best error=3.3099,	best estimator rf's best error=3.3099
# [flaml.automl: 12-15 01:31:42] {3166} INFO - iteration 26, current learner rf
# [flaml.automl: 12-15 01:32:01] {3343} INFO -  at 580.4s,	estimator rf's best error=3.3099,	best estimator rf's best error=3.3099
# [flaml.automl: 12-15 01:32:01] {3166} INFO - iteration 27, current learner rf
# [flaml.automl: 12-15 01:32:44] {3343} INFO -  at 623.4s,	estimator rf's best error=3.3099,	best estimator rf's best error=3.3099
# [flaml.automl: 12-15 01:32:44] {3166} INFO - iteration 28, current learner rf
# [flaml.automl: 12-15 01:33:22] {3343} INFO -  at 662.1s,	estimator rf's best error=3.3099,	best estimator rf's best error=3.3099
# [flaml.automl: 12-15 01:33:22] {3166} INFO - iteration 29, current learner rf
# [flaml.automl: 12-15 01:33:43] {3343} INFO -  at 682.7s,	estimator rf's best error=3.3099,	best estimator rf's best error=3.3099
# [flaml.automl: 12-15 01:33:43] {3166} INFO - iteration 30, current learner rf
# [flaml.automl: 12-15 01:34:53] {3343} INFO -  at 752.4s,	estimator rf's best error=3.3099,	best estimator rf's best error=3.3099
# [flaml.automl: 12-15 01:34:53] {3166} INFO - iteration 31, current learner rf
# [flaml.automl: 12-15 01:35:42] {3343} INFO -  at 801.8s,	estimator rf's best error=3.3099,	best estimator rf's best error=3.3099
# [flaml.automl: 12-15 01:35:42] {3166} INFO - iteration 32, current learner rf
# [flaml.automl: 12-15 01:36:15] {3343} INFO -  at 835.2s,	estimator rf's best error=3.3099,	best estimator rf's best error=3.3099
# [flaml.automl: 12-15 01:36:15] {3166} INFO - iteration 33, current learner rf
# [flaml.automl: 12-15 01:37:43] {3343} INFO -  at 923.2s,	estimator rf's best error=3.3099,	best estimator rf's best error=3.3099
# [flaml.automl: 12-15 01:37:43] {3166} INFO - iteration 34, current learner rf
# [flaml.automl: 12-15 01:38:02] {3343} INFO -  at 941.6s,	estimator rf's best error=3.3099,	best estimator rf's best error=3.3099
# [flaml.automl: 12-15 01:38:02] {3166} INFO - iteration 35, current learner rf
# [flaml.automl: 12-15 01:38:23] {3343} INFO -  at 963.2s,	estimator rf's best error=3.3099,	best estimator rf's best error=3.3099
# [flaml.automl: 12-15 01:38:23] {3166} INFO - iteration 36, current learner rf
# [flaml.automl: 12-15 01:39:45] {3343} INFO -  at 1044.5s,	estimator rf's best error=3.3068,	best estimator rf's best error=3.3068
# [flaml.automl: 12-15 01:39:45] {3166} INFO - iteration 37, current learner rf
# [flaml.automl: 12-15 01:42:01] {3343} INFO -  at 1180.9s,	estimator rf's best error=3.3068,	best estimator rf's best error=3.3068
# [flaml.automl: 12-15 01:42:01] {3166} INFO - iteration 38, current learner rf
# [flaml.automl: 12-15 01:42:33] {3343} INFO -  at 1212.8s,	estimator rf's best error=3.3068,	best estimator rf's best error=3.3068
# [flaml.automl: 12-15 01:42:33] {3166} INFO - iteration 39, current learner rf
# [flaml.automl: 12-15 01:43:36] {3343} INFO -  at 1275.9s,	estimator rf's best error=3.3068,	best estimator rf's best error=3.3068
# [flaml.automl: 12-15 01:43:36] {3166} INFO - iteration 40, current learner rf
# [flaml.automl: 12-15 01:44:23] {3343} INFO -  at 1322.7s,	estimator rf's best error=3.3068,	best estimator rf's best error=3.3068
# [flaml.automl: 12-15 01:44:23] {3166} INFO - iteration 41, current learner rf
# [flaml.automl: 12-15 01:45:21] {3343} INFO -  at 1381.2s,	estimator rf's best error=3.3068,	best estimator rf's best error=3.3068
# [flaml.automl: 12-15 01:45:42] {3602} INFO - retrain rf for 20.1s
# [flaml.automl: 12-15 01:45:42] {3609} INFO - retrained model: RandomForestRegressor(max_features=0.5084624412875598, max_leaf_nodes=1136,
#                       n_estimators=519, n_jobs=-1)
# [flaml.automl: 12-15 01:45:42] {2901} INFO - fit succeeded
# [flaml.automl: 12-15 01:45:42] {2902} INFO - Time taken to find the best model: 1044.5170822143555
# [flaml.automl: 12-15 01:45:42] {2913} WARNING - Time taken to find the best model is 73% of the provided time budget and not all estimators' hyperparameter search converged. Consider increasing the time budget.
# [flaml.automl: 12-15 01:45:42] {2599} INFO - task = regression
# [flaml.automl: 12-15 01:45:42] {2601} INFO - Data split method: uniform
# [flaml.automl: 12-15 01:45:42] {2604} INFO - Evaluation method: cv
# [flaml.automl: 12-15 01:45:42] {2726} INFO - Minimizing error metric: rmse
# [flaml.automl: 12-15 01:45:42] {2870} INFO - List of ML learners in AutoML Run: ['rf']
# [flaml.automl: 12-15 01:45:42] {3166} INFO - iteration 0, current learner rf
# [flaml.automl: 12-15 01:45:44] {3296} INFO - Estimated sufficient time budget=15476s. Estimated necessary time budget=15s.
# [flaml.automl: 12-15 01:45:44] {3343} INFO -  at 1.9s,	estimator rf's best error=6.5930,	best estimator rf's best error=6.5930
# [flaml.automl: 12-15 01:45:44] {3166} INFO - iteration 1, current learner rf
# [flaml.automl: 12-15 01:45:46] {3343} INFO -  at 3.4s,	estimator rf's best error=5.1824,	best estimator rf's best error=5.1824
# [flaml.automl: 12-15 01:45:46] {3166} INFO - iteration 2, current learner rf
# [flaml.automl: 12-15 01:45:47] {3343} INFO -  at 4.5s,	estimator rf's best error=5.1824,	best estimator rf's best error=5.1824
# [flaml.automl: 12-15 01:45:47] {3166} INFO - iteration 3, current learner rf
# [flaml.automl: 12-15 01:45:49] {3343} INFO -  at 6.5s,	estimator rf's best error=4.3940,	best estimator rf's best error=4.3940
# [flaml.automl: 12-15 01:45:49] {3166} INFO - iteration 4, current learner rf
# [flaml.automl: 12-15 01:45:50] {3343} INFO -  at 8.1s,	estimator rf's best error=4.0003,	best estimator rf's best error=4.0003
# [flaml.automl: 12-15 01:45:50] {3166} INFO - iteration 5, current learner rf
# [flaml.automl: 12-15 01:45:52] {3343} INFO -  at 10.4s,	estimator rf's best error=4.0003,	best estimator rf's best error=4.0003
# [flaml.automl: 12-15 01:45:52] {3166} INFO - iteration 6, current learner rf
# [flaml.automl: 12-15 01:45:54] {3343} INFO -  at 12.4s,	estimator rf's best error=3.8324,	best estimator rf's best error=3.8324
# [flaml.automl: 12-15 01:45:55] {3166} INFO - iteration 7, current learner rf
# [flaml.automl: 12-15 01:45:56] {3343} INFO -  at 14.4s,	estimator rf's best error=3.8324,	best estimator rf's best error=3.8324
# [flaml.automl: 12-15 01:45:56] {3166} INFO - iteration 8, current learner rf
# [flaml.automl: 12-15 01:45:59] {3343} INFO -  at 17.3s,	estimator rf's best error=3.5588,	best estimator rf's best error=3.5588
# [flaml.automl: 12-15 01:45:59] {3166} INFO - iteration 9, current learner rf
# [flaml.automl: 12-15 01:46:01] {3343} INFO -  at 19.2s,	estimator rf's best error=3.5588,	best estimator rf's best error=3.5588
# [flaml.automl: 12-15 01:46:01] {3166} INFO - iteration 10, current learner rf
# [flaml.automl: 12-15 01:46:03] {3343} INFO -  at 21.3s,	estimator rf's best error=3.5588,	best estimator rf's best error=3.5588
# [flaml.automl: 12-15 01:46:03] {3166} INFO - iteration 11, current learner rf
# [flaml.automl: 12-15 01:46:08] {3343} INFO -  at 26.2s,	estimator rf's best error=3.5588,	best estimator rf's best error=3.5588
# [flaml.automl: 12-15 01:46:08] {3166} INFO - iteration 12, current learner rf
# [flaml.automl: 12-15 01:46:10] {3343} INFO -  at 28.3s,	estimator rf's best error=3.5588,	best estimator rf's best error=3.5588
# [flaml.automl: 12-15 01:46:10] {3166} INFO - iteration 13, current learner rf
# [flaml.automl: 12-15 01:46:15] {3343} INFO -  at 32.9s,	estimator rf's best error=3.4166,	best estimator rf's best error=3.4166
# [flaml.automl: 12-15 01:46:15] {3166} INFO - iteration 14, current learner rf
# [flaml.automl: 12-15 01:46:18] {3343} INFO -  at 36.2s,	estimator rf's best error=3.4166,	best estimator rf's best error=3.4166
# [flaml.automl: 12-15 01:46:18] {3166} INFO - iteration 15, current learner rf
# [flaml.automl: 12-15 01:46:27] {3343} INFO -  at 44.9s,	estimator rf's best error=3.4006,	best estimator rf's best error=3.4006
# [flaml.automl: 12-15 01:46:27] {3166} INFO - iteration 16, current learner rf
# [flaml.automl: 12-15 01:46:31] {3343} INFO -  at 48.7s,	estimator rf's best error=3.4006,	best estimator rf's best error=3.4006
# [flaml.automl: 12-15 01:46:31] {3166} INFO - iteration 17, current learner rf
# [flaml.automl: 12-15 01:46:57] {3343} INFO -  at 74.8s,	estimator rf's best error=3.3365,	best estimator rf's best error=3.3365
# [flaml.automl: 12-15 01:46:57] {3166} INFO - iteration 18, current learner rf
# [flaml.automl: 12-15 01:47:48] {3343} INFO -  at 125.5s,	estimator rf's best error=3.3201,	best estimator rf's best error=3.3201
# [flaml.automl: 12-15 01:47:48] {3166} INFO - iteration 19, current learner rf
# [flaml.automl: 12-15 01:49:31] {3343} INFO -  at 229.0s,	estimator rf's best error=3.3201,	best estimator rf's best error=3.3201
# [flaml.automl: 12-15 01:49:31] {3166} INFO - iteration 20, current learner rf
# [flaml.automl: 12-15 01:49:53] {3343} INFO -  at 251.2s,	estimator rf's best error=3.3201,	best estimator rf's best error=3.3201
# [flaml.automl: 12-15 01:49:53] {3166} INFO - iteration 21, current learner rf
# [flaml.automl: 12-15 01:50:17] {3343} INFO -  at 275.2s,	estimator rf's best error=3.3201,	best estimator rf's best error=3.3201
# [flaml.automl: 12-15 01:50:17] {3166} INFO - iteration 22, current learner rf
# [flaml.automl: 12-15 01:52:08] {3343} INFO -  at 385.9s,	estimator rf's best error=3.3201,	best estimator rf's best error=3.3201
# [flaml.automl: 12-15 01:52:08] {3166} INFO - iteration 23, current learner rf
# [flaml.automl: 12-15 01:53:05] {3343} INFO -  at 443.0s,	estimator rf's best error=3.3201,	best estimator rf's best error=3.3201
# [flaml.automl: 12-15 01:53:05] {3166} INFO - iteration 24, current learner rf
# [flaml.automl: 12-15 01:53:49] {3343} INFO -  at 486.4s,	estimator rf's best error=3.3201,	best estimator rf's best error=3.3201
# [flaml.automl: 12-15 01:53:49] {3166} INFO - iteration 25, current learner rf
# [flaml.automl: 12-15 01:55:21] {3343} INFO -  at 579.2s,	estimator rf's best error=3.3201,	best estimator rf's best error=3.3201
# [flaml.automl: 12-15 01:55:21] {3166} INFO - iteration 26, current learner rf
# [flaml.automl: 12-15 01:55:45] {3343} INFO -  at 602.7s,	estimator rf's best error=3.3201,	best estimator rf's best error=3.3201
# [flaml.automl: 12-15 01:55:45] {3166} INFO - iteration 27, current learner rf
# [flaml.automl: 12-15 01:56:30] {3343} INFO -  at 647.6s,	estimator rf's best error=3.3201,	best estimator rf's best error=3.3201
# [flaml.automl: 12-15 01:56:30] {3166} INFO - iteration 28, current learner rf
# [flaml.automl: 12-15 01:57:17] {3343} INFO -  at 695.3s,	estimator rf's best error=3.3201,	best estimator rf's best error=3.3201
# [flaml.automl: 12-15 01:57:17] {3166} INFO - iteration 29, current learner rf
# [flaml.automl: 12-15 01:57:47] {3343} INFO -  at 724.7s,	estimator rf's best error=3.3201,	best estimator rf's best error=3.3201
# [flaml.automl: 12-15 01:57:47] {3166} INFO - iteration 30, current learner rf
# [flaml.automl: 12-15 01:59:01] {3343} INFO -  at 798.8s,	estimator rf's best error=3.3201,	best estimator rf's best error=3.3201
# [flaml.automl: 12-15 01:59:01] {3166} INFO - iteration 31, current learner rf
# [flaml.automl: 12-15 02:00:04] {3343} INFO -  at 862.2s,	estimator rf's best error=3.3201,	best estimator rf's best error=3.3201
# [flaml.automl: 12-15 02:00:04] {3166} INFO - iteration 32, current learner rf
# [flaml.automl: 12-15 02:00:52] {3343} INFO -  at 909.5s,	estimator rf's best error=3.3201,	best estimator rf's best error=3.3201
# [flaml.automl: 12-15 02:00:52] {3166} INFO - iteration 33, current learner rf
# [flaml.automl: 12-15 02:02:29] {3343} INFO -  at 1007.0s,	estimator rf's best error=3.3201,	best estimator rf's best error=3.3201
# [flaml.automl: 12-15 02:02:29] {3166} INFO - iteration 34, current learner rf
# [flaml.automl: 12-15 02:02:54] {3343} INFO -  at 1032.3s,	estimator rf's best error=3.3201,	best estimator rf's best error=3.3201
# [flaml.automl: 12-15 02:02:54] {3166} INFO - iteration 35, current learner rf
# [flaml.automl: 12-15 02:03:21] {3343} INFO -  at 1058.4s,	estimator rf's best error=3.3201,	best estimator rf's best error=3.3201
# [flaml.automl: 12-15 02:03:21] {3166} INFO - iteration 36, current learner rf
# [flaml.automl: 12-15 02:04:45] {3343} INFO -  at 1142.5s,	estimator rf's best error=3.3201,	best estimator rf's best error=3.3201
# [flaml.automl: 12-15 02:04:45] {3166} INFO - iteration 37, current learner rf
# [flaml.automl: 12-15 02:06:04] {3343} INFO -  at 1221.8s,	estimator rf's best error=3.3201,	best estimator rf's best error=3.3201
# [flaml.automl: 12-15 02:06:04] {3166} INFO - iteration 38, current learner rf
# [flaml.automl: 12-15 02:06:31] {3343} INFO -  at 1249.3s,	estimator rf's best error=3.3201,	best estimator rf's best error=3.3201
# [flaml.automl: 12-15 02:06:31] {3166} INFO - iteration 39, current learner rf
# [flaml.automl: 12-15 02:07:44] {3343} INFO -  at 1322.3s,	estimator rf's best error=3.3201,	best estimator rf's best error=3.3201
# [flaml.automl: 12-15 02:07:44] {3166} INFO - iteration 40, current learner rf
# [flaml.automl: 12-15 02:08:06] {3343} INFO -  at 1343.7s,	estimator rf's best error=3.3201,	best estimator rf's best error=3.3201
# [flaml.automl: 12-15 02:08:06] {3166} INFO - iteration 41, current learner rf
# [flaml.automl: 12-15 02:08:27] {3343} INFO -  at 1365.2s,	estimator rf's best error=3.3201,	best estimator rf's best error=3.3201
# [flaml.automl: 12-15 02:08:27] {3166} INFO - iteration 42, current learner rf
# [flaml.automl: 12-15 02:08:53] {3343} INFO -  at 1390.7s,	estimator rf's best error=3.3201,	best estimator rf's best error=3.3201
# [flaml.automl: 12-15 02:09:03] {3602} INFO - retrain rf for 10.4s
# [flaml.automl: 12-15 02:09:03] {3609} INFO - retrained model: RandomForestRegressor(max_features=0.4920275171813018, max_leaf_nodes=1149,
#                       n_estimators=318, n_jobs=-1)
# [flaml.automl: 12-15 02:09:03] {2901} INFO - fit succeeded
# ...
# [flaml.automl: 12-15 03:45:01] {3166} INFO - iteration 7, current learner rf
# [flaml.automl: 12-15 03:45:03] {3343} INFO -  at 15.5s,	estimator rf's best error=3.8744,	best estimator rf's best error=3.8744
# [flaml.automl: 12-15 03:45:03] {3166} INFO - iteration 8, current learner rf
# [flaml.automl: 12-15 03:45:06] {3343} INFO -  at 18.4s,	estimator rf's best error=3.6151,	best estimator rf's best error=3.6151
# [flaml.automl: 12-15 03:45:06] {3166} INFO - iteration 9, current learner rf
# [flaml.automl: 12-15 03:45:08] {3343} INFO -  at 20.4s,	estimator rf's best error=3.6151,	best estimator rf's best error=3.6151
# [flaml.automl: 12-15 03:45:08] {3166} INFO - iteration 10, current learner rf
# [flaml.automl: 12-15 03:45:10] {3343} INFO -  at 22.5s,	estimator rf's best error=3.6151,	best estimator rf's best error=3.6151
# [flaml.automl: 12-15 03:45:10] {3166} INFO - iteration 11, current learner rf
# [flaml.automl: 12-15 03:45:14] {3343} INFO -  at 26.5s,	estimator rf's best error=3.6151,	best estimator rf's best error=3.6151
# [flaml.automl: 12-15 03:45:14] {3166} INFO - iteration 12, current learner rf
# [flaml.automl: 12-15 03:45:16] {3343} INFO -  at 28.2s,	estimator rf's best error=3.6151,	best estimator rf's best error=3.6151
# [flaml.automl: 12-15 03:45:16] {3166} INFO - iteration 13, current learner rf
# [flaml.automl: 12-15 03:45:21] {3343} INFO -  at 33.4s,	estimator rf's best error=3.5015,	best estimator rf's best error=3.5015
# [flaml.automl: 12-15 03:45:21] {3166} INFO - iteration 14, current learner rf
# [flaml.automl: 12-15 03:45:24] {3343} INFO -  at 35.9s,	estimator rf's best error=3.5015,	best estimator rf's best error=3.5015
# [flaml.automl: 12-15 03:45:24] {3166} INFO - iteration 15, current learner rf
# [flaml.automl: 12-15 03:45:32] {3343} INFO -  at 43.8s,	estimator rf's best error=3.4738,	best estimator rf's best error=3.4738
# [flaml.automl: 12-15 03:45:32] {3166} INFO - iteration 16, current learner rf
# [flaml.automl: 12-15 03:45:35] {3343} INFO -  at 47.5s,	estimator rf's best error=3.4738,	best estimator rf's best error=3.4738
# [flaml.automl: 12-15 03:45:35] {3166} INFO - iteration 17, current learner rf
# [flaml.automl: 12-15 03:45:59] {3343} INFO -  at 71.3s,	estimator rf's best error=3.4561,	best estimator rf's best error=3.4561
# [flaml.automl: 12-15 03:45:59] {3166} INFO - iteration 18, current learner rf
# [flaml.automl: 12-15 03:46:48] {3343} INFO -  at 120.4s,	estimator rf's best error=3.4180,	best estimator rf's best error=3.4180
# [flaml.automl: 12-15 03:46:48] {3166} INFO - iteration 19, current learner rf
# [flaml.automl: 12-15 03:48:29] {3343} INFO -  at 221.1s,	estimator rf's best error=3.4180,	best estimator rf's best error=3.4180
# [flaml.automl: 12-15 03:48:29] {3166} INFO - iteration 20, current learner rf
# [flaml.automl: 12-15 03:48:52] {3343} INFO -  at 243.9s,	estimator rf's best error=3.4180,	best estimator rf's best error=3.4180
# [flaml.automl: 12-15 03:48:52] {3166} INFO - iteration 21, current learner rf
# [flaml.automl: 12-15 03:49:13] {3343} INFO -  at 265.0s,	estimator rf's best error=3.4180,	best estimator rf's best error=3.4180
# [flaml.automl: 12-15 03:49:13] {3166} INFO - iteration 22, current learner rf
# [flaml.automl: 12-15 03:51:01] {3343} INFO -  at 373.4s,	estimator rf's best error=3.4085,	best estimator rf's best error=3.4085
# [flaml.automl: 12-15 03:51:01] {3166} INFO - iteration 23, current learner rf
# [flaml.automl: 12-15 03:52:59] {3343} INFO -  at 491.2s,	estimator rf's best error=3.4085,	best estimator rf's best error=3.4085
# [flaml.automl: 12-15 03:52:59] {3166} INFO - iteration 24, current learner rf
# [flaml.automl: 12-15 03:54:37] {3343} INFO -  at 589.3s,	estimator rf's best error=3.4085,	best estimator rf's best error=3.4085
# [flaml.automl: 12-15 03:54:37] {3166} INFO - iteration 25, current learner rf
# [flaml.automl: 12-15 03:58:22] {3343} INFO -  at 814.3s,	estimator rf's best error=3.4085,	best estimator rf's best error=3.4085
# [flaml.automl: 12-15 03:58:22] {3166} INFO - iteration 26, current learner rf
# [flaml.automl: 12-15 03:59:13] {3343} INFO -  at 865.0s,	estimator rf's best error=3.4085,	best estimator rf's best error=3.4085
# [flaml.automl: 12-15 03:59:13] {3166} INFO - iteration 27, current learner rf
# [flaml.automl: 12-15 04:00:57] {3343} INFO -  at 968.8s,	estimator rf's best error=3.4085,	best estimator rf's best error=3.4085
# [flaml.automl: 12-15 04:00:57] {3166} INFO - iteration 28, current learner rf
# [flaml.automl: 12-15 04:02:10] {3343} INFO -  at 1041.8s,	estimator rf's best error=3.4085,	best estimator rf's best error=3.4085
# [flaml.automl: 12-15 04:02:10] {3166} INFO - iteration 29, current learner rf
# [flaml.automl: 12-15 04:03:03] {3343} INFO -  at 1095.4s,	estimator rf's best error=3.4085,	best estimator rf's best error=3.4085
# [flaml.automl: 12-15 04:03:03] {3166} INFO - iteration 30, current learner rf
# [flaml.automl: 12-15 04:05:32] {3343} INFO -  at 1243.8s,	estimator rf's best error=3.4085,	best estimator rf's best error=3.4085
# [flaml.automl: 12-15 04:05:32] {3166} INFO - iteration 31, current learner rf
# [flaml.automl: 12-15 04:07:35] {3343} INFO -  at 1366.7s,	estimator rf's best error=3.4085,	best estimator rf's best error=3.4085
# [flaml.automl: 12-15 04:07:59] {3602} INFO - retrain rf for 24.4s
# [flaml.automl: 12-15 04:07:59] {3609} INFO - retrained model: RandomForestRegressor(max_features=0.45712139133720076, max_leaf_nodes=654,
#                       n_estimators=755, n_jobs=-1)
# [flaml.automl: 12-15 04:07:59] {2901} INFO - fit succeeded
# [flaml.automl: 12-15 04:07:59] {2902} INFO - Time taken to find the best model: 373.4345688819885
# [flaml.automl: 12-15 04:08:00] {2599} INFO - task = regression
# [flaml.automl: 12-15 04:08:00] {2601} INFO - Data split method: uniform
# [flaml.automl: 12-15 04:08:00] {2604} INFO - Evaluation method: cv
# [flaml.automl: 12-15 04:08:00] {2726} INFO - Minimizing error metric: rmse
# [flaml.automl: 12-15 04:08:00] {2870} INFO - List of ML learners in AutoML Run: ['rf']
# [flaml.automl: 12-15 04:08:00] {3166} INFO - iteration 0, current learner rf
# [flaml.automl: 12-15 04:08:02] {3296} INFO - Estimated sufficient time budget=12858s. Estimated necessary time budget=13s.
# [flaml.automl: 12-15 04:08:02] {3343} INFO -  at 1.6s,	estimator rf's best error=6.8693,	best estimator rf's best error=6.8693
# [flaml.automl: 12-15 04:08:02] {3166} INFO - iteration 1, current learner rf
# [flaml.automl: 12-15 04:08:03] {3343} INFO -  at 2.9s,	estimator rf's best error=5.1085,	best estimator rf's best error=5.1085
# [flaml.automl: 12-15 04:08:03] {3166} INFO - iteration 2, current learner rf
# [flaml.automl: 12-15 04:08:04] {3343} INFO -  at 4.4s,	estimator rf's best error=5.1085,	best estimator rf's best error=5.1085
# [flaml.automl: 12-15 04:08:04] {3166} INFO - iteration 3, current learner rf
# [flaml.automl: 12-15 04:08:06] {3343} INFO -  at 6.3s,	estimator rf's best error=4.3836,	best estimator rf's best error=4.3836
# [flaml.automl: 12-15 04:08:06] {3166} INFO - iteration 4, current learner rf
# [flaml.automl: 12-15 04:08:08] {3343} INFO -  at 8.4s,	estimator rf's best error=3.9570,	best estimator rf's best error=3.9570
# [flaml.automl: 12-15 04:08:08] {3166} INFO - iteration 5, current learner rf
# [flaml.automl: 12-15 04:08:10] {3343} INFO -  at 10.5s,	estimator rf's best error=3.9570,	best estimator rf's best error=3.9570
# [flaml.automl: 12-15 04:08:10] {3166} INFO - iteration 6, current learner rf
# [flaml.automl: 12-15 04:08:12] {3343} INFO -  at 12.4s,	estimator rf's best error=3.7167,	best estimator rf's best error=3.7167
# [flaml.automl: 12-15 04:08:12] {3166} INFO - iteration 7, current learner rf
# [flaml.automl: 12-15 04:08:14] {3343} INFO -  at 13.9s,	estimator rf's best error=3.7167,	best estimator rf's best error=3.7167
# [flaml.automl: 12-15 04:08:14] {3166} INFO - iteration 8, current learner rf
# [flaml.automl: 12-15 04:08:16] {3343} INFO -  at 16.3s,	estimator rf's best error=3.5616,	best estimator rf's best error=3.5616
# [flaml.automl: 12-15 04:08:16] {3166} INFO - iteration 9, current learner rf
# [flaml.automl: 12-15 04:08:18] {3343} INFO -  at 18.2s,	estimator rf's best error=3.5616,	best estimator rf's best error=3.5616
# [flaml.automl: 12-15 04:08:18] {3166} INFO - iteration 10, current learner rf
# [flaml.automl: 12-15 04:08:20] {3343} INFO -  at 20.4s,	estimator rf's best error=3.5616,	best estimator rf's best error=3.5616
# [flaml.automl: 12-15 04:08:20] {3166} INFO - iteration 11, current learner rf
# [flaml.automl: 12-15 04:08:25] {3343} INFO -  at 24.7s,	estimator rf's best error=3.5399,	best estimator rf's best error=3.5399
# [flaml.automl: 12-15 04:08:25] {3166} INFO - iteration 12, current learner rf
# [flaml.automl: 12-15 04:08:27] {3343} INFO -  at 27.3s,	estimator rf's best error=3.5399,	best estimator rf's best error=3.5399
# [flaml.automl: 12-15 04:08:27] {3166} INFO - iteration 13, current learner rf
# [flaml.automl: 12-15 04:08:38] {3343} INFO -  at 37.9s,	estimator rf's best error=3.3953,	best estimator rf's best error=3.3953
# [flaml.automl: 12-15 04:08:38] {3166} INFO - iteration 14, current learner rf
# [flaml.automl: 12-15 04:08:44] {3343} INFO -  at 44.1s,	estimator rf's best error=3.3953,	best estimator rf's best error=3.3953
# [flaml.automl: 12-15 04:08:44] {3166} INFO - iteration 15, current learner rf
# [flaml.automl: 12-15 04:09:03] {3343} INFO -  at 62.6s,	estimator rf's best error=3.3315,	best estimator rf's best error=3.3315
# [flaml.automl: 12-15 04:09:03] {3166} INFO - iteration 16, current learner rf
# [flaml.automl: 12-15 04:09:10] {3343} INFO -  at 70.2s,	estimator rf's best error=3.3315,	best estimator rf's best error=3.3315
# [flaml.automl: 12-15 04:09:10] {3166} INFO - iteration 17, current learner rf
# [flaml.automl: 12-15 04:09:59] {3343} INFO -  at 119.0s,	estimator rf's best error=3.3315,	best estimator rf's best error=3.3315
# [flaml.automl: 12-15 04:09:59] {3166} INFO - iteration 18, current learner rf
# [flaml.automl: 12-15 04:10:42] {3343} INFO -  at 162.1s,	estimator rf's best error=3.3087,	best estimator rf's best error=3.3087
# [flaml.automl: 12-15 04:10:42] {3166} INFO - iteration 19, current learner rf
# [flaml.automl: 12-15 04:12:06] {3343} INFO -  at 245.6s,	estimator rf's best error=3.3054,	best estimator rf's best error=3.3054
# [flaml.automl: 12-15 04:12:06] {3166} INFO - iteration 20, current learner rf
# [flaml.automl: 12-15 04:12:52] {3343} INFO -  at 291.7s,	estimator rf's best error=3.3010,	best estimator rf's best error=3.3010
# [flaml.automl: 12-15 04:12:52] {3166} INFO - iteration 21, current learner rf
# [flaml.automl: 12-15 04:13:07] {3343} INFO -  at 307.4s,	estimator rf's best error=3.3010,	best estimator rf's best error=3.3010
# [flaml.automl: 12-15 04:13:07] {3166} INFO - iteration 22, current learner rf
# [flaml.automl: 12-15 04:14:49] {3343} INFO -  at 408.5s,	estimator rf's best error=3.3010,	best estimator rf's best error=3.3010
# [flaml.automl: 12-15 04:14:49] {3166} INFO - iteration 23, current learner rf
# [flaml.automl: 12-15 04:15:38] {3343} INFO -  at 457.7s,	estimator rf's best error=3.3010,	best estimator rf's best error=3.3010
# [flaml.automl: 12-15 04:15:38] {3166} INFO - iteration 24, current learner rf
# [flaml.automl: 12-15 04:16:16] {3343} INFO -  at 496.2s,	estimator rf's best error=3.3010,	best estimator rf's best error=3.3010
# [flaml.automl: 12-15 04:16:16] {3166} INFO - iteration 25, current learner rf
# [flaml.automl: 12-15 04:17:47] {3343} INFO -  at 586.8s,	estimator rf's best error=3.3010,	best estimator rf's best error=3.3010
# [flaml.automl: 12-15 04:17:47] {3166} INFO - iteration 26, current learner rf
# [flaml.automl: 12-15 04:18:07] {3343} INFO -  at 607.4s,	estimator rf's best error=3.3010,	best estimator rf's best error=3.3010
# [flaml.automl: 12-15 04:18:07] {3166} INFO - iteration 27, current learner rf
# [flaml.automl: 12-15 04:18:49] {3343} INFO -  at 648.7s,	estimator rf's best error=3.3010,	best estimator rf's best error=3.3010
# [flaml.automl: 12-15 04:18:49] {3166} INFO - iteration 28, current learner rf
# [flaml.automl: 12-15 04:19:36] {3343} INFO -  at 695.7s,	estimator rf's best error=3.3010,	best estimator rf's best error=3.3010
# [flaml.automl: 12-15 04:19:36] {3166} INFO - iteration 29, current learner rf
# [flaml.automl: 12-15 04:19:58] {3343} INFO -  at 718.0s,	estimator rf's best error=3.3010,	best estimator rf's best error=3.3010
# [flaml.automl: 12-15 04:19:58] {3166} INFO - iteration 30, current learner rf
# [flaml.automl: 12-15 04:21:08] {3343} INFO -  at 788.0s,	estimator rf's best error=3.3010,	best estimator rf's best error=3.3010
# [flaml.automl: 12-15 04:21:08] {3166} INFO - iteration 31, current learner rf
# [flaml.automl: 12-15 04:21:58] {3343} INFO -  at 838.4s,	estimator rf's best error=3.3010,	best estimator rf's best error=3.3010
# [flaml.automl: 12-15 04:21:58] {3166} INFO - iteration 32, current learner rf
# [flaml.automl: 12-15 04:22:37] {3343} INFO -  at 876.9s,	estimator rf's best error=3.3010,	best estimator rf's best error=3.3010
# [flaml.automl: 12-15 04:22:37] {3166} INFO - iteration 33, current learner rf
# [flaml.automl: 12-15 04:24:00] {3343} INFO -  at 960.1s,	estimator rf's best error=3.3010,	best estimator rf's best error=3.3010
# [flaml.automl: 12-15 04:24:00] {3166} INFO - iteration 34, current learner rf
# [flaml.automl: 12-15 04:24:21] {3343} INFO -  at 980.8s,	estimator rf's best error=3.3010,	best estimator rf's best error=3.3010
# [flaml.automl: 12-15 04:24:21] {3166} INFO - iteration 35, current learner rf
# [flaml.automl: 12-15 04:24:43] {3343} INFO -  at 1003.0s,	estimator rf's best error=3.3010,	best estimator rf's best error=3.3010
# [flaml.automl: 12-15 04:24:43] {3166} INFO - iteration 36, current learner rf
# [flaml.automl: 12-15 04:26:01] {3343} INFO -  at 1080.7s,	estimator rf's best error=3.3010,	best estimator rf's best error=3.3010
# [flaml.automl: 12-15 04:26:01] {3166} INFO - iteration 37, current learner rf
# [flaml.automl: 12-15 04:27:16] {3343} INFO -  at 1156.0s,	estimator rf's best error=3.3010,	best estimator rf's best error=3.3010
# [flaml.automl: 12-15 04:27:16] {3166} INFO - iteration 38, current learner rf
# [flaml.automl: 12-15 04:27:41] {3343} INFO -  at 1180.7s,	estimator rf's best error=3.3010,	best estimator rf's best error=3.3010
# [flaml.automl: 12-15 04:27:41] {3166} INFO - iteration 39, current learner rf
# [flaml.automl: 12-15 04:28:47] {3343} INFO -  at 1247.1s,	estimator rf's best error=3.3010,	best estimator rf's best error=3.3010
# [flaml.automl: 12-15 04:28:47] {3166} INFO - iteration 40, current learner rf
# [flaml.automl: 12-15 04:29:14] {3343} INFO -  at 1274.5s,	estimator rf's best error=3.3010,	best estimator rf's best error=3.3010
# [flaml.automl: 12-15 04:29:14] {3166} INFO - iteration 41, current learner rf
# [flaml.automl: 12-15 04:29:43] {3343} INFO -  at 1303.2s,	estimator rf's best error=3.3010,	best estimator rf's best error=3.3010
# [flaml.automl: 12-15 04:29:43] {3166} INFO - iteration 42, current learner rf
# [flaml.automl: 12-15 04:30:22] {3343} INFO -  at 1342.4s,	estimator rf's best error=3.3010,	best estimator rf's best error=3.3010
# [flaml.automl: 12-15 04:30:22] {3166} INFO - iteration 43, current learner rf
# [flaml.automl: 12-15 04:30:52] {3343} INFO -  at 1371.9s,	estimator rf's best error=3.3010,	best estimator rf's best error=3.3010
# [flaml.automl: 12-15 04:30:52] {3166} INFO - iteration 44, current learner rf
# [flaml.automl: 12-15 04:31:03] {3343} INFO -  at 1382.9s,	estimator rf's best error=3.3010,	best estimator rf's best error=3.3010
# [flaml.automl: 12-15 04:31:03] {3166} INFO - iteration 45, current learner rf
# [flaml.automl: 12-15 04:32:00] {3343} INFO -  at 1439.8s,	estimator rf's best error=3.3010,	best estimator rf's best error=3.3010
# [flaml.automl: 12-15 04:32:06] {3602} INFO - retrain rf for 6.6s
# [flaml.automl: 12-15 04:32:06] {3609} INFO - retrained model: RandomForestRegressor(max_features=0.4621065185993494, max_leaf_nodes=1059,
#                       n_estimators=294, n_jobs=-1)
# [flaml.automl: 12-15 04:32:06] {2901} INFO - fit succeeded
# [flaml.automl: 12-15 04:32:06] {2902} INFO - Time taken to find the best model: 291.7017879486084
# 0.95 0.91 0.19

# %% [markdown]
# from flaml import AutoML
# from sklearn.datasets import fetch_california_housing
# # Initialize an AutoML instance
# automl = AutoML()
# # Specify automl goal and constraint
# automl_settings = {
#     "time_budget": 180,  # in seconds
#     "metric": 'rmse',
#     "task": 'regression',
#     "log_file_name": "california.log",
# }
#
# Pred=[]
# rmse=[]
# model=[]
# for i in range(20):
#     X_Train, X_Test, y_Train, y_Test =train_test_split(X_train,y_train,test_size = 0.2,shuffle=True)
#     # Train with labeled input data
#     automl.fit(X_train=X_Train.drop(['Lab1'], axis=1), y_train=y_Train,**automl_settings,estimator_list=["xgb_limitdepth"])
#     pred=automl.predict(X_test.drop(['Lab1'], axis=1))
#     R2=round(sm.r2_score(y_test, pred), 2)
#     r=round(np.corrcoef(y_test, pred)[0, 1],2)
#     RMSE=round(np.sqrt(sm.mean_squared_error(y_test, pred))/np.mean(y),5)
#     print(r,R2,RMSE)
#     # Predict
#     #print(automl.predict(X_test))
#     # Print the best model
#     print(automl.model.estimator)
#     Pred.append(pred)
#     rmse.append(RMSE)
#     model.append(automl.model.estimator)
#
# Sorted_pred=[]
# sort_index = np.argsort(rmse)
# for i in sort_index:
#     Sorted_pred.append(Pred[i])
# ind=[i for i in range(len(y_test))]
# import matplotlib.pyplot as plt
# fig= plt.figure(figsize=(7,5))
# plt.plot(ind[:200],y_test[:200], color='blue',linewidth=1.5)
# plt.plot(ind[:200],Sorted_pred[1][:200],color='salmon',linewidth=1.5)
# plt.plot(ind[:200],Sorted_pred[17][:200],color='teal',linewidth=1.5)
# plt.legend(['Actual','p10','p90'],loc = 2, bbox_to_anchor = (0.75,1), fontsize=12)
# #plt.plot(ind[:200],Sorted_pred[4][:200],color='black',linewidth=0.2)
# #plt.fill_between(np.array(ind[:200]), np.array(Sorted_pred[0][:200]), np.array(Sorted_pred[4][:200]),
#                  #color='blue', alpha=0.15)
# #plt.plot(ind,Pred[2],color='darkgoldenrod')
# #plt.plot(ind,Pred[3],color='magenta')
# #plt.plot(ind,Pred[4],color='purple')
# plt.xlabel('Observation number',fontsize=16)
# plt.ylabel('Concentraton (ppb)',fontsize=16)
# plt.title('NO2-LDXGBoost',fontsize=16)
# plt.savefig("no2_ldxgboost.pdf", format="pdf", bbox_inches="tight")

# %% [markdown]
# from flaml import AutoML
# from sklearn.datasets import fetch_california_housing
#
# # Initialize an AutoML instance
# automl = AutoML()
# # Specify automl goal and constraint
# automl_settings = {
#     "time_budget": 21600,  # in seconds
#     "metric": 'mae',
#     "task": 'regression',
#     "log_file_name": "california.log",
# }
# # Train with labeled input data
# automl.fit(X_train=X_train.drop(['Lab1'], axis=1), y_train=y_train,**automl_settings,estimator_list=["xgb_limitdepth"])
# pred=automl.predict(X_test.drop(['Lab1'], axis=1))
# R2=round(sm.r2_score(y_test, pred), 2)
# r=round(np.corrcoef(y_test, pred)[0, 1],2)
# RMSE=round(np.sqrt(sm.mean_squared_error(y_test, pred))/np.mean(y),2)
# print(r,R2,RMSE)
# # Predict
# #print(automl.predict(X_test))
# # Print the best model
# print(automl.model.estimator)

# %% [markdown]
# from flaml import AutoML
# from sklearn.datasets import fetch_california_housing
#
# # Initialize an AutoML instance
# automl = AutoML()
# # Specify automl goal and constraint
# automl_settings = {
#     "time_budget": 200,  # in seconds
#     "metric": 'rmse',
#     "task": 'regression',
#     "log_file_name": "california.log",
# }
# # Train with labeled input data
# automl.fit(X_train=X_train.drop(['Lab1'], axis=1), y_train=y_train,**automl_settings,estimator_list=["xgboost"])
# pred=automl.predict(X_test.drop(['Lab1'], axis=1))
# R2=round(sm.r2_score(y_test, pred), 2)
# r=round(np.corrcoef(y_test, pred)[0, 1],2)
# RMSE=round(np.sqrt(sm.mean_squared_error(y_test, pred))/np.mean(y),2)
# print(r,R2,RMSE)
# # Predict
# #print(automl.predict(X_test))
# # Print the best model
# print(automl.model.estimator)

# %% [markdown]
# from sklearn.svm import SVR
# from sklearn.model_selection import GridSearchCV
#
# # defining parameter range
# param_grid = {'C': [0.1, 1, 10, 100, 1000],
#               'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#               'kernel':  ['rbf', 'poly', 'sigmoid']}
#
# grid = GridSearchCV(SVR(), param_grid, refit = True, verbose = 3)
#
# # fitting the model for grid search
# grid.fit(X_train.drop(['Lab1'], axis=1), y_train)
#
# # print best parameter after tuning
# print(grid.best_params_)
#
# # print how our model looks after hyper-parameter tuning
# print(grid.best_estimator_)

# %% [markdown]
# # O3 DATA

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error as mae
import sklearn.metrics as sm
import matplotlib.pyplot as plt
#,'Ref_CO','Ref_NO2','Ref_SO2'
X=O3_Data[['Net Signal','Lab1','Temp','RH','Month','Day_of_week','Hour','Ref_NO2']]#,'Ref_NO2'
y=O3_Data['Ref']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)
len(X)
# Out:
# 3534

# %% [markdown]
# from flaml import AutoML
# from sklearn.datasets import fetch_california_housing
#
# # Initialize an AutoML instance
# automl = AutoML()
# # Specify automl goal and constraint
# automl_settings = {
#     "time_budget": 200,  # in seconds
#     "metric": 'rmse',
#     "task": 'regression',
#     "log_file_name": "california.log",
# }
# # Train with labeled input data
# automl.fit(X_train=X_train.drop(['Lab1'], axis=1), y_train=y_train,**automl_settings,estimator_list=["xgboost"])
# pred=automl.predict(X_test.drop(['Lab1'], axis=1))
# R2=round(sm.r2_score(y_test, pred), 2)
# r=round(np.corrcoef(y_test, pred)[0, 1],2)
# RMSE=round(np.sqrt(sm.mean_squared_error(y_test, pred))/np.mean(y),2)
# print(r,R2,RMSE)
# # Predict
# #print(automl.predict(X_test))
# # Print the best model
# print(automl.model.estimator)

# %% [markdown]
# from sklearn.svm import SVR
# from sklearn.model_selection import GridSearchCV
#
# # defining parameter range
# param_grid = {'C': [0.1, 1, 10, 100, 1000],
#               'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#               'kernel':  ['rbf', 'poly', 'sigmoid']}
#
# grid = GridSearchCV(SVR(), param_grid, refit = True, verbose = 3)
#
# # fitting the model for grid search
# grid.fit(X_train.drop(['Lab1'], axis=1), y_train)
#
# # print best parameter after tuning
# print(grid.best_params_)
#
# # print how our model looks after hyper-parameter tuning
# print(grid.best_estimator_)

# %% [markdown]
# # SO2 DATA

# %%
import pandas as pd
Ref=pd.read_csv('Ref.csv')
Ref["CO"] = 1000 * Ref["CO"]
Ref['Date'] = pd.to_datetime(Ref['Date_Time'])
Ref=Ref.set_index('Date')
Ref.drop('Date_Time',axis = 1, inplace = True)
Ref=Ref.resample('5min').mean()
Ref=Ref[76463:137376]
Ref_CO=Ref['CO'].to_list()
Ref_NO2=Ref['NO2'].to_list()
Ref_SO2=Ref['SO2'].to_list()
Ref_O3=Ref['O3'].to_list()

# %%
import pandas as pd
import scipy.io
import numpy as np
data = pd.read_csv('Conc_SO2.txt', header = None,low_memory=False)
data.columns=['Lab2','Temp','RH','Time','Ref']
Time=data['Time'].to_list()
time=[]
for i in range(len(Time)):
    time.append(float(abs(Time[i])))
Time=np.array(time)
Date=pd.to_datetime(Time-719529,unit='d').round('s')
data['Date'] = Date.tolist()
data=data.set_index('Date')
data.drop('Time',axis = 1, inplace = True)
data=data.resample('5min').mean()
Data_SO2=data
Data_so2=data
#signal=np.array(WE)-np.array(AE)
#Data_SO2['Net Signal']=signal
Data_SO2['Month']=Data_SO2.index.month
Data_SO2['Day_of_week']=Data_SO2.index.dayofweek
Data_SO2['Day']=Data_SO2.index.day
Data_SO2['Hour']=Data_SO2.index.hour
SO2_Data=Data_SO2
SO2_Data=SO2_Data.resample('5min').mean()
SO2_Data=SO2_Data[(SO2_Data[SO2_Data.columns] >= 0).all(axis=1)]
SO2_Data=SO2_Data.dropna() 
data = pd.read_csv('SO2.txt', header = None,low_memory=False)
data.columns=['WE','AE','Temp','RH','Time']
Time=data['Time'].to_list()
time=[]
for i in range(len(Time)):
    time.append(float(abs(Time[i])))
Time=np.array(time)
Date=pd.to_datetime(Time-719529,unit='d').round('s')
data['Date'] = Date.tolist()
data=data.set_index('Date')
data.drop('Time',axis = 1, inplace = True)
data=data.resample('5min').mean()
Data_SO2=data
Data_SO2['Ref']=Ref_SO2
WE=Data_SO2['WE'].to_list()
AE=Data_SO2['AE'].to_list()
signal=np.array(WE)-np.array(AE)
Data_SO2['Lab2']=Data_so2['Lab2'].to_list()
Data_SO2['Net Signal']=signal
Data_SO2['Month']=Data_SO2.index.month
Data_SO2['Day_of_week']=Data_SO2.index.dayofweek
Data_SO2['Day']=Data_SO2.index.day
Data_SO2['Hour']=Data_SO2.index.hour
SO2_Data=Data_SO2
SO2_Data.shape
# Out:
# (60913, 11)

# %%
SO2_Data=SO2_Data[(SO2_Data[SO2_Data.columns] >= 0).all(axis=1)]
SO2_Data=SO2_Data.dropna()
SO2_Data=SO2_Data.resample('h').mean()
SO2_Data=SO2_Data.dropna()
SO2_Data.head()
# Out:
#                              WE          AE       Temp         RH       Ref  \
# Date
# 2019-10-10 04:00:00  344.013811  342.484305  18.332589  82.373211  1.190555
# 2019-10-10 05:00:00  347.947204  342.688948  18.160512  83.041499  1.517400
# 2019-10-10 06:00:00  349.586425  342.643169  18.294731  80.755815  1.596648
# 2019-10-10 07:00:00  348.280332  342.545156  21.874264  74.161148  1.518688
# 2019-10-10 08:00:00  352.303813  345.041354  29.141688  59.611152  1.379748
#
#                           Lab2  Net Signal  Month  Day_of_week   Day  Hour
# Date
# 2019-10-10 04:00:00   9.990807    1.529506   10.0          3.0  10.0   4.0
# 2019-10-10 05:00:00  21.173371    5.258256   10.0          3.0  10.0   5.0
# 2019-10-10 06:00:00  26.255508    6.943256   10.0          3.0  10.0   6.0
# 2019-10-10 07:00:00  22.449829    5.735176   10.0          3.0  10.0   7.0
# 2019-10-10 08:00:00  23.209242    7.262459   10.0          3.0  10.0   8.0

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error as mae
import sklearn.metrics as sm
import matplotlib.pyplot as plt
#'Ref_CO','Ref_NO2','Ref_O3',
X=SO2_Data[['Net Signal','Lab2','Temp','RH','Month','Day_of_week','Hour']]
y=SO2_Data['Ref']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)
len(X)
# Out:
# 1996

# %% [markdown]
# from flaml import AutoML
# from sklearn.datasets import fetch_california_housing
#
# # Initialize an AutoML instance
# automl = AutoML()
# # Specify automl goal and constraint
# automl_settings = {
#     "time_budget": 200,  # in seconds
#     "metric": 'rmse',
#     "task": 'regression',
#     "log_file_name": "california.log",
# }
# # Train with labeled input data
# automl.fit(X_train=X_train.drop(['Lab2'], axis=1), y_train=y_train,**automl_settings,estimator_list=["xgboost"])
# pred=automl.predict(X_test.drop(['Lab2'], axis=1))
# R2=round(sm.r2_score(y_test, pred), 2)
# r=round(np.corrcoef(y_test, pred)[0, 1],2)
# RMSE=round(np.sqrt(sm.mean_squared_error(y_test, pred))/np.mean(y),2)
# print(r,R2,RMSE)
# # Predict
# #print(automl.predict(X_test))
# # Print the best model
# print(automl.model.estimator)

# %% [markdown]
# from sklearn.svm import SVR
# from sklearn.model_selection import GridSearchCV
#
# # defining parameter range
# param_grid = {'C': [0.1, 1, 10, 100, 1000],
#               'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#               'kernel':  ['rbf', 'poly', 'sigmoid']}
#
# grid = GridSearchCV(SVR(), param_grid, refit = True, verbose = 3)
#
# # fitting the model for grid search
# grid.fit(X_train.drop(['Lab2'], axis=1), y_train)
#
# # print best parameter after tuning
# print(grid.best_params_)
#
# # print how our model looks after hyper-parameter tuning
# print(grid.best_estimator_)
